# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn import Linear, Dropout, LayerNorm
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import SAGEConv, global_add_pool, GraphConv
from torch.nn.utils import clip_grad_norm_
from torch.optim.lr_scheduler import ReduceLROnPlateau

import networkx as nx
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
import seaborn as sns
import random
import uproot

# %%
torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
path_to_tree = "DecayTreeTuple/tuple"

def rename_columns(df):
    new_columns = {}
    for col in df.columns:
        if "_BDTTag_" in col:
            new_columns[col] = col.replace("_BDTTag_", "_SVtag_")
    df.rename(columns=new_columns, inplace=True)

# maybe don't need
def extract_float(awk_array):
    return awk_array[0] if len(awk_array) > 0 else None

# %%
# Read the ROOT file
tree = uproot.open("Dijet_bb_pt20_50_dw.root" + ":" + path_to_tree)
bb_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000) 

# Clean column names and remove unwanted columns
bb_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in bb_df.columns]
rename_columns(bb_df)
columns_to_remove = [col for col in bb_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
bb_df.drop(columns=columns_to_remove, inplace=True)
for col in bb_df.columns:
    if "SVtag" in col:
        bb_df[col] = bb_df[col].apply(extract_float)
tree.close()

# Read the ROOT file
tree = uproot.open("Dijet_qq_pt20_50_dw.root" + ":" + path_to_tree)
qq_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000) 

# Clean column names and remove unwanted columns
qq_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in qq_df.columns]
rename_columns(qq_df)
columns_to_remove = [col for col in qq_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
qq_df.drop(columns=columns_to_remove, inplace=True)
for col in qq_df.columns:
    if "SVtag" in col:
        qq_df[col] = qq_df[col].apply(extract_float)
tree.close()

# %%
# Read the ROOT file
tree = uproot.open("Dijet_bb_pt50_dw.root" + ":" + path_to_tree)
bb50_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000) 

# Clean column names and remove unwanted columns
bb50_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in bb50_df.columns]
rename_columns(bb50_df)
columns_to_remove = [col for col in bb50_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
bb50_df.drop(columns=columns_to_remove, inplace=True)
for col in bb50_df.columns:
    if "SVtag" in col:
        bb50_df[col] = bb50_df[col].apply(extract_float)
tree.close()

# Read the ROOT file
tree = uproot.open("Dijet_qq_pt50_dw.root" + ":" + path_to_tree)
qq50_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000) 

# Clean column names and remove unwanted columns
qq50_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in qq50_df.columns]
rename_columns(qq50_df)
columns_to_remove = [col for col in qq50_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
qq50_df.drop(columns=columns_to_remove, inplace=True)
for col in qq50_df.columns:
    if "SVtag" in col:
        qq50_df[col] = qq50_df[col].apply(extract_float)
tree.close()

# %%
weights = {
    "bb_df": 1,
    "qq_df": 1,
    "bb50_df": 0.03073569429,
    "qq50_df": 0.02991944973
}

for df_name, weight in weights.items():
    globals()[df_name]['weights'] = weight

sig_df = pd.concat([bb_df, bb50_df])
bkg_df = pd.concat([qq_df, qq50_df])

# %%
print(f'There are {len(sig_df)} b-jet events (signal)')
print(f'There are {len(bkg_df)} q-jet events (background)')
# Out:
# There are 2000 b-jet events (signal)
# There are 2000 q-jet events (background)

# %%
# Distinguish signal and background
sig_df['IsB'] = 1
bkg_df['IsB'] = 0

# Filter columns to include only leading jet data and truth labels
sig_df = sig_df[sig_df.columns[sig_df.columns.str.contains("Jet0|IsB|weights")]]
bkg_df = bkg_df[bkg_df.columns[bkg_df.columns.str.contains("Jet0|IsB|weights")]]

# Apply cuts and truth matching
sig_df = sig_df[(sig_df['Jet0_MC_Match'] == 1) &
                (sig_df['Jet0_MC_Jet_EfB'] > 0.6) &
                (sig_df['Jet0_PT'] > 20000) &
                (sig_df['Jet0_Eta'].between(2.2, 4.4))]
bkg_df = bkg_df[(bkg_df['Jet0_MC_Match'] == 1) &
                (bkg_df['Jet0_MC_Jet_EfB'] < 0.6) &
                (bkg_df['Jet0_MC_Jet_EfD'] < 0.6) &
                (bkg_df['Jet0_PT'] > 20000) &
                (bkg_df['Jet0_Eta'].between(2.2, 4.4))]

# Combine signal and background
combined_df = pd.concat([sig_df, bkg_df]).reset_index(drop=True)

# %%
print(f"Efficiency of signal truth matching is: {len(sig_df)/len(bb_df):.4f}")
print(f"Efficiency of background truth matching is: {len(bkg_df)/len(qq_df):.4f}")
print('')
print(f"Total events after truth matching: {len(combined_df)}")
print(f"Number of b-jets after truth matching: {len(sig_df)}")
# Out:
# Efficiency of signal truth matching is: 0.6570
# Efficiency of background truth matching is: 0.8250
#
# Total events after truth matching: 1482
# Number of b-jets after truth matching: 657

# %% [markdown]
# The csv stores daughter information as a string, so the prepare features function converts them into accessible lists of floats. This function also duplicates jet-level features into lists of floats with lengths equal to the number of nodes in each jet, in order to match the formatting of the daughter-level features, where each float in a list corresponds to a daughter. The data is processed into a new dataframe. Then, the signal and background features are separated again. Training and testing data are created with equal parts of shuffled signal and background data, in a 80:20 ratio of the available leading jet data. The data before processing with signal and background combined includes 600k jets. After the truth matching and cuts are applied, there are 411,540 jets.

# %%
# Define feature columns including jet-level and daughter-level features
daughter_cols = [col for col in sig_df.columns if "_Daughters" in col]
svtag_cols = ['Jet0_SVtag_fdrMin',
 'Jet0_SVtag_ptSvrJet',
 'Jet0_SVtag_nTrk',
 'Jet0_SVtag_nTrkJet',
 'Jet0_SVtag_drSvrJet',
 'Jet0_SVtag_absQSum',
 'Jet0_SVtag_m',
 'Jet0_SVtag_mCor',
 'Jet0_SVtag_fdChi2',
 'Jet0_SVtag_ipChi2Sum',
 'Jet0_SVtag_tau',
 'Jet0_SVtag_z',
 'Jet0_SVtag_pt']
jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
feature_cols = daughter_cols + jet_cols

# Prepare features by converting daughter information to lists and duplicating jet-level features
def prepare_features(df, jet_cols, daughter_cols):
    # Duplicate data to lists matching the number of daughters/nodes per jet/row
    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)

    # Convert string values into list of floats
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)
    return df

df = prepare_features(combined_df, jet_cols, daughter_cols)

# %%
# Split data into training, validation, and test sets
sig_df = df[df['IsB'] == 1].sample(frac=1, random_state=42).reset_index(drop=True)
bkg_df = df[df['IsB'] == 0].sample(frac=1, random_state=42).reset_index(drop=True)

half_train_size = int((sum(combined_df.IsB)*0.8)/2)
half_test_size = int((sum(combined_df.IsB)*0.2)/2)

train_df = pd.concat([sig_df.head(half_train_size), bkg_df.head(half_train_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of training data is: {len(train_df)}')

test_df = pd.concat([sig_df.tail(half_test_size), bkg_df.tail(half_test_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of testing data is: {len(test_df)}')

validation_df = pd.concat([sig_df.iloc[half_train_size:-half_test_size], bkg_df.iloc[half_train_size:-half_test_size]]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of validation data is: {len(validation_df)}')
# Out:
# Length of training data is: 524
# Length of testing data is: 130
# Length of validation data is: 828

# %%
print('Ratio of c to b in datasets:')
print(f'    Training data: {sum(train_df.IsB)/len(train_df)}')
print(f'    Testing data: {sum(test_df.IsB)/len(test_df)}')
print(f'    Validation data: {sum(validation_df.IsB)/len(validation_df)}')
# Out:
# Ratio of c to b in datasets:
#     Training data: 0.5
#     Testing data: 0.5
#     Validation data: 0.39855072463768115

# %%
# Create graphs for training and testing
def create_graphs(df, feature_cols):

    features_list = []
    
    for _, row in df.iterrows():
        num_nodes = row['Jet0_nDaughters']
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    data_objects = []
    for idx, features in enumerate(features_list):

        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        # Create fully connected graph
        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()
        edge_weight = torch.tensor([df['weights'].iloc[idx]] * edge_index.size(1), dtype=torch.float) 

        y = torch.tensor([df['IsB'].iloc[idx]], dtype=torch.float)
        
        data = Data(x=x, edge_index=edge_index, y=y, num_nodes=num_nodes)
        data_objects.append(data)

    return data_objects

# Create graphs for training and testing
train_data = create_graphs(train_df, feature_cols)
test_data = create_graphs(test_df, feature_cols)

# Load data in batches
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %% [markdown]
# # Classifier

# %%
class GNN(torch.nn.Module):
    def __init__(self):
        super(GNN, self).__init__()
        hidden_channels = 64
        self.conv1 = GraphConv(len(feature_cols), hidden_channels)
        self.ln1 = LayerNorm(hidden_channels)
        self.conv2 = GraphConv(hidden_channels, hidden_channels)
        self.ln2 = LayerNorm(hidden_channels)
        self.conv3 = GraphConv(hidden_channels, hidden_channels)
        self.ln3 = LayerNorm(hidden_channels)
        self.conv4 = GraphConv(hidden_channels, hidden_channels)
        self.ln4 = LayerNorm(hidden_channels)
        self.lin = Linear(hidden_channels, 1)
        self.dropout = Dropout(0.3)

    def forward(self, x, edge_index, batch, edge_weight):        
        x = self.conv1(x, edge_index, edge_weight)
        x = self.ln1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv2(x, edge_index, edge_weight)
        x = self.ln2(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv3(x, edge_index, edge_weight)
        x = self.ln3(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv4(x, edge_index, edge_weight)
        x = self.ln4(x)
        x = F.relu(x)

        x = global_add_pool(x, batch)
        x = self.lin(x)
        return x.squeeze(1)
    
model = GNN()
model = model.to(device)

# %% [markdown]
# # Model Evaluation

# %%
# Define optimizer and loss function
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = nn.BCEWithLogitsLoss()
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5) # reduce lr by 0.5 every 5 epochs


# Training loop
def train():
    model.train()
    total_loss = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch, data.edge_weight)
        loss = criterion(out, data.y.float())
        clip_grad_norm_(model.parameters(), max_norm=0.5)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    return avg_loss

# Testing function
def test(loader):
    model.eval()
    total_correct = 0
    total_samples = 0
    total_loss = 0
    
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index, data.batch, data.edge_weight)
            loss = criterion(out, data.y.float())
            pred = (out > 0).float()
            correct = (pred.squeeze() == data.y.float()).sum().item()
            total_correct += correct
            total_samples += len(data.y)
            total_loss += loss.item() * data.num_graphs

        avg_loss = total_loss / len(loader.dataset)
        acc = total_correct / total_samples
    return avg_loss, acc

# Training parameters
num_epochs = 200

# Initialize lists for storing loss and accuracy values
train_loss_values = []
train_acc_values = []
test_loss_values = []
test_acc_values = []

# Training loop
for epoch in range(num_epochs):

    train_loss = train()
    train_loss_values.append(train_loss)

    train_acc = test(train_loader)[1]
    train_acc_values.append(train_acc)

    test_loss, test_acc = test(test_loader)
    test_loss_values.append(test_loss)
    test_acc_values.append(test_acc)

    scheduler.step(test_loss)

    print(f'Epoch: {epoch+1:03d}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')

    # Save the model and results every 50 epochs
    if (epoch + 1) % 50 == 0:
        # Overwrite the existing model file
        torch.save(model.state_dict(), 'bq50_model1.pth')
        print('Model saved as bq50_model1.pth.')

        # Save the loss and accuracy values to a CSV file, overwriting the existing file
        results_df = pd.DataFrame({
            'Epoch': list(range(1, epoch + 2)),
            'Train Loss': train_loss_values,
            'Test Loss': test_loss_values,
            'Train Accuracy': train_acc_values,
            'Test Accuracy': test_acc_values
        })
        results_df.to_csv('bq50_training1.csv', index=False)
        print('Training results saved as bq50_training1.csv.')

torch.save(model.state_dict(), 'bq50_model1.pth')
print('Model saved as bq50_model1.pth. Training complete.')

results_df = pd.DataFrame({
    'Epoch': list(range(1, num_epochs+1)),
    'Train Loss': train_loss_values,
    'Test Loss': test_loss_values,
    'Train Accuracy': train_acc_values,
    'Test Accuracy': test_acc_values
})

# Save the loss and accuracy values to a CSV file
results_df.to_csv('bq50_training1.csv', index=False)
print('Training results saved as bq50_training1.csv. Training complete.')
# Out:
# Epoch: 001, Train Loss: 3.5411, Test Loss: 2.1611, Train Acc: 0.5038, Test Acc: 0.5000
# Epoch: 002, Train Loss: 1.4163, Test Loss: 0.9551, Train Acc: 0.5344, Test Acc: 0.5692
# Epoch: 003, Train Loss: 1.2748, Test Loss: 0.9376, Train Acc: 0.5191, Test Acc: 0.5538
# Epoch: 004, Train Loss: 1.0853, Test Loss: 0.6968, Train Acc: 0.6145, Test Acc: 0.6385
# Epoch: 005, Train Loss: 0.9295, Test Loss: 0.8522, Train Acc: 0.6355, Test Acc: 0.6077
# Epoch: 006, Train Loss: 0.9749, Test Loss: 0.6595, Train Acc: 0.7080, Test Acc: 0.6538
# Epoch: 007, Train Loss: 0.8716, Test Loss: 0.5894, Train Acc: 0.7462, Test Acc: 0.7308
# Epoch: 008, Train Loss: 0.8095, Test Loss: 0.6826, Train Acc: 0.7443, Test Acc: 0.6923
# Epoch: 009, Train Loss: 0.7901, Test Loss: 0.6590, Train Acc: 0.7557, Test Acc: 0.7077
# Epoch: 010, Train Loss: 0.8286, Test Loss: 0.6215, Train Acc: 0.7710, Test Acc: 0.7308
# Epoch: 011, Train Loss: 0.7801, Test Loss: 0.6366, Train Acc: 0.7672, Test Acc: 0.7308
# Epoch: 012, Train Loss: 0.7682, Test Loss: 0.6458, Train Acc: 0.7691, Test Acc: 0.7308
# Epoch: 013, Train Loss: 0.7445, Test Loss: 0.5933, Train Acc: 0.7882, Test Acc: 0.7385
# Epoch: 014, Train Loss: 0.7112, Test Loss: 0.6161, Train Acc: 0.7748, Test Acc: 0.7308
# Epoch: 015, Train Loss: 0.7346, Test Loss: 0.6427, Train Acc: 0.7672, Test Acc: 0.7308
# Epoch: 016, Train Loss: 0.6874, Test Loss: 0.6221, Train Acc: 0.7691, Test Acc: 0.7308
# Epoch: 017, Train Loss: 0.7444, Test Loss: 0.5953, Train Acc: 0.7767, Test Acc: 0.7385
# Epoch: 018, Train Loss: 0.6824, Test Loss: 0.5974, Train Acc: 0.7767, Test Acc: 0.7385
# Epoch: 019, Train Loss: 0.7098, Test Loss: 0.5912, Train Acc: 0.7844, Test Acc: 0.7385
# Epoch: 020, Train Loss: 0.6499, Test Loss: 0.5922, Train Acc: 0.7844, Test Acc: 0.7385
# Epoch: 021, Train Loss: 0.6753, Test Loss: 0.5946, Train Acc: 0.7824, Test Acc: 0.7385
# Epoch: 022, Train Loss: 0.6605, Test Loss: 0.6046, Train Acc: 0.7748, Test Acc: 0.7385
# Epoch: 023, Train Loss: 0.6932, Test Loss: 0.5975, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 024, Train Loss: 0.6848, Test Loss: 0.5783, Train Acc: 0.7882, Test Acc: 0.7308
# Epoch: 025, Train Loss: 0.6404, Test Loss: 0.5668, Train Acc: 0.7939, Test Acc: 0.7308
# Epoch: 026, Train Loss: 0.6634, Test Loss: 0.5743, Train Acc: 0.7882, Test Acc: 0.7308
# Epoch: 027, Train Loss: 0.5988, Test Loss: 0.5928, Train Acc: 0.7824, Test Acc: 0.7385
# Epoch: 028, Train Loss: 0.6774, Test Loss: 0.5995, Train Acc: 0.7767, Test Acc: 0.7385
# Epoch: 029, Train Loss: 0.6602, Test Loss: 0.6076, Train Acc: 0.7748, Test Acc: 0.7385
# Epoch: 030, Train Loss: 0.6905, Test Loss: 0.6132, Train Acc: 0.7748, Test Acc: 0.7385
# Epoch: 031, Train Loss: 0.6470, Test Loss: 0.5900, Train Acc: 0.7824, Test Acc: 0.7385
# Epoch: 032, Train Loss: 0.6861, Test Loss: 0.5909, Train Acc: 0.7824, Test Acc: 0.7385
# Epoch: 033, Train Loss: 0.6351, Test Loss: 0.5961, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 034, Train Loss: 0.6381, Test Loss: 0.6003, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 035, Train Loss: 0.6488, Test Loss: 0.6062, Train Acc: 0.7748, Test Acc: 0.7385
# Epoch: 036, Train Loss: 0.6375, Test Loss: 0.5996, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 037, Train Loss: 0.6612, Test Loss: 0.5944, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 038, Train Loss: 0.6743, Test Loss: 0.5925, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 039, Train Loss: 0.6500, Test Loss: 0.5932, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 040, Train Loss: 0.6299, Test Loss: 0.5966, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 041, Train Loss: 0.6357, Test Loss: 0.5972, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 042, Train Loss: 0.6297, Test Loss: 0.5969, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 043, Train Loss: 0.6108, Test Loss: 0.5960, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 044, Train Loss: 0.6899, Test Loss: 0.5967, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 045, Train Loss: 0.6360, Test Loss: 0.5961, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 046, Train Loss: 0.6383, Test Loss: 0.5971, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 047, Train Loss: 0.6867, Test Loss: 0.5982, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 048, Train Loss: 0.6287, Test Loss: 0.5985, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 049, Train Loss: 0.6714, Test Loss: 0.5983, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 050, Train Loss: 0.6262, Test Loss: 0.5974, Train Acc: 0.7805, Test Acc: 0.7385
# Model saved as bq50_model1.pth.
# Training results saved as bq50_training1.csv.
# Epoch: 051, Train Loss: 0.6304, Test Loss: 0.5967, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 052, Train Loss: 0.6635, Test Loss: 0.5952, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 053, Train Loss: 0.6274, Test Loss: 0.5940, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 054, Train Loss: 0.5892, Test Loss: 0.5940, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 055, Train Loss: 0.6330, Test Loss: 0.5934, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 056, Train Loss: 0.6934, Test Loss: 0.5930, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 057, Train Loss: 0.5865, Test Loss: 0.5928, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 058, Train Loss: 0.6414, Test Loss: 0.5928, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 059, Train Loss: 0.6556, Test Loss: 0.5925, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 060, Train Loss: 0.6149, Test Loss: 0.5925, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 061, Train Loss: 0.6746, Test Loss: 0.5927, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 062, Train Loss: 0.6334, Test Loss: 0.5929, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 063, Train Loss: 0.6961, Test Loss: 0.5931, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 064, Train Loss: 0.6306, Test Loss: 0.5933, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 065, Train Loss: 0.6316, Test Loss: 0.5932, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 066, Train Loss: 0.6454, Test Loss: 0.5933, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 067, Train Loss: 0.6650, Test Loss: 0.5934, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 068, Train Loss: 0.6647, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 069, Train Loss: 0.5836, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 070, Train Loss: 0.6123, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 071, Train Loss: 0.6311, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 072, Train Loss: 0.6797, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 073, Train Loss: 0.6708, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 074, Train Loss: 0.6035, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 075, Train Loss: 0.6103, Test Loss: 0.5934, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 076, Train Loss: 0.5879, Test Loss: 0.5934, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 077, Train Loss: 0.6465, Test Loss: 0.5934, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 078, Train Loss: 0.6482, Test Loss: 0.5934, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 079, Train Loss: 0.6537, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 080, Train Loss: 0.6259, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 081, Train Loss: 0.6033, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 082, Train Loss: 0.6281, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 083, Train Loss: 0.6789, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 084, Train Loss: 0.6340, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 085, Train Loss: 0.6495, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 086, Train Loss: 0.6546, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 087, Train Loss: 0.6477, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 088, Train Loss: 0.6174, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 089, Train Loss: 0.6109, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 090, Train Loss: 0.6574, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 091, Train Loss: 0.6170, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 092, Train Loss: 0.6455, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 093, Train Loss: 0.6785, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 094, Train Loss: 0.6588, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 095, Train Loss: 0.6376, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 096, Train Loss: 0.6300, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 097, Train Loss: 0.6264, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 098, Train Loss: 0.6672, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 099, Train Loss: 0.6889, Test Loss: 0.5936, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 100, Train Loss: 0.6814, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Model saved as bq50_model1.pth.
# Training results saved as bq50_training1.csv.
# Epoch: 101, Train Loss: 0.6714, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 102, Train Loss: 0.6420, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 103, Train Loss: 0.6350, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 104, Train Loss: 0.6592, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 105, Train Loss: 0.6536, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 106, Train Loss: 0.6341, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 107, Train Loss: 0.6049, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 108, Train Loss: 0.6014, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 109, Train Loss: 0.6378, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 110, Train Loss: 0.7350, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 111, Train Loss: 0.6112, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 112, Train Loss: 0.6687, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 113, Train Loss: 0.5961, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 114, Train Loss: 0.6392, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 115, Train Loss: 0.6289, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 116, Train Loss: 0.6444, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 117, Train Loss: 0.6212, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 118, Train Loss: 0.6322, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 119, Train Loss: 0.6600, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 120, Train Loss: 0.5666, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 121, Train Loss: 0.6756, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 122, Train Loss: 0.6048, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 123, Train Loss: 0.6921, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 124, Train Loss: 0.6043, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 125, Train Loss: 0.6167, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 126, Train Loss: 0.6103, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 127, Train Loss: 0.6463, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 128, Train Loss: 0.6425, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 129, Train Loss: 0.6329, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 130, Train Loss: 0.6260, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 131, Train Loss: 0.6510, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 132, Train Loss: 0.6121, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 133, Train Loss: 0.6358, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 134, Train Loss: 0.6127, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 135, Train Loss: 0.6272, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 136, Train Loss: 0.6056, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 137, Train Loss: 0.6908, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 138, Train Loss: 0.6477, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 139, Train Loss: 0.6569, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 140, Train Loss: 0.6230, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 141, Train Loss: 0.6003, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 142, Train Loss: 0.5969, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 143, Train Loss: 0.6661, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 144, Train Loss: 0.6375, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 145, Train Loss: 0.6426, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 146, Train Loss: 0.5946, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 147, Train Loss: 0.6639, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 148, Train Loss: 0.6516, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 149, Train Loss: 0.6531, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 150, Train Loss: 0.6339, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Model saved as bq50_model1.pth.
# Training results saved as bq50_training1.csv.
# Epoch: 151, Train Loss: 0.5978, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 152, Train Loss: 0.6622, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 153, Train Loss: 0.6299, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 154, Train Loss: 0.6353, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 155, Train Loss: 0.6024, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 156, Train Loss: 0.6110, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 157, Train Loss: 0.6740, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 158, Train Loss: 0.6609, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 159, Train Loss: 0.6006, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 160, Train Loss: 0.5965, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 161, Train Loss: 0.6750, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 162, Train Loss: 0.6491, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 163, Train Loss: 0.6585, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 164, Train Loss: 0.6497, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 165, Train Loss: 0.6323, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 166, Train Loss: 0.6219, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 167, Train Loss: 0.6592, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 168, Train Loss: 0.6045, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 169, Train Loss: 0.6348, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 170, Train Loss: 0.6734, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 171, Train Loss: 0.6344, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 172, Train Loss: 0.6373, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 173, Train Loss: 0.6678, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 174, Train Loss: 0.6538, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 175, Train Loss: 0.6329, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 176, Train Loss: 0.6343, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 177, Train Loss: 0.6216, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 178, Train Loss: 0.6527, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 179, Train Loss: 0.6460, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 180, Train Loss: 0.6569, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 181, Train Loss: 0.6275, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 182, Train Loss: 0.6592, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 183, Train Loss: 0.6554, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 184, Train Loss: 0.6556, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 185, Train Loss: 0.6068, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 186, Train Loss: 0.5801, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 187, Train Loss: 0.6634, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 188, Train Loss: 0.6080, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 189, Train Loss: 0.6306, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 190, Train Loss: 0.5655, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 191, Train Loss: 0.6084, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 192, Train Loss: 0.6551, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 193, Train Loss: 0.5665, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 194, Train Loss: 0.6026, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 195, Train Loss: 0.6220, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 196, Train Loss: 0.6082, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 197, Train Loss: 0.5926, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 198, Train Loss: 0.6050, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 199, Train Loss: 0.6622, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Epoch: 200, Train Loss: 0.6013, Test Loss: 0.5935, Train Acc: 0.7805, Test Acc: 0.7385
# Model saved as bq50_model1.pth.
# Training results saved as bq50_training1.csv.
# Model saved as bq50_model1.pth. Training complete.
# Training results saved as bq50_training1.csv. Training complete.

# %%
# Reload training data to produce plots
training = pd.read_csv('bq50_training1.csv')
train_loss_values = training['Train Loss'].to_list()
test_loss_values = training['Test Loss'].to_list()
train_acc_values = training['Train Accuracy'].to_list()
test_acc_values = training['Test Accuracy'].to_list()

# %%
training
# Out:
#      Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy
# 0        1    3.541074   2.161097        0.503817       0.500000
# 1        2    1.416329   0.955092        0.534351       0.569231
# 2        3    1.274839   0.937580        0.519084       0.553846
# 3        4    1.085326   0.696846        0.614504       0.638462
# 4        5    0.929456   0.852166        0.635496       0.607692
# ..     ...         ...        ...             ...            ...
# 195    196    0.608243   0.593488        0.780534       0.738462
# 196    197    0.592562   0.593478        0.780534       0.738462
# 197    198    0.605045   0.593475        0.780534       0.738462
# 198    199    0.662179   0.593475        0.780534       0.738462
# 199    200    0.601284   0.593480        0.780534       0.738462
#
# [200 rows x 5 columns]

# %%
# Plot Loss and Accuracy
def plot_training_results():
    epochs = range(1, len(train_loss_values) + 1)

    mean_train_loss = np.mean(train_loss_values)
    mean_test_loss = np.mean(test_loss_values)
    mean_train_acc = np.mean(train_acc_values)
    mean_test_acc = np.mean(test_acc_values)

    min_train_loss = min(train_loss_values)
    min_test_loss = min(test_loss_values)
    max_train_acc = max(train_acc_values)
    max_test_acc = max(test_acc_values)

    final_train_loss = train_loss_values[-1]
    final_test_loss = test_loss_values[-1]
    final_train_acc = train_acc_values[-1]
    final_test_acc = test_acc_values[-1]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    #fig.suptitle('Training Results', fontsize=16)

    # Plot Loss
    ax1.plot(epochs, train_loss_values, color='darkred', label=(f"Training Loss (min = {min_train_loss:.4f})"))
    ax1.plot(epochs, test_loss_values, color='mediumblue', label=(f"Testing Loss (min = {min_test_loss:.4f})"))

    ax1.text(0.15, 0.90, "LHCb Simulation", transform=ax1.transAxes, fontsize=14, verticalalignment='bottom')

    ax1.set_title('Loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='best')

    # Plot  Accuracy
    ax2.plot(epochs, train_acc_values, color='darkred', label=(f"Training Accuracy (max = {max_train_acc:.4f})"))
    ax2.plot(epochs, test_acc_values, color='mediumblue', label=(f"Testing Accuracy (max = {max_test_acc:.4})"))

    ax2.text(0.7, 0.15, "LHCb Simulation", transform=ax2.transAxes, fontsize=14, verticalalignment='bottom')

    ax2.set_title(' Accuracy')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.legend(loc='best')

    plt.style.use('default')
    plt.tight_layout()
    plt.show()
    
# After your training loop, call the function:
plot_training_results()

# %%
# Get model predictions
y_true = []  # class values (0 or 1)
y_scores = []  # predicted probabilities or scores

model.load_state_dict(torch.load('bq50_model1.pth'))
model = model.to('cpu')
model.eval()
with torch.no_grad():
    for data in test_loader:
        out = model(data.x, data.edge_index, data.batch, data.edge_weight)
        prob = torch.sigmoid(out)
        
        y_true.append(data.y.numpy().flatten())
        y_scores.append(prob.numpy().flatten())

y_true = np.concatenate(y_true)
y_scores = np.concatenate(y_scores)

fpr, tpr, thresholds = roc_curve(y_true, y_scores)
auc = roc_auc_score(y_true, y_scores)

# Save each array separately
np.save('bq50_fpr.npy', fpr)
np.save('bq50_tpr.npy', tpr)
np.save('bq50_thresholds.npy', thresholds)
np.save('bq50_auc.npy', auc)

# %%
# Load ROC data
fpr1 = np.load('cq50_fpr.npy', allow_pickle=True)
tpr1 = np.load('cq50_tpr.npy', allow_pickle=True)
thresholds1 = np.load('cq50_thresholds.npy', allow_pickle=True)
auc1 = np.load('cq50_auc.npy', allow_pickle=True)
fpr2 = np.load('bq50_fpr.npy', allow_pickle=True)
tpr2 = np.load('bq50_tpr.npy', allow_pickle=True)
thresholds2 = np.load('bq50_thresholds.npy', allow_pickle=True)
auc2 = np.load('bq50_auc.npy', allow_pickle=True)

# Plot ROC curves
plt.figure(figsize=(8, 6))
plt.plot(fpr1, tpr1, label=f'c vs q ROC Curve (AUC = {auc1:.4f})', color='green')
plt.plot(fpr2, tpr2, label=f'b vs q ROC Curve (AUC = {auc2:.4f})', color='purple')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')

# Labels and legend
plt.text(0.85, 0.15, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('Signal Efficency (TPR)')
plt.xlim(0,1)
plt.ylim(0,1)
plt.title('Receiver Operating Characteristics (ROC)')
plt.legend(loc='lower right')
plt.show()

# %%
# Get FPRs for TPRs
desired_tpr = [0.85, 0.80, 0.75, 0.70, 0.65, 0.60]

print("Efficiency | FPR ")
for val in desired_tpr:
    # Find the index of the closest TPR to the desired TPR value
    closest_index = np.argmin(np.abs(tpr - val))

    # Get the chosen threshold and corresponding FPR, where the threshold is the probability cutoff
    chosen_threshold = thresholds[closest_index]
    given_fpr = fpr[closest_index]
    print(f"{val}: {given_fpr:.4f}")
# Out:
# Efficiency | FPR
# 0.85: 0.6000
# 0.8: 0.5692
# 0.75: 0.4000
# 0.7: 0.3231
# 0.65: 0.1692
# 0.6: 0.1385

# %%
chosen_tpr = 0.75
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pb {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.75: Pb 0.2378: FPR 0.4000

# %%
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)

cm_percentage = cm.astype(float) / cm.sum(axis=1)[:, np.newaxis] * 100

annot_labels = np.empty_like(cm, dtype=object)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        percentage = cm_percentage[i, j]
        annot_labels[i, j] = f'{percentage:.1f}%'

fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm_percentage, annot=annot_labels, fmt='', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr*100}% Efficiency")

ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)
df_cm = pd.DataFrame(cm)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr*100}% Efficiency")

# Add TP, FP, FN, TN labels
ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
# Plot ROC Curve and show AUC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='navy', label=f'ROC curve (AUC = {auc:.4f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--', label='Baseline (AUC = 0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.style.use('default')
plt.ylabel('Signal Efficiency')
plt.xlabel('False Positive Rate (FPR)')
plt.title('Receiver Operating Characteristics (ROC)')
plt.text(0.85, 0.15, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.legend(loc='lower right')
plt.show()

# %%
# Prepare model
model.eval()
data = next(iter(test_loader))
x, edge_index, batch = data.x, data.edge_index, data.batch

G = nx.Graph()
edges = list(zip(edge_index[0].numpy(), edge_index[1].numpy()))
G.add_edges_from(edges)

feature_importances = np.zeros(x.size(1))

for feature_idx in range(x.size(1)):
    x_perturbed = x.clone()
    x_perturbed[:, feature_idx] = 0

    # Predict with original features
    with torch.no_grad():
        orig_pred = model(x, edge_index, batch, None)
        perturbed_pred = model(x_perturbed, edge_index, batch, None)

    # Compute importance - difference in predictions
    importance = torch.mean(torch.abs(orig_pred - perturbed_pred))
    feature_importances[feature_idx] = importance

importance_df = pd.DataFrame({'Feature': feature_cols, 'Importance': feature_importances})
print(importance_df)

plt.figure(figsize=(12, 12))
sns.barplot(x='Importance', y='Feature', data=importance_df, palette='viridis', hue='Feature', dodge=False)
plt.title('Feature Importance', fontsize=15)
plt.text(0.87, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.xlabel('Importance', fontsize=15)
plt.ylabel('Feature', fontsize=15)
plt.show()
# Out:
#                                 Feature    Importance
# 0                      Jet0_Daughters_E  1.582353e-01
# 1                     Jet0_Daughters_pT  1.115470e-02
# 2                     Jet0_Daughters_ID  2.664967e-03
# 3                     Jet0_Daughters_pX  3.179079e-02
# 4                     Jet0_Daughters_pY  1.549370e-02
# 5                     Jet0_Daughters_pZ  1.212406e-01
# 6                    Jet0_Daughters_Eta  1.095040e-04
# 7                    Jet0_Daughters_Phi  6.355532e-05
# 8                      Jet0_Daughters_Q  2.513826e-05
# 9                     Jet0_Daughters_IP  1.722913e-03
# 10                Jet0_Daughters_IPCHI2  3.183000e-01
# 11                 Jet0_Daughters_IPraw  3.182867e-03
# 12                   Jet0_Daughters_NNe  2.605626e-02
# 13                   Jet0_Daughters_NNk  2.248335e-02
# 14                   Jet0_Daughters_NNp  1.991407e-02
# 15                  Jet0_Daughters_NNpi  5.263469e-02
# 16                  Jet0_Daughters_NNmu  5.738578e-02
# 17                  Jet0_Daughters_Chi2  1.877874e-02
# 18                Jet0_Daughters_QoverP  3.011912e-02
# 19                Jet0_Daughters_trackX  1.748622e-02
# 20                Jet0_Daughters_trackY  4.353154e-02
# 21                Jet0_Daughters_trackZ  5.509784e-02
# 22               Jet0_Daughters_trackVX  1.382034e-02
# 23               Jet0_Daughters_trackVY  4.005393e-02
# 24               Jet0_Daughters_trackVZ  9.860745e-02
# 25       Jet0_Daughters_CaloNeutralEcal  4.269820e-02
# 26  Jet0_Daughters_CaloNeutralHcal2Ecal  3.345325e-02
# 27        Jet0_Daughters_CaloNeutralE49  3.066279e-02
# 28        Jet0_Daughters_CaloNeutralPrs  2.510005e-02
# 29                             Jet0_Eta  1.110109e-04
# 30                              Jet0_PT  1.752230e+00
# 31                    Jet0_SVtag_fdrMin  3.451668e-05
# 32                  Jet0_SVtag_ptSvrJet  9.123236e-06
# 33                      Jet0_SVtag_nTrk  4.567765e-05
# 34                   Jet0_SVtag_nTrkJet  3.303494e-05
# 35                  Jet0_SVtag_drSvrJet  4.377216e-07
# 36                   Jet0_SVtag_absQSum  9.641051e-06
# 37                         Jet0_SVtag_m  5.413977e-02
# 38                      Jet0_SVtag_mCor  5.675870e-02
# 39                    Jet0_SVtag_fdChi2  2.069319e-01
# 40                 Jet0_SVtag_ipChi2Sum  2.749807e-02
# 41                       Jet0_SVtag_tau  3.475696e-06
# 42                         Jet0_SVtag_z  3.169402e-04
# 43                        Jet0_SVtag_pt  6.385649e-01

# %%
for index, row in importance_df.iterrows():
    feature = row['Feature'] 
    importance = row['Importance']
    if importance > 0.25:
        print(f'{feature} & {importance:4f}')
# Out:
# Jet0_Daughters_IPCHI2 & 0.318300
# Jet0_PT & 1.752230
# Jet0_SVtag_pt & 0.638565

# %% [markdown]
# # Model Probability Output

# %%
df = validation_df
chosen_threshold = 0.5

def make_predictions():
    # Select a random integer for sampling
    random_integer = np.random.randint(0, len(df))
    sample_jet = df.iloc[random_integer:random_integer+1].copy()

    # Filter columns related to Jet0
    sample_jet = sample_jet.filter(like='Jet0')

    # Define feature columns
    daughter_cols = [col for col in sample_jet.columns if "_Daughters" in col]
    svtag_cols = ['Jet0_SVtag_fdrMin',
    'Jet0_SVtag_ptSvrJet',
    'Jet0_SVtag_nTrk',
    'Jet0_SVtag_nTrkJet',
    'Jet0_SVtag_drSvrJet',
    'Jet0_SVtag_absQSum',
    'Jet0_SVtag_m',
    'Jet0_SVtag_mCor',
    'Jet0_SVtag_fdChi2',
    'Jet0_SVtag_ipChi2Sum',
    'Jet0_SVtag_tau',
    'Jet0_SVtag_z',
    'Jet0_SVtag_pt']
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    for col in jet_cols:
        sample_jet[col] = sample_jet.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)
    for col in daughter_cols:
        sample_jet[col] = sample_jet[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Obtain features of each node within the graph
    features_list = []
    for _, row in sample_jet.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    # Create graph representation with data objects
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch, data.edge_weight)
            probability = torch.sigmoid(output)
            prediction = (probability > chosen_threshold).int()

    print(f'Probability: {probability.item()}')
    if prediction.item() == 1:  
        print(f'Prediction: c-jet')
    if prediction.item() == 0:  
        print(f'Prediction: q-jet')
    return probability.item()

i = 0

for i in range(100):
    make_predictions()
# Out:
# Probability: 0.6120538711547852
# Prediction: c-jet
# Probability: 0.23324474692344666
# Prediction: q-jet
# Probability: 0.303479939699173
# Prediction: q-jet
# Probability: 0.2760891318321228
# Prediction: q-jet
# Probability: 0.15087835490703583
# Prediction: q-jet
# Probability: 0.3613160252571106
# Prediction: q-jet
# Probability: 0.07786542177200317
# Prediction: q-jet
# Probability: 0.4387255609035492
# Prediction: q-jet
# Probability: 0.16905178129673004
# Prediction: q-jet
# Probability: 0.9925526976585388
# Prediction: c-jet
# Probability: 0.21905536949634552
# Prediction: q-jet
# Probability: 0.8465646505355835
# Prediction: c-jet
# Probability: 0.43612709641456604
# Prediction: q-jet
# Probability: 0.2524995505809784
# Prediction: q-jet
# Probability: 0.11804614961147308
# Prediction: q-jet
# Probability: 0.34530457854270935
# Prediction: q-jet
# Probability: 0.2663730978965759
# Prediction: q-jet
# Probability: 0.43825197219848633
# Prediction: q-jet
# Probability: 0.8258453011512756
# Prediction: c-jet
# Probability: 0.8701295852661133
# Prediction: c-jet
# Probability: 0.22976550459861755
# Prediction: q-jet
# Probability: 0.9388821721076965
# Prediction: c-jet
# Probability: 0.172452911734581
# Prediction: q-jet
# Probability: 0.31455686688423157
# Prediction: q-jet
# Probability: 0.20217199623584747
# Prediction: q-jet
# Probability: 0.27427974343299866
# Prediction: q-jet
# Probability: 0.14036250114440918
# Prediction: q-jet
# Probability: 0.2761431336402893
# Prediction: q-jet
# Probability: 0.23590977489948273
# Prediction: q-jet
# Probability: 0.31319406628608704
# Prediction: q-jet
# Probability: 0.9786800146102905
# Prediction: c-jet
# Probability: 0.23596636950969696
# Prediction: q-jet
# Probability: 0.23497101664543152
# Prediction: q-jet
# Probability: 0.8377084732055664
# Prediction: c-jet
# Probability: 0.9920136332511902
# Prediction: c-jet
# Probability: 0.9895057082176208
# Prediction: c-jet
# Probability: 0.9056185483932495
# Prediction: c-jet
# Probability: 0.3003627359867096
# Prediction: q-jet
# Probability: 0.9554063081741333
# Prediction: c-jet
# Probability: 0.9231059551239014
# Prediction: c-jet
# Probability: 0.2726972699165344
# Prediction: q-jet
# Probability: 0.18586419522762299
# Prediction: q-jet
# Probability: 0.8280971050262451
# Prediction: c-jet
# Probability: 0.04418345168232918
# Prediction: q-jet
# Probability: 0.8828547596931458
# Prediction: c-jet
# Probability: 0.4910314381122589
# Prediction: q-jet
# Probability: 0.33814042806625366
# Prediction: q-jet
# Probability: 0.16828562319278717
# Prediction: q-jet
# Probability: 0.1352200210094452
# Prediction: q-jet
# Probability: 0.86170494556427
# Prediction: c-jet
# Probability: 0.2667035758495331
# Prediction: q-jet
# Probability: 0.1418282687664032
# Prediction: q-jet
# Probability: 0.1983225792646408
# Prediction: q-jet
# Probability: 0.9824262857437134
# Prediction: c-jet
# Probability: 0.20188963413238525
# Prediction: q-jet
# Probability: 0.1562584489583969
# Prediction: q-jet
# Probability: 0.16905178129673004
# Prediction: q-jet
# Probability: 0.00851655937731266
# Prediction: q-jet
# Probability: 0.22406083345413208
# Prediction: q-jet
# Probability: 0.18928134441375732
# Prediction: q-jet
# Probability: 0.6855683922767639
# Prediction: c-jet
# Probability: 0.4707678258419037
# Prediction: q-jet
# Probability: 0.2518223226070404
# Prediction: q-jet
# Probability: 0.09306646138429642
# Prediction: q-jet
# Probability: 0.34318071603775024
# Prediction: q-jet
# Probability: 0.11239305883646011
# Prediction: q-jet
# Probability: 0.9814153909683228
# Prediction: c-jet
# Probability: 0.7811761498451233
# Prediction: c-jet
# Probability: 0.29171472787857056
# Prediction: q-jet
# Probability: 0.2160256952047348
# Prediction: q-jet
# Probability: 0.9819707870483398
# Prediction: c-jet
# Probability: 0.11907689273357391
# Prediction: q-jet
# Probability: 0.3837672472000122
# Prediction: q-jet
# Probability: 0.10165106505155563
# Prediction: q-jet
# Probability: 0.2092171013355255
# Prediction: q-jet
# Probability: 0.7468752264976501
# Prediction: c-jet
# Probability: 0.0372503288090229
# Prediction: q-jet
# Probability: 0.2762505114078522
# Prediction: q-jet
# Probability: 0.8258453011512756
# Prediction: c-jet
# Probability: 0.9785665273666382
# Prediction: c-jet
# Probability: 0.22155126929283142
# Prediction: q-jet
# Probability: 0.2956938147544861
# Prediction: q-jet
# Probability: 0.24612784385681152
# Prediction: q-jet
# Probability: 0.2742190957069397
# Prediction: q-jet
# Probability: 0.3121437728404999
# Prediction: q-jet
# Probability: 0.33981335163116455
# Prediction: q-jet
# Probability: 0.9654368162155151
# Prediction: c-jet
# Probability: 0.2461525797843933
# Prediction: q-jet
# Probability: 0.2326163798570633
# Prediction: q-jet
# Probability: 0.2060718536376953
# Prediction: q-jet
# Probability: 0.9895057082176208
# Prediction: c-jet
# Probability: 0.05948469787836075
# Prediction: q-jet
# Probability: 0.1574537456035614
# Prediction: q-jet
# Probability: 0.12922154366970062
# Prediction: q-jet
# Probability: 0.3121437728404999
# Prediction: q-jet
# Probability: 0.09306646138429642
# Prediction: q-jet
# Probability: 0.42542484402656555
# Prediction: q-jet
# Probability: 0.3613160252571106
# Prediction: q-jet
# Probability: 0.12049409747123718
# Prediction: q-jet
# Probability: 0.23596636950969696
# Prediction: q-jet

# %% [markdown]
# # Create Efficiency Plot

# %%
model.load_state_dict(torch.load('bq50_model1.pth'))
model = model.to('cpu')

# %%
# Separate b and q data from testing dataset (preprocessed)
b = test_df[test_df.IsB == 1]
q = test_df[test_df.IsB == 0]

b_data = create_graphs(b, feature_cols)
q_data = create_graphs(q, feature_cols)

b_prob = []
q_prob = []

def get_probabilities(data_list):
    prob_list = []
    model.eval()
    with torch.no_grad():
        for data in data_list:
            out = model(data.x, data.edge_index, data.batch, data.edge_weight)
            prob = torch.sigmoid(out).numpy().flatten()
            prob_list.append(prob)
    return np.concatenate(prob_list)

# Compute probabilities for b and q data
b_prob = get_probabilities(b_data)
q_prob = get_probabilities(q_data)

# %%
def plot_probability_distribution(b_prob, q_prob, target_efficiencies):

    # Sort b-jet probabilities in descending order for cutoff calculations
    sorted_b_prob = np.sort(b_prob)[::-1]
    
    # Calculate cutoffs for each efficiency level
    cutoffs = {}
    for efficiency in target_efficiencies:
        cutoff_index = int(len(sorted_b_prob) * efficiency)
        cutoffs[efficiency] = sorted_b_prob[cutoff_index - 1] if cutoff_index > 0 else sorted_b_prob[0]
    
    # Plot histograms for b-jet and q-jet probabilities
    plt.figure(figsize=(10, 6))
    b_values, b_bins, _ = plt.hist(b_prob, bins=100, label='b-jets', color='darkred', histtype='step')
    q_values, q_bins, _ = plt.hist(q_prob, bins=100, label='q-jets', color='mediumblue', histtype='step')

    max_y = max(max(b_values), max(q_values))
    
    # Mark cutoffs for selected efficiencies
    for i, (efficiency, cutoff) in enumerate(cutoffs.items()):
        plt.vlines(x=cutoff, ymin=0, ymax=max_y * 0.1, color='grey', linestyle='--', linewidth=1)
        plt.text(cutoff, max_y*0.12, f'{int(efficiency * 100)}%', ha='center', va='bottom', rotation=90)

    plt.xlabel("P$_b$")
    plt.ylabel("Number of Jets")
    plt.text(0.9, max_y * 0.8, "LHCb Simulation", fontsize=14, verticalalignment='bottom', horizontalalignment='right')
    plt.title("Probability Distribution")
    plt.yscale('log')
    plt.legend(loc='best')
    plt.show()

target_efficiencies = [0.6, 0.7, 0.8]
plot_probability_distribution(b_prob, q_prob, target_efficiencies)

# %%
chosen_tpr = 0.75
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pb {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.75: Pb 0.2378: FPR 0.4000

# %%
b = test_df[test_df.IsB == 1]
b.loc[:, 'Jet0_PT'] = b['Jet0_PT'].apply(lambda x: x[0] if isinstance(x, list) else x)

pt23_df = b[(b['Jet0_PT'].between(20000, 30000))].reset_index(drop=True)
pt34_df = b[(b['Jet0_PT'].between(30000, 40000))].reset_index(drop=True)
pt45_df = b[(b['Jet0_PT'].between(40000, 50000))].reset_index(drop=True)
pt50_df = b[(b['Jet0_PT'].between(50000, 100000))].reset_index(drop=True)

# %%
def make_predictions(df):
    daughter_cols = [col for col in df.columns if "_Daughters" in col]
    svtag_cols = [
        'Jet0_SVtag_fdrMin',
        'Jet0_SVtag_ptSvrJet',
        'Jet0_SVtag_nTrk',
        'Jet0_SVtag_nTrkJet',
        'Jet0_SVtag_drSvrJet',
        'Jet0_SVtag_absQSum',
        'Jet0_SVtag_m',
        'Jet0_SVtag_mCor',
        'Jet0_SVtag_fdChi2',
        'Jet0_SVtag_ipChi2Sum',
        'Jet0_SVtag_tau',
        'Jet0_SVtag_z',
        'Jet0_SVtag_pt'
    ]
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Get features of each node within the graph
    features_list = []
    for _, row in df.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    num_b = 0
    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch, data.edge_weight)
            probability = torch.sigmoid(output)
            prediction = (probability > chosen_threshold).int()

            if prediction.item() == 1:  
                num_b += 1

    return num_b

# %%
num_c23 = make_predictions(pt23_df)
num_c34 = make_predictions(pt34_df)
num_c45 = make_predictions(pt45_df)
num_c50 = make_predictions(pt50_df)

efficiency23 = num_c23 / len(pt23_df)
efficiency34 = num_c34 / len(pt34_df)
efficiency45 = num_c45 / len(pt45_df)
efficiency50 = num_c50 / len(pt50_df)

print(f'Efficiency for pT 20-30 GeV: {efficiency23:.4f}')
print(f'Efficiency for pT 30-40 GeV: {efficiency34:.4f}')
print(f'Efficiency for pT 40-50 GeV: {efficiency45:.4f}')
print(f'Efficiency for pT 50-100 GeV: {efficiency50:.4f}')
# Out:
# Efficiency for pT 20-30 GeV: 0.7917
# Efficiency for pT 30-40 GeV: 1.0000
# Efficiency for pT 40-50 GeV: 0.8333
# Efficiency for pT 50-100 GeV: 0.6071

# %%
def plot_efficiency_histogram(efficiencies, pt_bins):
    plt.figure(figsize=(10, 6))

    # Calculate bin centers and widths
    bin_centers = (pt_bins[:-1] + pt_bins[1:]) / 2
    bar_width = np.diff(pt_bins)  # Width of the bins

    # Create the histogram by plotting only the tops of the bins
    for i in range(len(efficiencies)):
        plt.plot([pt_bins[i], pt_bins[i+1]], [efficiencies[i], efficiencies[i]], color='blue', linewidth=2)
    plt.xticks(np.arange(20000, 101000, 10000))
    plt.xlabel('pT (GeV)')
    plt.ylabel('Efficiency')
    plt.text(0.85, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
    plt.title('Efficiency for b-jets at 75% TPR')
    plt.ylim(0, 1.1)
    plt.xlim(20000, 100000)
    plt.show()

# Custom bin ranges (with unequal bins for the upper range)
pt_bins = np.array([20000, 30000, 40000, 50000, 100000])
efficiencies = [efficiency23, efficiency34, efficiency45, efficiency50]

plot_efficiency_histogram(efficiencies, pt_bins)

# %%
# Visualize some graphs
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, data in enumerate(train_loader.dataset[:6]):
    G = nx.Graph()
    G.add_edges_from(data.edge_index.t().tolist())

    nx.draw(G, ax=axes[i], node_color='navy', node_size=100)
    
    axes[i].set_title(f"Graph {i+1}: {data.num_nodes} nodes, {data.edge_index.size(1)} edges")

plt.tight_layout()
plt.show()
