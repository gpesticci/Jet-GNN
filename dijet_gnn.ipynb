# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn import Linear
from torch import Tensor
from torch_geometric.nn import GCNConv
from torch_geometric.data   import Data
from torch_geometric.loader import DataLoader
from torch_geometric.data import InMemoryDataset

# %%
# signal data
df = pd.read_csv('Dijet_bb_pt10_15_dw.csv')

# background data
df2 = pd.read_csv('Dijet_qq_pt10_15_dw.csv')

# %%
# view column names
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Jet0_ENDVERTEX_X',
#  'Jet0_ENDVERTEX_Y',
#  'Jet0_ENDVERTEX_Z',
#  'Jet0_ENDVERTEX_XERR',
#  'Jet0_ENDVERTEX_YERR',
#  'Jet0_ENDVERTEX_ZERR',
#  'Jet0_ENDVERTEX_CHI2',
#  'Jet0_ENDVERTEX_NDOF',
#  'Jet0_OWNPV_X',
#  'Jet0_OWNPV_Y',
#  'Jet0_OWNPV_Z',
#  'Jet0_OWNPV_XERR',
#  'Jet0_OWNPV_YERR',
#  'Jet0_OWNPV_ZERR',
#  'Jet0_OWNPV_CHI2',
#  'Jet0_OWNPV_NDOF',
#  'Jet0_IP_OWNPV',
#  'Jet0_IPCHI2_OWNPV',
#  'Jet0_FD_OWNPV',
#  'Jet0_FDCHI2_OWNPV',
#  'Jet0_DIRA_OWNPV',
#  'Jet0_ORIVX_X',
#  'Jet0_ORIVX_Y',
#  'Jet0_ORIVX_Z',
#  'Jet0_ORIVX_XERR',
#  'Jet0_ORIVX_YERR',
#  'Jet0_ORIVX_ZERR',
#  'Jet0_ORIVX_CHI2',
#  'Jet0_ORIVX_NDOF',
#  'Jet0_FD_ORIVX',
#  'Jet0_FDCHI2_ORIVX',
#  'Jet0_DIRA_ORIVX',
#  'Jet0_P',
#  'Jet0_PT',
#  'Jet0_PE',
#  'Jet0_PX',
#  'Jet0_PY',
#  'Jet0_PZ',
#  'Jet0_MM',
#  'Jet0_MMERR',
#  'Jet0_M',
#  'Jet0_ID',
#  'Jet0_Eta',
#  'Jet0_Phi',
#  'Jet0_MLoKi',
#  'Jet0_MMLoKi',
#  'Jet0_NTrk',
#  'Jet0_N90',
#  'Jet0_MTF',
#  'Jet0_NSatCells',
#  'Jet0_NHasPVInfo',
#  'Jet0_JEC_Cor',
#  'Jet0_JEC_PV',
#  'Jet0_JEC_Error',
#  'Jet0_w',
#  'Jet0_CPF',
#  'Jet0_JetWidth',
#  'Jet0_NSatECAL',
#  'Jet0_NSatHCAL',
#  'Jet0_NIPChi2Inf4',
#  'Jet0_EfCharged',
#  'Jet0_EfChargedHadron',
#  'Jet0_EfMuon',
#  'Jet0_EfElectron',
#  'Jet0_EfNeutral',
#  'Jet0_EfPhoton',
#  'Jet0_EfPi0',
#  'Jet0_EfMPi0',
#  'Jet0_EfRPi0',
#  'Jet0_EfNHad',
#  'Jet0_EfNReco',
#  'Jet0_EfCompo',
#  'Jet0_EfV0',
#  'Jet0_EfD',
#  'Jet0_EfB',
#  'Jet0_EfBadParticle',
#  'Jet0_EfCharged0Momentum',
#  'Jet0_EfChargedInfMomentum',
#  'Jet0_EfBadPhotonMatchingT',
#  'Jet0_EfBadPhoton',
#  'Jet0_EfIsolatedPhoton',
#  'Jet0_NLongTrk',
#  'Jet0_EfLongTrk',
#  'Jet0_NDownTrk',
#  'Jet0_EfDownTrk',
#  'Jet0_NUpTrk',
#  'Jet0_EfUpTrk',
#  'Jet0_PU_NPVs',
#  'Jet0_PU_Cone06_SumPTLongTrk',
#  'Jet0_PU_Cone06_SumELongTrk',
#  'Jet0_PU_Cone06_NLongTrk',
#  'Jet0_PU_Cone06_NUpVeloTrk',
#  'Jet0_PU_Cone10_SumPTLongTrk',
#  'Jet0_PU_Cone10_SumELongTrk',
#  'Jet0_PU_Cone10_NLongTrk',
#  'Jet0_PU_Cone10_NUpVeloTrk',
#  'Jet0_PU_Cone15_SumPTLongTrk',
#  'Jet0_PU_Cone15_SumELongTrk',
#  'Jet0_PU_Cone15_NLongTrk',
#  'Jet0_PU_Cone15_NUpVeloTrk',
#  'Jet0_ParticleMultiplicity',
#  'Jet0_foundMuon',
#  'Jet0_nmuons',
#  'Jet0_muon_PE',
#  'Jet0_muon_PX',
#  'Jet0_muon_PY',
#  'Jet0_muon_PZ',
#  'Jet0_muon_PT',
#  'Jet0_muon_DLLmu',
#  'Jet0_muon_ProbNNMu',
#  'Jet0_muon_IP',
#  'Jet0_muon_IPchi2',
#  'Jet0_muon_q',
#  'Jet0_nDaughters',
#  'Jet0_Daughters_E',
#  'Jet0_Daughters_pT',
#  'Jet0_Daughters_ID',
#  'Jet0_Daughters_pX',
#  'Jet0_Daughters_pY',
#  'Jet0_Daughters_pZ',
#  'Jet0_Daughters_Eta',
#  'Jet0_Daughters_Phi',
#  'Jet0_Daughters_Q',
#  'Jet0_Daughters_IP',
#  'Jet0_Daughters_IPCHI2',
#  'Jet0_Daughters_IPraw',
#  'Jet0_Daughters_NNe',
#  'Jet0_Daughters_NNk',
#  'Jet0_Daughters_NNp',
#  'Jet0_Daughters_NNpi',
#  'Jet0_Daughters_NNmu',
#  'Jet0_Daughters_Chi2',
#  'Jet0_Daughters_QoverP',
#  'Jet0_Daughters_trackX',
#  'Jet0_Daughters_trackY',
#  'Jet0_Daughters_trackZ',
#  'Jet0_Daughters_trackVX',
#  'Jet0_Daughters_trackVY',
#  'Jet0_Daughters_trackVZ',
#  'Jet0_Daughters_CaloNeutralEcal',
#  'Jet0_Daughters_CaloNeutralHcal2Ecal',
#  'Jet0_Daughters_CaloNeutralE49',
#  'Jet0_Daughters_CaloNeutralPrs',
#  'Jet0_MC_Match',
#  'Jet0_MC_Jet_PT',
#  'Jet0_MC_Jet_PX',
#  'Jet0_MC_Jet_PY',
#  'Jet0_MC_Jet_PZ',
#  'Jet0_MC_Jet_E',
#  'Jet0_MC_Jet_EfD',
#  'Jet0_MC_Jet_EfB',
#  'Jet0_MC_Jet_EfW',
#  'Jet0_MC_Jet_EfZ',
#  'Jet0_MC_Jet_EfV0',
#  'Jet0_MC_Jet_cpf',
#  'Jet0_L0Global_Dec',
#  'Jet0_L0Global_TIS',
#  'Jet0_L0Global_TOS',
#  'Jet0_Hlt1Global_Dec',
#  'Jet0_Hlt1Global_TIS',
#  'Jet0_Hlt1Global_TOS',
#  'Jet0_Hlt1Phys_Dec',
#  'Jet0_Hlt1Phys_TIS',
#  'Jet0_Hlt1Phys_TOS',
#  'Jet0_Hlt2Global_Dec',
#  'Jet0_Hlt2Global_TIS',
#  'Jet0_Hlt2Global_TOS',
#  'Jet0_Hlt2Phys_Dec',
#  'Jet0_Hlt2Phys_TIS',
#  'Jet0_Hlt2Phys_TOS',
#  'Jet1_ENDVERTEX_X',
#  'Jet1_ENDVERTEX_Y',
#  'Jet1_ENDVERTEX_Z',
#  'Jet1_ENDVERTEX_XERR',
#  'Jet1_ENDVERTEX_YERR',
#  'Jet1_ENDVERTEX_ZERR',
#  'Jet1_ENDVERTEX_CHI2',
#  'Jet1_ENDVERTEX_NDOF',
#  'Jet1_OWNPV_X',
#  'Jet1_OWNPV_Y',
#  'Jet1_OWNPV_Z',
#  'Jet1_OWNPV_XERR',
#  'Jet1_OWNPV_YERR',
#  'Jet1_OWNPV_ZERR',
#  'Jet1_OWNPV_CHI2',
#  'Jet1_OWNPV_NDOF',
#  'Jet1_IP_OWNPV',
#  'Jet1_IPCHI2_OWNPV',
#  'Jet1_FD_OWNPV',
#  'Jet1_FDCHI2_OWNPV',
#  'Jet1_DIRA_OWNPV',
#  'Jet1_ORIVX_X',
#  'Jet1_ORIVX_Y',
#  'Jet1_ORIVX_Z',
#  'Jet1_ORIVX_XERR',
#  'Jet1_ORIVX_YERR',
#  'Jet1_ORIVX_ZERR',
#  'Jet1_ORIVX_CHI2',
#  'Jet1_ORIVX_NDOF',
#  'Jet1_FD_ORIVX',
#  'Jet1_FDCHI2_ORIVX',
#  'Jet1_DIRA_ORIVX',
#  'Jet1_P',
#  'Jet1_PT',
#  'Jet1_PE',
#  'Jet1_PX',
#  'Jet1_PY',
#  'Jet1_PZ',
#  'Jet1_MM',
#  'Jet1_MMERR',
#  'Jet1_M',
#  'Jet1_ID',
#  'Jet1_Eta',
#  'Jet1_Phi',
#  'Jet1_MLoKi',
#  'Jet1_MMLoKi',
#  'Jet1_NTrk',
#  'Jet1_N90',
#  'Jet1_MTF',
#  'Jet1_NSatCells',
#  'Jet1_NHasPVInfo',
#  'Jet1_JEC_Cor',
#  'Jet1_JEC_PV',
#  'Jet1_JEC_Error',
#  'Jet1_w',
#  'Jet1_CPF',
#  'Jet1_JetWidth',
#  'Jet1_NSatECAL',
#  'Jet1_NSatHCAL',
#  'Jet1_NIPChi2Inf4',
#  'Jet1_EfCharged',
#  'Jet1_EfChargedHadron',
#  'Jet1_EfMuon',
#  'Jet1_EfElectron',
#  'Jet1_EfNeutral',
#  'Jet1_EfPhoton',
#  'Jet1_EfPi0',
#  'Jet1_EfMPi0',
#  'Jet1_EfRPi0',
#  'Jet1_EfNHad',
#  'Jet1_EfNReco',
#  'Jet1_EfCompo',
#  'Jet1_EfV0',
#  'Jet1_EfD',
#  'Jet1_EfB',
#  'Jet1_EfBadParticle',
#  'Jet1_EfCharged0Momentum',
#  'Jet1_EfChargedInfMomentum',
#  'Jet1_EfBadPhotonMatchingT',
#  'Jet1_EfBadPhoton',
#  'Jet1_EfIsolatedPhoton',
#  'Jet1_NLongTrk',
#  'Jet1_EfLongTrk',
#  'Jet1_NDownTrk',
#  'Jet1_EfDownTrk',
#  'Jet1_NUpTrk',
#  'Jet1_EfUpTrk',
#  'Jet1_PU_NPVs',
#  'Jet1_PU_Cone06_SumPTLongTrk',
#  'Jet1_PU_Cone06_SumELongTrk',
#  'Jet1_PU_Cone06_NLongTrk',
#  'Jet1_PU_Cone06_NUpVeloTrk',
#  'Jet1_PU_Cone10_SumPTLongTrk',
#  'Jet1_PU_Cone10_SumELongTrk',
#  'Jet1_PU_Cone10_NLongTrk',
#  'Jet1_PU_Cone10_NUpVeloTrk',
#  'Jet1_PU_Cone15_SumPTLongTrk',
#  'Jet1_PU_Cone15_SumELongTrk',
#  'Jet1_PU_Cone15_NLongTrk',
#  'Jet1_PU_Cone15_NUpVeloTrk',
#  'Jet1_ParticleMultiplicity',
#  'Jet1_foundMuon',
#  'Jet1_nmuons',
#  'Jet1_muon_PE',
#  'Jet1_muon_PX',
#  'Jet1_muon_PY',
#  'Jet1_muon_PZ',
#  'Jet1_muon_PT',
#  'Jet1_muon_DLLmu',
#  'Jet1_muon_ProbNNMu',
#  'Jet1_muon_IP',
#  'Jet1_muon_IPchi2',
#  'Jet1_muon_q',
#  'Jet1_nDaughters',
#  'Jet1_Daughters_E',
#  'Jet1_Daughters_pT',
#  'Jet1_Daughters_ID',
#  'Jet1_Daughters_pX',
#  'Jet1_Daughters_pY',
#  'Jet1_Daughters_pZ',
#  'Jet1_Daughters_Eta',
#  'Jet1_Daughters_Phi',
#  'Jet1_Daughters_Q',
#  'Jet1_Daughters_IP',
#  'Jet1_Daughters_IPCHI2',
#  'Jet1_Daughters_IPraw',
#  'Jet1_Daughters_NNe',
#  'Jet1_Daughters_NNk',
#  'Jet1_Daughters_NNp',
#  'Jet1_Daughters_NNpi',
#  'Jet1_Daughters_NNmu',
#  'Jet1_Daughters_Chi2',
#  'Jet1_Daughters_QoverP',
#  'Jet1_Daughters_trackX',
#  'Jet1_Daughters_trackY',
#  'Jet1_Daughters_trackZ',
#  'Jet1_Daughters_trackVX',
#  'Jet1_Daughters_trackVY',
#  'Jet1_Daughters_trackVZ',
#  'Jet1_Daughters_CaloNeutralEcal',
#  'Jet1_Daughters_CaloNeutralHcal2Ecal',
#  'Jet1_Daughters_CaloNeutralE49',
#  'Jet1_Daughters_CaloNeutralPrs',
#  'Jet1_MC_Match',
#  'Jet1_MC_Jet_PT',
#  'Jet1_MC_Jet_PX',
#  'Jet1_MC_Jet_PY',
#  'Jet1_MC_Jet_PZ',
#  'Jet1_MC_Jet_E',
#  'Jet1_MC_Jet_EfD',
#  'Jet1_MC_Jet_EfB',
#  'Jet1_MC_Jet_EfW',
#  'Jet1_MC_Jet_EfZ',
#  'Jet1_MC_Jet_EfV0',
#  'Jet1_MC_Jet_cpf',
#  'Jet1_L0Global_Dec',
#  'Jet1_L0Global_TIS',
#  'Jet1_L0Global_TOS',
#  'Jet1_Hlt1Global_Dec',
#  'Jet1_Hlt1Global_TIS',
#  'Jet1_Hlt1Global_TOS',
#  'Jet1_Hlt1Phys_Dec',
#  'Jet1_Hlt1Phys_TIS',
#  'Jet1_Hlt1Phys_TOS',
#  'Jet1_Hlt2Global_Dec',
#  'Jet1_Hlt2Global_TIS',
#  'Jet1_Hlt2Global_TOS',
#  'Jet1_Hlt2Phys_Dec',
#  'Jet1_Hlt2Phys_TIS',
#  'Jet1_Hlt2Phys_TOS',
#  'nCandidate',
#  'totCandidates',
#  'EventInSequence',
#  'runNumber',
#  'eventNumber',
#  'BCID',
#  'BCType',
#  'OdinTCK',
#  'L0DUTCK',
#  'HLT1TCK',
#  'HLT2TCK',
#  'GpsTime',
#  'Polarity',
#  'nPV',
#  'PVX',
#  'PVY',
#  'PVZ',
#  'PVXERR',
#  'PVYERR',
#  'PVZERR',
#  'PVCHI2',
#  'PVNDOF',
#  'PVNTRACKS',
#  'nPVs',
#  'nTracks',
#  'nLongTracks',
#  'nDownstreamTracks',
#  'nUpstreamTracks',
#  'nVeloTracks',
#  'nTTracks',
#  'nBackTracks',
#  'nRich1Hits',
#  'nRich2Hits',
#  'nVeloClusters',
#  'nITClusters',
#  'nTTClusters',
#  'nOTClusters',
#  'nSPDHits',
#  'nMuonCoordsS0',
#  'nMuonCoordsS1',
#  'nMuonCoordsS2',
#  'nMuonCoordsS3',
#  'nMuonCoordsS4',
#  'nMuonTracks']

# %%
# separate signal and background of Jet 0 and 1
jet00 = df[df.columns[df.columns.str.contains("Jet0")]] # Jet0 sig
jet01 = df2[df2.columns[df2.columns.str.contains("Jet0")]] # Jet0 back

jet10 = df[df.columns[df.columns.str.contains("Jet1")]] # Jet 1 sig
jet11 = df2[df2.columns[df2.columns.str.contains("Jet1")]] # Jet 1 back

# %%
train_data = pd.concat([jet00, jet01]) # combine Jet 0 sig/ back data
test_data = pd.concat([jet10, jet11]) # combine Jet 1 sig/ back data

# %%
# define nodes & convert to numpy
x = [len(train_data), 0] # x = [nodes, features]
edge_index = [2, len(train_data.columns)] # edge_index = [2, edges]

# %%
loader = DataLoader(train_data, batch_size=32, shuffle=True) # must load to iterate later

# %%
# GNN Model with 2 conv layers, relu activation fxns, and linear layer
# input_size = number of nodes
# ReLu (rectified linear layer) activation fxn

class GNN_Model(nn.Module):
    def __init__(self, input_size, hidden_layers, conv):
        super().__init__()
        self.conv1 = conv(input_size, hidden_layers)
        self.conv2 = conv(input_size, hidden_layers)
        self.lin = Linear(hidden_layers, input_size)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        # linear layers maps input nodes to output
        x = self.lin(x)
    
        return F.relu(self.conv2(x))

input_size = 32
hidden_layers = 64
model = GNN_Model(input_size, hidden_layers, GCNConv)
print(model)
# Out:
# GNN_Model(
#   (conv1): GCNConv(32, 64)
#   (conv2): GCNConv(32, 64)
#   (lin): Linear(in_features=64, out_features=32, bias=True)
# )

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
epochs = 1

def train():    
    model.train()

    for data in range (len(train_data)): # iterate in batches across dataset
        total_loss = 0
        optimizer.zero_grad()
        output = model(data.x, data.edge_index)
        loss = criterion(output, data.y) # compute loss
        loss.backward() # derive the gradients
        optimizer.step() # udpate parameters from gradients
        total_loss += loss.item()
        
        avg_loss = total_loss / len(loader.data)
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {avg_loss:.4f}')

# %%
for epoch in range(epochs):
    train()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 for epoch in range(epochs):
# ----> 2     train()
#
# Cell In[12], line 11, in train()
#       9 total_loss = 0
#      10 optimizer.zero_grad()
# ---> 11 output = model(data.x, data.edge_index)
#      12 loss = criterion(output, data.y) # compute loss
#      13 loss.backward() # derive the gradients
#
# AttributeError: 'int' object has no attribute 'x'
