# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn import Linear, Dropout, LayerNorm
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import SAGEConv, global_add_pool
from torch.nn.utils import clip_grad_norm_
from torch.optim.lr_scheduler import ReduceLROnPlateau

import networkx as nx

from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
import seaborn as sns
from statistics import mean
import uproot

# %%
torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
path_to_tree = "DecayTreeTuple/tuple"

def rename_columns(df):
    new_columns = {}
    for col in df.columns:
        if "_BDTTag_" in col:
            new_columns[col] = col.replace("_BDTTag_", "_SVtag_")
    df.rename(columns=new_columns, inplace=True)

def extract_float(awk_array):
    return awk_array[0] if len(awk_array) > 0 else None

# %%
# Read the ROOT file
tree = uproot.open("Dijet_bb_pt20_50_dw.root" + ":" + path_to_tree)
bb_df = tree.arrays(tree.keys(), library="pd")#, entry_start=0, entry_stop=1000)

# Clean column names and remove unwanted columns
bb_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in bb_df.columns]
rename_columns(bb_df)
columns_to_remove = [col for col in bb_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
bb_df.drop(columns=columns_to_remove, inplace=True)
for col in bb_df.columns:
    if "SVtag" in col:
        bb_df[col] = bb_df[col].apply(extract_float)
tree.close()

# Read the ROOT file
tree = uproot.open("Dijet_cc_pt20_50_dw.root" + ":" + path_to_tree)
cc_df = tree.arrays(tree.keys(), library="pd")#, entry_start=0, entry_stop=1000)

# Clean column names and remove unwanted columns
cc_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in cc_df.columns]
rename_columns(cc_df)
columns_to_remove = [col for col in cc_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
cc_df.drop(columns=columns_to_remove, inplace=True)
for col in cc_df.columns:
    if "SVtag" in col:
        cc_df[col] = cc_df[col].apply(extract_float)
tree.close()
# Out:
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# ...
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]

# %%
print(f'There are {len(cc_df)} c-jet events (signal)')
print(f'There are {len(bb_df)} b-jet events (background)')
# Out:
# There are 1694797 c-jet events (signal)
# There are 1824752 b-jet events (background)

# %%
# Read from csv and assign truth labels
sig_df = cc_df.assign(IsC=1)
bkg_df = bb_df.assign(IsC=0)

# Filter columns to include only leading jet data and truth labels
sig_df = sig_df[sig_df.columns[sig_df.columns.str.contains("Jet0|IsC")]]
bkg_df = bkg_df[bkg_df.columns[bkg_df.columns.str.contains("Jet0|IsC")]]

# Apply cuts and truth matching
sig_df = sig_df[(sig_df['Jet0_MC_Match'] == 1) &
                (sig_df['Jet0_MC_Jet_EfD'] > 0.6) &
                (sig_df['Jet0_PT'] > 20000) &
                (sig_df['Jet0_Eta'].between(2.2, 4.4))]

bkg_df = bkg_df[(bkg_df['Jet0_MC_Match'] == 1) &
                (bkg_df['Jet0_MC_Jet_EfB'] > 0.6) &
                (bkg_df['Jet0_PT'] > 20000) &
                (bkg_df['Jet0_Eta'].between(2.2, 4.4))]

# Combine signal and background
combined_df = pd.concat([sig_df, bkg_df]).reset_index(drop=True)

# %%
print(f"Efficiency of signal truth matching is: {len(sig_df)/len(cc_df):.4f}")
print(f"Efficiency of background truth matching is: {len(bkg_df)/len(bb_df):.4f}")
print('')
print(f"Total events after truth matching: {len(combined_df)}")
print(f"Number of c-jets after truth matching: {len(sig_df)}")
# Out:
# Efficiency of signal truth matching is: 0.2176
# Efficiency of background truth matching is: 0.3450
#
# Total events after truth matching: 998420
# Number of c-jets after truth matching: 368832

# %%
# Define feature columns including jet-level and daughter-level features
daughter_cols = [col for col in sig_df.columns if "_Daughters" in col]
svtag_cols = ['Jet0_SVtag_fdrMin',
 'Jet0_SVtag_ptSvrJet',
 'Jet0_SVtag_nTrk',
 'Jet0_SVtag_nTrkJet',
 'Jet0_SVtag_drSvrJet',
 'Jet0_SVtag_absQSum',
 'Jet0_SVtag_m',
 'Jet0_SVtag_mCor',
 'Jet0_SVtag_fdChi2',
 'Jet0_SVtag_ipChi2Sum',
 'Jet0_SVtag_tau',
 'Jet0_SVtag_z',
 'Jet0_SVtag_pt']
jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
feature_cols = daughter_cols + jet_cols

# Prepare features by converting daughter information to lists and duplicating jet-level features
def prepare_features(df, jet_cols, daughter_cols):
    # Duplicate data to lists matching the number of daughters/nodes per jet/row
    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)

    # Convert string values into list of floats
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)
    return df

df = prepare_features(combined_df, jet_cols, daughter_cols)

# %%
# Split data into training, validation, and test sets
sig_df = df[df['IsC'] == 1].sample(frac=1, random_state=42).reset_index(drop=True)
bkg_df = df[df['IsC'] == 0].sample(frac=1, random_state=42).reset_index(drop=True)

# Calculate dataset sizes from number of c-jets
half_train_size = int((sum(combined_df.IsC)*0.8)/2)
half_test_size = int((sum(combined_df.IsC)*0.2)/2)

# Split into training, testing, and validation data
train_df = pd.concat([sig_df.head(half_train_size), bkg_df.head(half_train_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of training data is: {len(train_df)}')

test_df = pd.concat([sig_df.tail(half_test_size), bkg_df.tail(half_test_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of testing data is: {len(test_df)}')

validation_df = pd.concat([sig_df.iloc[half_train_size:-half_test_size], bkg_df.iloc[half_train_size:-half_test_size]]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of validation data is: {len(validation_df)}')
# Out:
# Length of training data is: 295064
# Length of testing data is: 73766
# Length of validation data is: 629590

# %%
print('Ratio of c to b in datasets:')
print(f'    Training data: {sum(train_df.IsC)/len(train_df)}')
print(f'    Testing data: {sum(test_df.IsC)/len(test_df)}')
print(f'    Validation data: {sum(validation_df.IsC)/len(validation_df)}')
# Out:
# Ratio of c to b in datasets:
#     Training data: 0.5
#     Testing data: 0.5
#     Validation data: 0.29291602471449674

# %%
# Create graphs for training and testing
def create_graphs(df, feature_cols):

    features_list = []
    
    for _, row in df.iterrows():
        num_nodes = row['Jet0_nDaughters']
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    data_objects = []
    for idx, features in enumerate(features_list):

        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        # Create fully connected graph
        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        y = torch.tensor([df['IsC'].iloc[idx]], dtype=torch.float)
        
        data = Data(x=x, edge_index=edge_index, y=y, num_nodes=num_nodes)
        data_objects.append(data)

    return data_objects

# Create graphs for training and testing
train_data = create_graphs(train_df, feature_cols)
test_data = create_graphs(test_df, feature_cols)

# Load data in batches
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %%
class GNN(torch.nn.Module):
    def __init__(self):
        super(GNN, self).__init__()
        hidden_channels = 64
        self.conv1 = SAGEConv(len(feature_cols), hidden_channels)
        self.ln1 = LayerNorm(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.ln2 = LayerNorm(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.ln3 = LayerNorm(hidden_channels)
        self.conv4 = SAGEConv(hidden_channels, hidden_channels)
        self.ln4 = LayerNorm(hidden_channels)
        self.lin = Linear(hidden_channels, 1)
        self.dropout = Dropout(0.3)

    def forward(self, x, edge_index, batch):        
        x = self.conv1(x, edge_index)
        x = self.ln1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv2(x, edge_index)
        x = self.ln2(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv3(x, edge_index)
        x = self.ln3(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv4(x, edge_index)
        x = self.ln4(x)
        x = F.relu(x)

        x = global_add_pool(x, batch)
        x = self.lin(x)
        return x.squeeze(1)
    
model = GNN()
model = model.to(device)

# %%
# Define optimizer and loss function
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = nn.BCEWithLogitsLoss()
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5) # reduce lr by 0.5 every 5 epochs


# Training loop
def train():
    model.train()
    total_loss = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y.float())
        clip_grad_norm_(model.parameters(), max_norm=0.5)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    return avg_loss

# Testing function
def test(loader):
    model.eval()
    total_correct = 0
    total_samples = 0
    total_loss = 0
    
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y.float())
            pred = (out > 0).float()
            correct = (pred.squeeze() == data.y.float()).sum().item()
            total_correct += correct
            total_samples += len(data.y)
            total_loss += loss.item() * data.num_graphs

        avg_loss = total_loss / len(loader.dataset)
        acc = total_correct / total_samples
    return avg_loss, acc

# Training parameters
num_epochs = 200

# Initialize lists for storing loss and accuracy values
train_loss_values = []
train_acc_values = []
test_loss_values = []
test_acc_values = []

# Training loop
for epoch in range(num_epochs):

    train_loss = train()
    train_loss_values.append(train_loss)

    train_acc = test(train_loader)[1]
    train_acc_values.append(train_acc)

    test_loss, test_acc = test(test_loader)
    test_loss_values.append(test_loss)
    test_acc_values.append(test_acc)

    scheduler.step(test_loss)

    print(f'Epoch: {epoch+1:03d}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')

    # Save the model and results every 50 epochs
    if (epoch + 1) % 50 == 0:
        # Overwrite the existing model file
        torch.save(model.state_dict(), 'full_cb_model1.pth')
        print('Model saved as full_cb_model1.pth.')

        # Save the loss and accuracy values to a CSV file, overwriting the existing file
        results_df = pd.DataFrame({
            'Epoch': list(range(1, epoch + 2)),
            'Train Loss': train_loss_values,
            'Test Loss': test_loss_values,
            'Train Accuracy': train_acc_values,
            'Test Accuracy': test_acc_values
        })
        results_df.to_csv('full_cb_training_results1.csv', index=False)
        print('Training results saved as full_cb_training_results1.csv.')

torch.save(model.state_dict(), 'full_cb_model1.pth')
print('Model saved as full_cb_model1.pth. Training complete.')

results_df = pd.DataFrame({
    'Epoch': list(range(1, num_epochs+1)),
    'Train Loss': train_loss_values,
    'Test Loss': test_loss_values,
    'Train Accuracy': train_acc_values,
    'Test Accuracy': test_acc_values
})

# Save the loss and accuracy values to a CSV file
results_df.to_csv('full_cb_training_results1.csv', index=False)
print('Training results saved as full_cb_training_results1.csv. Training complete.')
# Out:
# Epoch: 001, Train Loss: 0.5770, Test Loss: 0.5107, Train Acc: 0.7458, Test Acc: 0.7447
# Epoch: 002, Train Loss: 0.5089, Test Loss: 0.4908, Train Acc: 0.7567, Test Acc: 0.7552
# Epoch: 003, Train Loss: 0.4928, Test Loss: 0.4757, Train Acc: 0.7658, Test Acc: 0.7638
# Epoch: 004, Train Loss: 0.4846, Test Loss: 0.4695, Train Acc: 0.7688, Test Acc: 0.7671
# Epoch: 005, Train Loss: 0.4792, Test Loss: 0.4659, Train Acc: 0.7705, Test Acc: 0.7691
# Epoch: 006, Train Loss: 0.4746, Test Loss: 0.4673, Train Acc: 0.7706, Test Acc: 0.7686
# Epoch: 007, Train Loss: 0.4724, Test Loss: 0.4674, Train Acc: 0.7690, Test Acc: 0.7677
# Epoch: 008, Train Loss: 0.4698, Test Loss: 0.4621, Train Acc: 0.7742, Test Acc: 0.7728
# Epoch: 009, Train Loss: 0.4677, Test Loss: 0.4604, Train Acc: 0.7736, Test Acc: 0.7717
# Epoch: 010, Train Loss: 0.4662, Test Loss: 0.4626, Train Acc: 0.7739, Test Acc: 0.7716
# Epoch: 011, Train Loss: 0.4648, Test Loss: 0.4616, Train Acc: 0.7735, Test Acc: 0.7713
# Epoch: 012, Train Loss: 0.4632, Test Loss: 0.4585, Train Acc: 0.7754, Test Acc: 0.7744
# Epoch: 013, Train Loss: 0.4623, Test Loss: 0.4561, Train Acc: 0.7775, Test Acc: 0.7759
# Epoch: 014, Train Loss: 0.4612, Test Loss: 0.4575, Train Acc: 0.7780, Test Acc: 0.7768
# Epoch: 015, Train Loss: 0.4600, Test Loss: 0.4557, Train Acc: 0.7794, Test Acc: 0.7767
# Epoch: 016, Train Loss: 0.4591, Test Loss: 0.4543, Train Acc: 0.7782, Test Acc: 0.7758
# Epoch: 017, Train Loss: 0.4587, Test Loss: 0.4537, Train Acc: 0.7787, Test Acc: 0.7769
# Epoch: 018, Train Loss: 0.4582, Test Loss: 0.4549, Train Acc: 0.7779, Test Acc: 0.7759
# Epoch: 019, Train Loss: 0.4569, Test Loss: 0.4521, Train Acc: 0.7795, Test Acc: 0.7771
# Epoch: 020, Train Loss: 0.4561, Test Loss: 0.4550, Train Acc: 0.7772, Test Acc: 0.7752
# Epoch: 021, Train Loss: 0.4561, Test Loss: 0.4531, Train Acc: 0.7797, Test Acc: 0.7775
# Epoch: 022, Train Loss: 0.4552, Test Loss: 0.4519, Train Acc: 0.7806, Test Acc: 0.7782
# Epoch: 023, Train Loss: 0.4551, Test Loss: 0.4606, Train Acc: 0.7744, Test Acc: 0.7718
# Epoch: 024, Train Loss: 0.4543, Test Loss: 0.4498, Train Acc: 0.7813, Test Acc: 0.7785
# Epoch: 025, Train Loss: 0.4540, Test Loss: 0.4490, Train Acc: 0.7824, Test Acc: 0.7793
# Epoch: 026, Train Loss: 0.4534, Test Loss: 0.4492, Train Acc: 0.7822, Test Acc: 0.7806
# Epoch: 027, Train Loss: 0.4531, Test Loss: 0.4496, Train Acc: 0.7808, Test Acc: 0.7786
# Epoch: 028, Train Loss: 0.4526, Test Loss: 0.4502, Train Acc: 0.7825, Test Acc: 0.7800
# Epoch: 029, Train Loss: 0.4527, Test Loss: 0.4489, Train Acc: 0.7820, Test Acc: 0.7794
# Epoch: 030, Train Loss: 0.4517, Test Loss: 0.4511, Train Acc: 0.7813, Test Acc: 0.7787
# Epoch: 031, Train Loss: 0.4519, Test Loss: 0.4514, Train Acc: 0.7811, Test Acc: 0.7784
# Epoch: 032, Train Loss: 0.4514, Test Loss: 0.4492, Train Acc: 0.7831, Test Acc: 0.7799
# Epoch: 033, Train Loss: 0.4504, Test Loss: 0.4467, Train Acc: 0.7833, Test Acc: 0.7815
# Epoch: 034, Train Loss: 0.4505, Test Loss: 0.4475, Train Acc: 0.7821, Test Acc: 0.7796
# Epoch: 035, Train Loss: 0.4505, Test Loss: 0.4476, Train Acc: 0.7835, Test Acc: 0.7802
# Epoch: 036, Train Loss: 0.4500, Test Loss: 0.4487, Train Acc: 0.7824, Test Acc: 0.7799
# Epoch: 037, Train Loss: 0.4501, Test Loss: 0.4466, Train Acc: 0.7832, Test Acc: 0.7803
# Epoch: 038, Train Loss: 0.4496, Test Loss: 0.4464, Train Acc: 0.7846, Test Acc: 0.7809
# Epoch: 039, Train Loss: 0.4492, Test Loss: 0.4465, Train Acc: 0.7835, Test Acc: 0.7810
# Epoch: 040, Train Loss: 0.4492, Test Loss: 0.4466, Train Acc: 0.7839, Test Acc: 0.7805
# Epoch: 041, Train Loss: 0.4485, Test Loss: 0.4453, Train Acc: 0.7841, Test Acc: 0.7813
# Epoch: 042, Train Loss: 0.4482, Test Loss: 0.4471, Train Acc: 0.7835, Test Acc: 0.7796
# Epoch: 043, Train Loss: 0.4479, Test Loss: 0.4454, Train Acc: 0.7844, Test Acc: 0.7814
# Epoch: 044, Train Loss: 0.4478, Test Loss: 0.4445, Train Acc: 0.7853, Test Acc: 0.7822
# Epoch: 045, Train Loss: 0.4473, Test Loss: 0.4479, Train Acc: 0.7825, Test Acc: 0.7793
# Epoch: 046, Train Loss: 0.4475, Test Loss: 0.4444, Train Acc: 0.7859, Test Acc: 0.7826
# Epoch: 047, Train Loss: 0.4468, Test Loss: 0.4462, Train Acc: 0.7852, Test Acc: 0.7813
# Epoch: 048, Train Loss: 0.4466, Test Loss: 0.4434, Train Acc: 0.7848, Test Acc: 0.7818
# Epoch: 049, Train Loss: 0.4462, Test Loss: 0.4451, Train Acc: 0.7837, Test Acc: 0.7802
# Epoch: 050, Train Loss: 0.4459, Test Loss: 0.4450, Train Acc: 0.7850, Test Acc: 0.7820
# Epoch: 051, Train Loss: 0.4460, Test Loss: 0.4446, Train Acc: 0.7854, Test Acc: 0.7817
# Epoch: 052, Train Loss: 0.4454, Test Loss: 0.4429, Train Acc: 0.7862, Test Acc: 0.7832
# Epoch: 053, Train Loss: 0.4453, Test Loss: 0.4419, Train Acc: 0.7867, Test Acc: 0.7836
# Epoch: 054, Train Loss: 0.4450, Test Loss: 0.4430, Train Acc: 0.7852, Test Acc: 0.7823
# Epoch: 055, Train Loss: 0.4444, Test Loss: 0.4451, Train Acc: 0.7852, Test Acc: 0.7825
# Epoch: 056, Train Loss: 0.4443, Test Loss: 0.4423, Train Acc: 0.7856, Test Acc: 0.7826
# Epoch: 057, Train Loss: 0.4443, Test Loss: 0.4407, Train Acc: 0.7877, Test Acc: 0.7840
# Epoch: 058, Train Loss: 0.4439, Test Loss: 0.4439, Train Acc: 0.7860, Test Acc: 0.7818
# Epoch: 059, Train Loss: 0.4435, Test Loss: 0.4403, Train Acc: 0.7881, Test Acc: 0.7841
# Epoch: 060, Train Loss: 0.4432, Test Loss: 0.4407, Train Acc: 0.7876, Test Acc: 0.7838
# Epoch: 061, Train Loss: 0.4430, Test Loss: 0.4440, Train Acc: 0.7850, Test Acc: 0.7816
# Epoch: 062, Train Loss: 0.4428, Test Loss: 0.4397, Train Acc: 0.7885, Test Acc: 0.7853
# Epoch: 063, Train Loss: 0.4426, Test Loss: 0.4404, Train Acc: 0.7882, Test Acc: 0.7848
# Epoch: 064, Train Loss: 0.4425, Test Loss: 0.4400, Train Acc: 0.7876, Test Acc: 0.7841
# Epoch: 065, Train Loss: 0.4421, Test Loss: 0.4388, Train Acc: 0.7893, Test Acc: 0.7850
# Epoch: 066, Train Loss: 0.4421, Test Loss: 0.4439, Train Acc: 0.7849, Test Acc: 0.7807
# Epoch: 067, Train Loss: 0.4415, Test Loss: 0.4384, Train Acc: 0.7894, Test Acc: 0.7861
# Epoch: 068, Train Loss: 0.4410, Test Loss: 0.4392, Train Acc: 0.7884, Test Acc: 0.7839
# Epoch: 069, Train Loss: 0.4413, Test Loss: 0.4379, Train Acc: 0.7890, Test Acc: 0.7852
# Epoch: 070, Train Loss: 0.4415, Test Loss: 0.4395, Train Acc: 0.7886, Test Acc: 0.7845
# Epoch: 071, Train Loss: 0.4405, Test Loss: 0.4379, Train Acc: 0.7900, Test Acc: 0.7862
# Epoch: 072, Train Loss: 0.4404, Test Loss: 0.4382, Train Acc: 0.7897, Test Acc: 0.7868
# Epoch: 073, Train Loss: 0.4398, Test Loss: 0.4382, Train Acc: 0.7899, Test Acc: 0.7858
# Epoch: 074, Train Loss: 0.4404, Test Loss: 0.4393, Train Acc: 0.7892, Test Acc: 0.7855
# Epoch: 075, Train Loss: 0.4398, Test Loss: 0.4386, Train Acc: 0.7895, Test Acc: 0.7850
# Epoch: 076, Train Loss: 0.4376, Test Loss: 0.4364, Train Acc: 0.7912, Test Acc: 0.7873
# Epoch: 077, Train Loss: 0.4371, Test Loss: 0.4376, Train Acc: 0.7910, Test Acc: 0.7871
# Epoch: 078, Train Loss: 0.4375, Test Loss: 0.4366, Train Acc: 0.7905, Test Acc: 0.7856
# Epoch: 079, Train Loss: 0.4372, Test Loss: 0.4355, Train Acc: 0.7910, Test Acc: 0.7866
# Epoch: 080, Train Loss: 0.4367, Test Loss: 0.4349, Train Acc: 0.7916, Test Acc: 0.7872
# Epoch: 081, Train Loss: 0.4367, Test Loss: 0.4370, Train Acc: 0.7903, Test Acc: 0.7846
# Epoch: 082, Train Loss: 0.4368, Test Loss: 0.4386, Train Acc: 0.7895, Test Acc: 0.7850
# Epoch: 083, Train Loss: 0.4368, Test Loss: 0.4406, Train Acc: 0.7882, Test Acc: 0.7833
# Epoch: 084, Train Loss: 0.4363, Test Loss: 0.4370, Train Acc: 0.7910, Test Acc: 0.7855
# Epoch: 085, Train Loss: 0.4366, Test Loss: 0.4343, Train Acc: 0.7924, Test Acc: 0.7881
# Epoch: 086, Train Loss: 0.4363, Test Loss: 0.4358, Train Acc: 0.7910, Test Acc: 0.7857
# Epoch: 087, Train Loss: 0.4360, Test Loss: 0.4348, Train Acc: 0.7926, Test Acc: 0.7879
# Epoch: 088, Train Loss: 0.4358, Test Loss: 0.4354, Train Acc: 0.7922, Test Acc: 0.7871
# Epoch: 089, Train Loss: 0.4364, Test Loss: 0.4344, Train Acc: 0.7922, Test Acc: 0.7870
# Epoch: 090, Train Loss: 0.4361, Test Loss: 0.4355, Train Acc: 0.7917, Test Acc: 0.7865
# Epoch: 091, Train Loss: 0.4354, Test Loss: 0.4340, Train Acc: 0.7926, Test Acc: 0.7881
# Epoch: 092, Train Loss: 0.4358, Test Loss: 0.4351, Train Acc: 0.7915, Test Acc: 0.7862
# Epoch: 093, Train Loss: 0.4352, Test Loss: 0.4333, Train Acc: 0.7928, Test Acc: 0.7884
# Epoch: 094, Train Loss: 0.4353, Test Loss: 0.4343, Train Acc: 0.7917, Test Acc: 0.7864
# Epoch: 095, Train Loss: 0.4349, Test Loss: 0.4337, Train Acc: 0.7930, Test Acc: 0.7878
# Epoch: 096, Train Loss: 0.4348, Test Loss: 0.4339, Train Acc: 0.7924, Test Acc: 0.7872
# Epoch: 097, Train Loss: 0.4345, Test Loss: 0.4343, Train Acc: 0.7929, Test Acc: 0.7876
# Epoch: 098, Train Loss: 0.4346, Test Loss: 0.4333, Train Acc: 0.7933, Test Acc: 0.7886
# Epoch: 099, Train Loss: 0.4343, Test Loss: 0.4329, Train Acc: 0.7931, Test Acc: 0.7887
# Epoch: 100, Train Loss: 0.4346, Test Loss: 0.4330, Train Acc: 0.7939, Test Acc: 0.7892
# Epoch: 101, Train Loss: 0.4345, Test Loss: 0.4335, Train Acc: 0.7933, Test Acc: 0.7896
# Epoch: 102, Train Loss: 0.4339, Test Loss: 0.4330, Train Acc: 0.7935, Test Acc: 0.7887
# Epoch: 103, Train Loss: 0.4348, Test Loss: 0.4326, Train Acc: 0.7940, Test Acc: 0.7892
# Epoch: 104, Train Loss: 0.4343, Test Loss: 0.4320, Train Acc: 0.7940, Test Acc: 0.7891
# Epoch: 105, Train Loss: 0.4336, Test Loss: 0.4322, Train Acc: 0.7940, Test Acc: 0.7890
# Epoch: 106, Train Loss: 0.4343, Test Loss: 0.4321, Train Acc: 0.7936, Test Acc: 0.7892
# Epoch: 107, Train Loss: 0.4339, Test Loss: 0.4349, Train Acc: 0.7920, Test Acc: 0.7861
# Epoch: 108, Train Loss: 0.4340, Test Loss: 0.4320, Train Acc: 0.7946, Test Acc: 0.7896
# Epoch: 109, Train Loss: 0.4335, Test Loss: 0.4350, Train Acc: 0.7920, Test Acc: 0.7864
# Epoch: 110, Train Loss: 0.4338, Test Loss: 0.4329, Train Acc: 0.7938, Test Acc: 0.7887
# Epoch: 111, Train Loss: 0.4325, Test Loss: 0.4324, Train Acc: 0.7938, Test Acc: 0.7878
# Epoch: 112, Train Loss: 0.4319, Test Loss: 0.4314, Train Acc: 0.7944, Test Acc: 0.7893
# Epoch: 113, Train Loss: 0.4314, Test Loss: 0.4325, Train Acc: 0.7937, Test Acc: 0.7877
# Epoch: 114, Train Loss: 0.4317, Test Loss: 0.4313, Train Acc: 0.7948, Test Acc: 0.7896
# Epoch: 115, Train Loss: 0.4324, Test Loss: 0.4321, Train Acc: 0.7939, Test Acc: 0.7879
# Epoch: 116, Train Loss: 0.4319, Test Loss: 0.4311, Train Acc: 0.7949, Test Acc: 0.7893
# Epoch: 117, Train Loss: 0.4317, Test Loss: 0.4308, Train Acc: 0.7951, Test Acc: 0.7901
# Epoch: 118, Train Loss: 0.4315, Test Loss: 0.4309, Train Acc: 0.7948, Test Acc: 0.7890
# Epoch: 119, Train Loss: 0.4321, Test Loss: 0.4308, Train Acc: 0.7953, Test Acc: 0.7898
# Epoch: 120, Train Loss: 0.4315, Test Loss: 0.4307, Train Acc: 0.7954, Test Acc: 0.7906
# Epoch: 121, Train Loss: 0.4315, Test Loss: 0.4322, Train Acc: 0.7945, Test Acc: 0.7880
# Epoch: 122, Train Loss: 0.4314, Test Loss: 0.4307, Train Acc: 0.7953, Test Acc: 0.7895
# Epoch: 123, Train Loss: 0.4313, Test Loss: 0.4315, Train Acc: 0.7946, Test Acc: 0.7885
# Epoch: 124, Train Loss: 0.4310, Test Loss: 0.4302, Train Acc: 0.7955, Test Acc: 0.7902
# Epoch: 125, Train Loss: 0.4312, Test Loss: 0.4305, Train Acc: 0.7957, Test Acc: 0.7897
# Epoch: 126, Train Loss: 0.4312, Test Loss: 0.4312, Train Acc: 0.7955, Test Acc: 0.7895
# Epoch: 127, Train Loss: 0.4310, Test Loss: 0.4312, Train Acc: 0.7947, Test Acc: 0.7890
# Epoch: 128, Train Loss: 0.4310, Test Loss: 0.4309, Train Acc: 0.7955, Test Acc: 0.7896
# Epoch: 129, Train Loss: 0.4309, Test Loss: 0.4308, Train Acc: 0.7953, Test Acc: 0.7894
# Epoch: 130, Train Loss: 0.4307, Test Loss: 0.4304, Train Acc: 0.7954, Test Acc: 0.7895
# Epoch: 131, Train Loss: 0.4303, Test Loss: 0.4299, Train Acc: 0.7963, Test Acc: 0.7902
# Epoch: 132, Train Loss: 0.4299, Test Loss: 0.4309, Train Acc: 0.7953, Test Acc: 0.7894
# Epoch: 133, Train Loss: 0.4306, Test Loss: 0.4297, Train Acc: 0.7963, Test Acc: 0.7909
# Epoch: 134, Train Loss: 0.4301, Test Loss: 0.4311, Train Acc: 0.7952, Test Acc: 0.7891
# Epoch: 135, Train Loss: 0.4305, Test Loss: 0.4305, Train Acc: 0.7957, Test Acc: 0.7899
# Epoch: 136, Train Loss: 0.4298, Test Loss: 0.4302, Train Acc: 0.7960, Test Acc: 0.7900
# Epoch: 137, Train Loss: 0.4296, Test Loss: 0.4296, Train Acc: 0.7961, Test Acc: 0.7906
# Epoch: 138, Train Loss: 0.4302, Test Loss: 0.4312, Train Acc: 0.7953, Test Acc: 0.7890
# Epoch: 139, Train Loss: 0.4299, Test Loss: 0.4305, Train Acc: 0.7956, Test Acc: 0.7893
# Epoch: 140, Train Loss: 0.4300, Test Loss: 0.4299, Train Acc: 0.7962, Test Acc: 0.7908
# Epoch: 141, Train Loss: 0.4302, Test Loss: 0.4298, Train Acc: 0.7965, Test Acc: 0.7911
# Epoch: 142, Train Loss: 0.4292, Test Loss: 0.4302, Train Acc: 0.7959, Test Acc: 0.7898
# Epoch: 143, Train Loss: 0.4294, Test Loss: 0.4323, Train Acc: 0.7946, Test Acc: 0.7879
# Epoch: 144, Train Loss: 0.4298, Test Loss: 0.4297, Train Acc: 0.7964, Test Acc: 0.7905
# Epoch: 145, Train Loss: 0.4292, Test Loss: 0.4298, Train Acc: 0.7964, Test Acc: 0.7901
# Epoch: 146, Train Loss: 0.4294, Test Loss: 0.4295, Train Acc: 0.7966, Test Acc: 0.7913
# Epoch: 147, Train Loss: 0.4293, Test Loss: 0.4297, Train Acc: 0.7964, Test Acc: 0.7903
# Epoch: 148, Train Loss: 0.4296, Test Loss: 0.4299, Train Acc: 0.7960, Test Acc: 0.7899
# Epoch: 149, Train Loss: 0.4293, Test Loss: 0.4296, Train Acc: 0.7965, Test Acc: 0.7902
# Epoch: 150, Train Loss: 0.4293, Test Loss: 0.4294, Train Acc: 0.7967, Test Acc: 0.7904
# Epoch: 151, Train Loss: 0.4293, Test Loss: 0.4295, Train Acc: 0.7969, Test Acc: 0.7909
# Epoch: 152, Train Loss: 0.4295, Test Loss: 0.4293, Train Acc: 0.7967, Test Acc: 0.7910
# Epoch: 153, Train Loss: 0.4291, Test Loss: 0.4296, Train Acc: 0.7964, Test Acc: 0.7906
# Epoch: 154, Train Loss: 0.4291, Test Loss: 0.4297, Train Acc: 0.7963, Test Acc: 0.7902
# Epoch: 155, Train Loss: 0.4291, Test Loss: 0.4297, Train Acc: 0.7967, Test Acc: 0.7905
# Epoch: 156, Train Loss: 0.4290, Test Loss: 0.4293, Train Acc: 0.7970, Test Acc: 0.7911
# Epoch: 157, Train Loss: 0.4289, Test Loss: 0.4296, Train Acc: 0.7966, Test Acc: 0.7906
# Epoch: 158, Train Loss: 0.4297, Test Loss: 0.4294, Train Acc: 0.7966, Test Acc: 0.7905
# Epoch: 159, Train Loss: 0.4291, Test Loss: 0.4299, Train Acc: 0.7964, Test Acc: 0.7900
# Epoch: 160, Train Loss: 0.4292, Test Loss: 0.4294, Train Acc: 0.7967, Test Acc: 0.7904
# Epoch: 161, Train Loss: 0.4288, Test Loss: 0.4299, Train Acc: 0.7965, Test Acc: 0.7901
# Epoch: 162, Train Loss: 0.4287, Test Loss: 0.4293, Train Acc: 0.7967, Test Acc: 0.7908
# Epoch: 163, Train Loss: 0.4288, Test Loss: 0.4295, Train Acc: 0.7967, Test Acc: 0.7903
# Epoch: 164, Train Loss: 0.4287, Test Loss: 0.4294, Train Acc: 0.7969, Test Acc: 0.7900
# Epoch: 165, Train Loss: 0.4292, Test Loss: 0.4298, Train Acc: 0.7965, Test Acc: 0.7904
# Epoch: 166, Train Loss: 0.4287, Test Loss: 0.4296, Train Acc: 0.7965, Test Acc: 0.7900
# Epoch: 167, Train Loss: 0.4283, Test Loss: 0.4296, Train Acc: 0.7966, Test Acc: 0.7903
# Epoch: 168, Train Loss: 0.4288, Test Loss: 0.4295, Train Acc: 0.7969, Test Acc: 0.7907
# Epoch: 169, Train Loss: 0.4286, Test Loss: 0.4294, Train Acc: 0.7969, Test Acc: 0.7906
# Epoch: 170, Train Loss: 0.4284, Test Loss: 0.4293, Train Acc: 0.7970, Test Acc: 0.7910
# Epoch: 171, Train Loss: 0.4290, Test Loss: 0.4294, Train Acc: 0.7968, Test Acc: 0.7907
# Epoch: 172, Train Loss: 0.4284, Test Loss: 0.4292, Train Acc: 0.7969, Test Acc: 0.7908
# Epoch: 173, Train Loss: 0.4286, Test Loss: 0.4296, Train Acc: 0.7965, Test Acc: 0.7900
# Epoch: 174, Train Loss: 0.4290, Test Loss: 0.4292, Train Acc: 0.7969, Test Acc: 0.7909
# Epoch: 175, Train Loss: 0.4287, Test Loss: 0.4294, Train Acc: 0.7968, Test Acc: 0.7902
# Epoch: 176, Train Loss: 0.4288, Test Loss: 0.4294, Train Acc: 0.7968, Test Acc: 0.7903
# Epoch: 177, Train Loss: 0.4287, Test Loss: 0.4292, Train Acc: 0.7971, Test Acc: 0.7909
# Epoch: 178, Train Loss: 0.4286, Test Loss: 0.4294, Train Acc: 0.7969, Test Acc: 0.7905
# Epoch: 179, Train Loss: 0.4289, Test Loss: 0.4294, Train Acc: 0.7969, Test Acc: 0.7906
# Epoch: 180, Train Loss: 0.4287, Test Loss: 0.4294, Train Acc: 0.7970, Test Acc: 0.7903
# Epoch: 181, Train Loss: 0.4289, Test Loss: 0.4294, Train Acc: 0.7970, Test Acc: 0.7905
# Epoch: 182, Train Loss: 0.4286, Test Loss: 0.4293, Train Acc: 0.7971, Test Acc: 0.7906
# Epoch: 183, Train Loss: 0.4288, Test Loss: 0.4294, Train Acc: 0.7969, Test Acc: 0.7905
# Epoch: 184, Train Loss: 0.4285, Test Loss: 0.4293, Train Acc: 0.7970, Test Acc: 0.7904
# Epoch: 185, Train Loss: 0.4286, Test Loss: 0.4292, Train Acc: 0.7970, Test Acc: 0.7905
# Epoch: 186, Train Loss: 0.4286, Test Loss: 0.4293, Train Acc: 0.7968, Test Acc: 0.7903
# Epoch: 187, Train Loss: 0.4286, Test Loss: 0.4294, Train Acc: 0.7968, Test Acc: 0.7904
# Epoch: 188, Train Loss: 0.4285, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7902
# Epoch: 189, Train Loss: 0.4284, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7902
# Epoch: 190, Train Loss: 0.4288, Test Loss: 0.4292, Train Acc: 0.7970, Test Acc: 0.7905
# Epoch: 191, Train Loss: 0.4286, Test Loss: 0.4292, Train Acc: 0.7970, Test Acc: 0.7905
# Epoch: 192, Train Loss: 0.4289, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7903
# Epoch: 193, Train Loss: 0.4290, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7902
# Epoch: 194, Train Loss: 0.4286, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7903
# Epoch: 195, Train Loss: 0.4286, Test Loss: 0.4292, Train Acc: 0.7970, Test Acc: 0.7906
# Epoch: 196, Train Loss: 0.4285, Test Loss: 0.4292, Train Acc: 0.7970, Test Acc: 0.7905
# Epoch: 197, Train Loss: 0.4285, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7905
# Epoch: 198, Train Loss: 0.4285, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7903
# Epoch: 199, Train Loss: 0.4284, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7902
# Epoch: 200, Train Loss: 0.4284, Test Loss: 0.4293, Train Acc: 0.7969, Test Acc: 0.7904
# Model saved as full_cb_model1.pth. Training complete.

# %%
# Reload training data to produce plots
training = pd.read_csv('full_cb_training_results1.csv')
train_loss_values = training['Train Loss'].to_list()
test_loss_values = training['Test Loss'].to_list()
train_acc_values = training['Train Accuracy'].to_list()
test_acc_values = training['Test Accuracy'].to_list()

# %%
training
# Out:
#      Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy
# 0        1    0.577004   0.510697        0.745818       0.744706
# 1        2    0.508890   0.490778        0.756714       0.755212
# 2        3    0.492847   0.475701        0.765800       0.763821
# 3        4    0.484583   0.469480        0.768820       0.767101
# 4        5    0.479177   0.465854        0.770528       0.769108
# ..     ...         ...        ...             ...            ...
# 195    196    0.428491   0.429233        0.796966       0.790486
# 196    197    0.428534   0.429251        0.796925       0.790486
# 197    198    0.428545   0.429264        0.796922       0.790323
# 198    199    0.428438   0.429282        0.796922       0.790201
# 199    200    0.428397   0.429270        0.796908       0.790391
#
# [200 rows x 5 columns]

# %%
# Plot Loss and Accuracy
def plot_training_results():
    epochs = range(1, len(train_loss_values) + 1)

    mean_train_loss = mean(train_loss_values)
    mean_test_loss = mean(test_loss_values)
    mean_train_acc = mean(train_acc_values)
    mean_test_acc = mean(test_acc_values)

    min_train_loss = min(train_loss_values)
    min_test_loss = min(test_loss_values)
    max_train_acc = max(train_acc_values)
    max_test_acc = max(test_acc_values)

    final_train_loss = train_loss_values[-1]
    final_test_loss = test_loss_values[-1]
    final_train_acc = train_acc_values[-1]
    final_test_acc = test_acc_values[-1]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

    # Plot Loss
    ax1.plot(epochs, train_loss_values, color='darkred', label=(f"Training Loss (min = {min_train_loss:.4f})"))
    ax1.plot(epochs, test_loss_values, color='mediumblue', label=(f"Testing Loss (min = {min_test_loss:.4f})"))
        
    ax1.text(0.15, 0.90, "LHCb Simulation", transform=ax1.transAxes, fontsize=15, verticalalignment='bottom')
    #ax1.text(0.85, 0.10, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')

    ax1.set_title('Loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='best')

    # Plot  Accuracy
    ax2.plot(epochs, train_acc_values, color='darkred', label=(f"Training Accuracy (max = {max_train_acc:.4f})"))
    ax2.plot(epochs, test_acc_values, color='mediumblue', label=(f"Testing Accuracy (max = {max_test_acc:.4f})"))
    
    ax2.text(0.7, 0.15, "LHCb Simulation", transform=ax2.transAxes, fontsize=15, verticalalignment='bottom')
    #ax2.text(0.85, 0.10, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')

    ax2.set_title('Accuracy')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.legend(loc='best')

    plt.style.use('default')
    plt.tight_layout()
    plt.show()
    
plot_training_results()

# %%
# Get model predictions
y_true = []  # class values (0 or 1)
y_scores = []  # predicted probabilities or scores

model.load_state_dict(torch.load('full_cb_model1.pth'))
model = model.to('cpu')
model.eval()
with torch.no_grad():
    for data in test_loader:
        out = model(data.x, data.edge_index, data.batch)
        prob = torch.sigmoid(out)
        
        y_true.append(data.y.numpy().flatten())
        y_scores.append(prob.numpy().flatten())

y_true = np.concatenate(y_true)
y_scores = np.concatenate(y_scores)

fpr, tpr, thresholds = roc_curve(y_true, y_scores)
auc = roc_auc_score(y_true, y_scores)

#np.save('full_cb_roc_data1.npy', np.array([fpr, tpr, thresholds, auc]))

# %%
chosen_tpr = 0.2
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pc {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.2: Pc 0.8968: FPR 0.0153

# %%
# Get FPRs for TPRs
desired_tpr = [0.2, 0.3, 0.4]

print("Efficiency | FPR ")
for val in desired_tpr:
    closest_index = np.argmin(np.abs(tpr - val))
    chosen_threshold = thresholds[closest_index]
    chosen_fpr = fpr[closest_index]
    print(f"{val}: {chosen_fpr:.4f}")
# Out:
# Efficiency | FPR
# 0.2: 0.0153
# 0.3: 0.0301
# 0.4: 0.0507

# %%
chosen_tpr = 0.2
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pc {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.2: Pc 0.8968: FPR 0.0153

# %%
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)

cm_percentage = cm.astype(float) / cm.sum(axis=1)[:, np.newaxis] * 100

annot_labels = np.empty_like(cm, dtype=object)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        percentage = cm_percentage[i, j]
        annot_labels[i, j] = f'{percentage:.1f}%'

fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm_percentage, annot=annot_labels, fmt='', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr * 100}% Efficiency")

ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
# need to revise for different efficiency
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)
df_cm = pd.DataFrame(cm)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr*100}% Efficiency")

# Add TP, FP, FN, TN labels
ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
# Plot ROC Curve and show AUC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='navy', label=f'ROC curve (AUC = {auc:.4f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--', label='Baseline (AUC = 0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.ylabel('Signal Efficiency')
plt.xlabel('False Positive Rate (FPR)')
plt.title('Receiver Operating Characteristics (ROC)')
plt.text(0.85, 0.15, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.legend(loc='lower right')
plt.show()

# %%
# Prepare model
model.eval()
data = next(iter(test_loader))
x, edge_index, batch = data.x, data.edge_index, data.batch

G = nx.Graph()
edges = list(zip(edge_index[0].numpy(), edge_index[1].numpy()))
G.add_edges_from(edges)

feature_importances = np.zeros(x.size(1))

for feature_idx in range(x.size(1)):
    x_perturbed = x.clone()
    x_perturbed[:, feature_idx] = 0

    # Predict with original features
    with torch.no_grad():
        orig_pred = model(x, edge_index, batch)
        perturbed_pred = model(x_perturbed, edge_index, batch)

    # Compute importance - difference in predictions
    importance = torch.mean(torch.abs(orig_pred - perturbed_pred))
    feature_importances[feature_idx] = importance

importance_df = pd.DataFrame({'Feature': feature_cols, 'Importance': feature_importances})
print(importance_df)

plt.figure(figsize=(12, 12))
sns.barplot(x='Importance', y='Feature', data=importance_df, palette='viridis', hue='Feature', dodge=False)
plt.text(0.87, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()
# Out:
#                                 Feature  Importance
# 0                      Jet0_Daughters_E    1.012113
# 1                     Jet0_Daughters_pT    1.092537
# 2                     Jet0_Daughters_ID    0.058974
# 3                     Jet0_Daughters_pX    0.063448
# 4                     Jet0_Daughters_pY    0.063030
# 5                     Jet0_Daughters_pZ    1.106680
# 6                    Jet0_Daughters_Eta    0.004334
# 7                    Jet0_Daughters_Phi    0.002194
# 8                      Jet0_Daughters_Q    0.000490
# 9                     Jet0_Daughters_IP    0.048027
# 10                Jet0_Daughters_IPCHI2    0.992011
# 11                 Jet0_Daughters_IPraw    0.028872
# 12                   Jet0_Daughters_NNe    0.152410
# 13                   Jet0_Daughters_NNk    0.089877
# 14                   Jet0_Daughters_NNp    0.190665
# 15                  Jet0_Daughters_NNpi    0.172920
# 16                  Jet0_Daughters_NNmu    0.853119
# 17                  Jet0_Daughters_Chi2    0.182333
# 18                Jet0_Daughters_QoverP    0.104140
# 19                Jet0_Daughters_trackX    0.120335
# 20                Jet0_Daughters_trackY    0.107669
# 21                Jet0_Daughters_trackZ    0.213493
# 22               Jet0_Daughters_trackVX    0.080551
# 23               Jet0_Daughters_trackVY    0.106447
# 24               Jet0_Daughters_trackVZ    0.553243
# 25       Jet0_Daughters_CaloNeutralEcal    0.281919
# 26  Jet0_Daughters_CaloNeutralHcal2Ecal    0.247273
# 27        Jet0_Daughters_CaloNeutralE49    0.309438
# 28        Jet0_Daughters_CaloNeutralPrs    0.257044
# 29                             Jet0_Eta    0.004458
# 30                              Jet0_PT    1.814370
# 31                    Jet0_SVtag_fdrMin    0.007050
# 32                  Jet0_SVtag_ptSvrJet    0.000674
# 33                      Jet0_SVtag_nTrk    0.014723
# 34                   Jet0_SVtag_nTrkJet    0.018674
# 35                  Jet0_SVtag_drSvrJet    0.000375
# 36                   Jet0_SVtag_absQSum    0.010874
# 37                         Jet0_SVtag_m    0.669492
# 38                      Jet0_SVtag_mCor    2.717152
# 39                    Jet0_SVtag_fdChi2    0.345262
# 40                 Jet0_SVtag_ipChi2Sum    1.543244
# 41                       Jet0_SVtag_tau    0.000791
# 42                         Jet0_SVtag_z    0.043600
# 43                        Jet0_SVtag_pt    1.458305

# %%
for index, row in importance_df.iterrows():
    feature = row['Feature'] 
    importance = row['Importance']
    if importance > 0.25:
        print(f'{feature} & {importance:4f}')
# Out:
# Jet0_Daughters_E & 1.012113
# Jet0_Daughters_pT & 1.092537
# Jet0_Daughters_pZ & 1.106680
# Jet0_Daughters_IPCHI2 & 0.992011
# Jet0_Daughters_NNmu & 0.853119
# Jet0_Daughters_trackVZ & 0.553243
# Jet0_Daughters_CaloNeutralEcal & 0.281919
# Jet0_Daughters_CaloNeutralE49 & 0.309438
# Jet0_Daughters_CaloNeutralPrs & 0.257044
# Jet0_PT & 1.814370
# Jet0_SVtag_m & 0.669492
# Jet0_SVtag_mCor & 2.717152
# Jet0_SVtag_fdChi2 & 0.345262
# Jet0_SVtag_ipChi2Sum & 1.543244
# Jet0_SVtag_pt & 1.458305

# %% [markdown]
# # Model Probability Output

# %%
df = pd.concat([cc_df, bb_df]).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_from_iter.py:73, in from_iter(iterable, allow_record, highlevel, behavior, initial, resize)
#      62 with ak._errors.OperationErrorContext(
#      63     "ak.from_iter",
#      64     {
#    (...)
#      71     },
#      72 ):
# ---> 73     return _impl(iterable, highlevel, behavior, allow_record, initial, resize)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_from_iter.py:102, in _impl(iterable, highlevel, behavior, allow_record, initial, resize)
#     101 builder = _ext.ArrayBuilder(initial=initial, resize=resize)
# --> 102 builder.fromiter(iterable)
#     104 formstr, length, buffers = builder.to_buffers()
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/highlevel.py:500, in Array.__iter__(self)
#     499         for x in array:
# --> 500             yield x
#     501 else:
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_to_layout.py:52, in to_layout(array, allow_record, allow_other, regulararray)
#      43 with _errors.OperationErrorContext(
#      44     "ak.to_layout",
#      45     {
#    (...)
#      50     },
#      51 ):
# ---> 52     return _impl(array, allow_record, allow_other, regulararray=regulararray)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_to_layout.py:114, in _impl(array, allow_record, allow_other, regulararray)
#     112 elif isinstance(array, Iterable):
#     113     return _impl(
# --> 114         ak.operations.from_iter(array, highlevel=False),
#     115         allow_record,
#     116         allow_other,
#     117         regulararray,
#     118     )
#     120 elif not allow_other:
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_from_iter.py:73, in from_iter(iterable, allow_record, highlevel, behavior, initial, resize)
#      62 with ak._errors.OperationErrorContext(
#      63     "ak.from_iter",
#      64     {
#    (...)
#      71     },
#      72 ):
# ---> 73     return _impl(iterable, highlevel, behavior, allow_record, initial, resize)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/_errors.py:54, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      53     if exception_type is not None:
# ---> 54         self.handle_exception(exception_type, exception_value)
#      55 finally:
#      56     # Step out of the way so that another ErrorContext can become primary.
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/_errors.py:64, in ErrorContext.handle_exception(self, cls, exception)
#      63 else:
# ---> 64     raise self.decorate_exception(cls, exception)
#
# KeyboardInterrupt:
#
# This error occurred while calling
#
#     ak.from_iter(
#         iterable = AwkwardExtensionArray-instance
#         allow_record = True
#         highlevel = False
#         behavior = None
#         initial = 1024
#         resize = 1.5
#     )
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:50, in concatenate(arrays, axis, mergebool, highlevel, behavior)
#      40 with ak._errors.OperationErrorContext(
#      41     "ak.concatenate",
#      42     {
#    (...)
#      48     },
#      49 ):
# ---> 50     return _impl(arrays, axis, mergebool, highlevel, behavior)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:70, in _impl(arrays, axis, mergebool, highlevel, behavior)
#      68         return ak.operations.ak_flatten._impl(content, 1, highlevel, behavior)
# ---> 70 content_or_others = [
#      71     x.to_backend(backend) if isinstance(x, ak.contents.Content) else x
#      72     for x in (
#      73         ak.operations.to_layout(
#      74             x, allow_record=False if axis == 0 else True, allow_other=True
#      75         )
#      76         for x in arrays
#      77     )
#      78 ]
#      80 contents = [x for x in content_or_others if isinstance(x, ak.contents.Content)]
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:70, in <listcomp>(.0)
#      68         return ak.operations.ak_flatten._impl(content, 1, highlevel, behavior)
# ---> 70 content_or_others = [
#      71     x.to_backend(backend) if isinstance(x, ak.contents.Content) else x
#      72     for x in (
#      73         ak.operations.to_layout(
#      74             x, allow_record=False if axis == 0 else True, allow_other=True
#      75         )
#      76         for x in arrays
#      77     )
#      78 ]
#      80 contents = [x for x in content_or_others if isinstance(x, ak.contents.Content)]
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:73, in <genexpr>(.0)
#      68         return ak.operations.ak_flatten._impl(content, 1, highlevel, behavior)
#      70 content_or_others = [
#      71     x.to_backend(backend) if isinstance(x, ak.contents.Content) else x
#      72     for x in (
# ---> 73         ak.operations.to_layout(
#      74             x, allow_record=False if axis == 0 else True, allow_other=True
#      75         )
#      76         for x in arrays
#      77     )
#      78 ]
#      80 contents = [x for x in content_or_others if isinstance(x, ak.contents.Content)]
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_to_layout.py:52, in to_layout(array, allow_record, allow_other, regulararray)
#      43 with _errors.OperationErrorContext(
#      44     "ak.to_layout",
#      45     {
#    (...)
#      50     },
#      51 ):
# ---> 52     return _impl(array, allow_record, allow_other, regulararray=regulararray)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/_errors.py:54, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      53     if exception_type is not None:
# ---> 54         self.handle_exception(exception_type, exception_value)
#      55 finally:
#      56     # Step out of the way so that another ErrorContext can become primary.
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/_errors.py:64, in ErrorContext.handle_exception(self, cls, exception)
#      63 else:
# ---> 64     raise self.decorate_exception(cls, exception)
#
# KeyboardInterrupt:
#
# This error occurred while calling
#
#     ak.from_iter(
#         iterable = AwkwardExtensionArray-instance
#         allow_record = True
#         highlevel = False
#         behavior = None
#         initial = 1024
#         resize = 1.5
#     )
#
# This error occurred while calling
#
#     ak.to_layout(
#         array = AwkwardExtensionArray-instance
#         allow_record = False
#         allow_other = True
#         regulararray = True
#     )
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = pd.concat([cc_df, bb_df]).reset_index(drop=True)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/reshape/concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/reshape/concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/internals/concat.py:180, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     177     values = np.concatenate(vals, axis=1)  # type: ignore[arg-type]
#     178 elif is_1d_only_ea_dtype(blk.dtype):
#     179     # TODO(EA2D): special-casing not needed with 2D EAs
# --> 180     values = concat_compat(vals, axis=0, ea_compat_axis=True)
#     181     values = ensure_block_shape(values, ndim=2)
#     182 else:
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/dtypes/concat.py:83, in concat_compat(to_concat, axis, ea_compat_axis)
#      80 to_concat_eas = cast("Sequence[ExtensionArray]", to_concat)
#      81 if ea_compat_axis:
#      82     # We have 1D objects, that don't support axis keyword
# ---> 83     return obj._concat_same_type(to_concat_eas)
#      84 elif axis == 0:
#      85     return obj._concat_same_type(to_concat_eas)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward_pandas/array.py:130, in AwkwardExtensionArray._concat_same_type(cls, to_concat)
#     128 @classmethod
#     129 def _concat_same_type(cls, to_concat):
# --> 130     return cls(ak.concatenate(to_concat))
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/operations/ak_concatenate.py:50, in concatenate(arrays, axis, mergebool, highlevel, behavior)
#      19 """
#      20 Args:
#      21     arrays: Array-like data (anything #ak.to_layout recognizes).
#    (...)
#      38 element for element, and similarly for deeper levels.
#      39 """
#      40 with ak._errors.OperationErrorContext(
#      41     "ak.concatenate",
#      42     {
#    (...)
#      48     },
#      49 ):
# ---> 50     return _impl(arrays, axis, mergebool, highlevel, behavior)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/_errors.py:54, in ErrorContext.__exit__(self, exception_type, exception_value, traceback)
#      51 try:
#      52     # Handle caught exception
#      53     if exception_type is not None:
# ---> 54         self.handle_exception(exception_type, exception_value)
#      55 finally:
#      56     # Step out of the way so that another ErrorContext can become primary.
#      57     if self.primary() is self:
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/_errors.py:64, in ErrorContext.handle_exception(self, cls, exception)
#      62     return self.decorate_exception(cls, exception)
#      63 else:
# ---> 64     raise self.decorate_exception(cls, exception)
#
# KeyboardInterrupt:
#
# This error occurred while calling
#
#     ak.from_iter(
#         iterable = AwkwardExtensionArray-instance
#         allow_record = True
#         highlevel = False
#         behavior = None
#         initial = 1024
#         resize = 1.5
#     )
#
# This error occurred while calling
#
#     ak.to_layout(
#         array = AwkwardExtensionArray-instance
#         allow_record = False
#         allow_other = True
#         regulararray = True
#     )
#
# This error occurred while calling
#
#     ak.concatenate(
#         arrays = [<AwkwardExtensionArray>
# [  <Array [57.7, 344, 917, ..., 2.3...
#         axis = 0
#         mergebool = True
#         highlevel = True
#         behavior = None
#     )

# %%
def make_predictions():
    # Select a random integer for sampling
    random_integer = np.random.randint(0, len(df))
    sample_jet = df.iloc[random_integer:random_integer+1].copy()

    # Filter columns related to Jet0
    sample_jet = sample_jet.filter(like='Jet0')

    # Define feature columns
    daughter_cols = [col for col in sample_jet.columns if "_Daughters" in col]
    svtag_cols = ['Jet0_SVtag_fdrMin',
    'Jet0_SVtag_ptSvrJet',
    'Jet0_SVtag_nTrk',
    'Jet0_SVtag_nTrkJet',
    'Jet0_SVtag_drSvrJet',
    'Jet0_SVtag_absQSum',
    'Jet0_SVtag_m',
    'Jet0_SVtag_mCor',
    'Jet0_SVtag_fdChi2',
    'Jet0_SVtag_ipChi2Sum',
    'Jet0_SVtag_tau',
    'Jet0_SVtag_z',
    'Jet0_SVtag_pt']
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    # Process feature columns
    for col in feature_cols:
        if col in sample_jet.columns:
            sample_jet[col] = sample_jet.apply(lambda row: [row[col]] * int(row['Jet0_nDaughters']) if isinstance(row[col], (float, int)) else row[col], axis=1)
            sample_jet[col] = sample_jet[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Obtain features of each node within the graph
    features_list = []
    for _, row in sample_jet.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    # Create graph representation with data objects
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch)
            probability = torch.sigmoid(output)
            prediction = (probability > thresholds).int()

    print(f'Probability: {probability.item()}')
    if prediction.item() == 1:  
        print(f'Prediction: c-jet')
    if prediction.item() == 0:  
        print(f'Prediction: not a c-jet')
    return probability.item()

i = 0

for i in range(100):
    cprob = make_predictions()
    bprob = make_predictions()

# %% [markdown]
# # Create Efficiency Plot

# %%
model.load_state_dict(torch.load('full_cb_model1.pth'))
model = model.to('cpu')

# %%
len(test_df)
# Out:
# 73766

# %%
# Separate b and q data from testing dataset (preprocessed)
c = test_df[test_df.IsC == 1]
b = test_df[test_df.IsC == 0]

c_data = create_graphs(c, feature_cols)
b_data = create_graphs(b, feature_cols)

c_prob = []
b_prob = []

def get_probabilities(data_list):
    prob_list = []
    model.eval()
    with torch.no_grad():
        for data in data_list:
            out = model(data.x, data.edge_index, data.batch)
            prob = torch.sigmoid(out).numpy().flatten()
            prob_list.append(prob)
    return np.concatenate(prob_list)

# Compute probabilities for b and q data
c_prob = get_probabilities(c_data)
b_prob = get_probabilities(b_data)

# %%
len(c_prob)
# Out:
# 36883
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
len(b_prob)
# Out:
# 36883

# %%
def plot_probability_distribution(c_prob, b_prob, target_efficiencies):

    # Sort c-jet probabilities in descending order for cutoff calculations
    sorted_c_prob = np.sort(c_prob)[::-1]
    
    # Calculate cutoffs for each efficiency level
    cutoffs = {}
    for efficiency in target_efficiencies:
        cutoff_index = int(len(sorted_c_prob) * efficiency)
        cutoffs[efficiency] = sorted_c_prob[cutoff_index - 1] if cutoff_index > 0 else sorted_c_prob[0]
    
    # Plot histograms for b-jet and q-jet probabilities
    plt.figure(figsize=(10, 6))
    c_values, c_bins, _ = plt.hist(c_prob, bins=100, label='c-jets', color='darkred', histtype='step')
    b_values, b_bins, _ = plt.hist(b_prob, bins=100, label='b-jets', color='mediumblue', histtype='step')

    max_y = max(max(c_values), max(b_values))
    
    # Mark cutoffs for selected efficiencies
    for i, (efficiency, cutoff) in enumerate(cutoffs.items()):
        plt.vlines(x=cutoff, ymin=0, ymax=max_y * 0.15, color='grey', linestyle='--', linewidth=1)
        plt.text(cutoff, max_y*0.17, f'{int(efficiency * 100)}%', ha='center', va='bottom', rotation=90)


    plt.xlabel("P$_c$")
    plt.ylabel("Number of Jets")
    plt.text(0.9, max_y * 0.8, "LHCb Simulation", fontsize=15, verticalalignment='bottom', horizontalalignment='right')
    plt.title("Probability Distribution")
    plt.yscale('log')
    plt.legend(loc='best')
    plt.show()

target_efficiencies = [0.2, 0.3, 0.4]
plot_probability_distribution(c_prob, b_prob, target_efficiencies)

# %%
fpr, tpr, thresholds, auc = np.load('full_cb_roc_data1.npy', allow_pickle=True)

# %%
chosen_tpr = 0.30
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pc {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.3: Pc 0.8476: FPR 0.0340

# %%
c = test_df[test_df.IsC == 1]
# Revert Jet0_PT to one element, not a list
c.loc[:, 'Jet0_PT'] = c['Jet0_PT'].apply(lambda x: x[0] if isinstance(x, list) else x)

pt23_df = c[(c['Jet0_PT'].between(20000, 30000))].reset_index(drop=True)
pt34_df = c[(c['Jet0_PT'].between(30000, 40000))].reset_index(drop=True)
pt45_df = c[(c['Jet0_PT'].between(40000, 50000))].reset_index(drop=True)

# %%
def make_predictions(df):
    # Define feature columns
    daughter_cols = [col for col in df.columns if "_Daughters" in col]
    svtag_cols = [
        'Jet0_SVtag_fdrMin',
        'Jet0_SVtag_ptSvrJet',
        'Jet0_SVtag_nTrk',
        'Jet0_SVtag_nTrkJet',
        'Jet0_SVtag_drSvrJet',
        'Jet0_SVtag_absQSum',
        'Jet0_SVtag_m',
        'Jet0_SVtag_mCor',
        'Jet0_SVtag_fdChi2',
        'Jet0_SVtag_ipChi2Sum',
        'Jet0_SVtag_tau',
        'Jet0_SVtag_z',
        'Jet0_SVtag_pt'
    ]
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    # Expand jet and daughter features
    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Obtain features of each node within the graph
    features_list = []
    for _, row in df.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    # Create graph representation with data objects
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    num_c = 0

    # Make predictions
    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch)  # Ensure batch is included if required
            probability = torch.sigmoid(output)
            prediction = (probability > chosen_threshold).int()

            if prediction.item() == 1:  
                num_c += 1
    return num_c

# %%
num_c23 = make_predictions(pt23_df)
num_c34 = make_predictions(pt34_df)
num_c45 = make_predictions(pt45_df)

# %%
efficiency23 = num_c23 / len(pt23_df)
efficiency34 = num_c34 / len(pt34_df)
efficiency45 = num_c45 / len(pt45_df)

print(f'Efficiency for pT 20-30 GeV: {efficiency23:.4f}')
print(f'Efficiency for pT 30-40 GeV: {efficiency34:.4f}')
print(f'Efficiency for pT 40-50 GeV: {efficiency45:.4f}')
# Out:
# Efficiency for pT 20-30 GeV: 0.2784
# Efficiency for pT 30-40 GeV: 0.3331
# Efficiency for pT 40-50 GeV: 0.3304

# %%
def plot_efficiency_histogram(efficiencies, pt_bins):
    plt.figure(figsize=(10, 6))

    # Calculate bin centers and widths
    bin_centers = (pt_bins[:-1] + pt_bins[1:]) / 2
    bar_width = np.diff(pt_bins)  # Width of the bins

    # Create the histogram by plotting only the tops of the bins
    for i in range(len(efficiencies)):
        plt.plot([pt_bins[i], pt_bins[i+1]], [efficiencies[i], efficiencies[i]], color='blue', linewidth=2)
    plt.xticks(np.arange(20000, 51000, 5000))
    plt.xlabel('pT (GeV)')
    plt.ylabel('Efficiency')
    plt.text(0.85, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
    plt.title('Efficiency for c-jets at 30% TPR')
    plt.ylim(0, 1)
    plt.xlim(20000,50000)
    plt.show()

pt_bins = np.array([20000, 30000, 40000, 50000])
efficiencies = [efficiency23, efficiency34, efficiency45]

plot_efficiency_histogram(efficiencies, pt_bins)
