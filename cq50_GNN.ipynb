# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn import Linear, Dropout, LayerNorm
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import SAGEConv, global_add_pool, GraphConv
from torch.nn.utils import clip_grad_norm_
from torch.optim.lr_scheduler import ReduceLROnPlateau

import networkx as nx
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
import seaborn as sns
import random
import uproot

# %%
torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
path_to_tree = "DecayTreeTuple/tuple"

def rename_columns(df):
    new_columns = {}
    for col in df.columns:
        if "_BDTTag_" in col:
            new_columns[col] = col.replace("_BDTTag_", "_SVtag_")
    df.rename(columns=new_columns, inplace=True)

# maybe don't need
def extract_float(awk_array):
    return awk_array[0] if len(awk_array) > 0 else None

# %%
# Read the ROOT file
tree = uproot.open("Dijet_cc_pt20_50_dw.root" + ":" + path_to_tree)
cc_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000)

# Clean column names and remove unwanted columns
cc_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in cc_df.columns]
rename_columns(cc_df)
columns_to_remove = [col for col in cc_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
cc_df.drop(columns=columns_to_remove, inplace=True)
for col in cc_df.columns:
    if "SVtag" in col:
        cc_df[col] = cc_df[col].apply(extract_float)
tree.close()

# Read the ROOT file
tree = uproot.open("Dijet_qq_pt20_50_dw.root" + ":" + path_to_tree)
qq_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000)

# Clean column names and remove unwanted columns
qq_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in qq_df.columns]
rename_columns(qq_df)
columns_to_remove = [col for col in qq_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
qq_df.drop(columns=columns_to_remove, inplace=True)
for col in qq_df.columns:
    if "SVtag" in col:
        qq_df[col] = qq_df[col].apply(extract_float)
tree.close()

# %%
# Read the ROOT file
tree = uproot.open("Dijet_cc_pt50_dw.root" + ":" + path_to_tree)
cc50_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000)

# Clean column names and remove unwanted columns
cc50_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in cc50_df.columns]
rename_columns(cc50_df)
columns_to_remove = [col for col in cc50_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
cc50_df.drop(columns=columns_to_remove, inplace=True)
for col in cc50_df.columns:
    if "SVtag" in col:
        cc50_df[col] = cc50_df[col].apply(extract_float)
tree.close()

# Read the ROOT file
tree = uproot.open("Dijet_qq_pt50_dw.root" + ":" + path_to_tree)
qq50_df = tree.arrays(tree.keys(), library="pd", entry_start=0, entry_stop=1000) 

# Clean column names and remove unwanted columns
qq50_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in qq50_df.columns]
rename_columns(qq50_df)
columns_to_remove = [col for col in qq50_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
qq50_df.drop(columns=columns_to_remove, inplace=True)
for col in qq50_df.columns:
    if "SVtag" in col:
        qq50_df[col] = qq50_df[col].apply(extract_float)
tree.close()

# %%
weights = {
    "cc_df": 1,
    "qq_df": 1,
    "cc50_df": 0.02880875704,
    "qq50_df": 0.02991944973
}

for df_name, weight in weights.items():
    globals()[df_name]['weights'] = weight

sig_df = pd.concat([cc_df, cc50_df])
bkg_df = pd.concat([qq_df, qq50_df])

# %%
print(f'There are {len(sig_df)} c-jet events (signal)')
print(f'There are {len(bkg_df)} q-jet events (background)')
# Out:
# There are 2000 c-jet events (signal)
# There are 2000 q-jet events (background)

# %%
# Read from csv and assign truth labels
sig_df['IsC'] = 1
bkg_df['IsC'] = 0

# Filter columns to include only leading jet data and truth labels
sig_df = sig_df[sig_df.columns[sig_df.columns.str.contains("Jet0|IsC|weights")]]
bkg_df = bkg_df[bkg_df.columns[bkg_df.columns.str.contains("Jet0|IsC|weights")]]

# Apply cuts and truth matching
sig_df = sig_df[(sig_df['Jet0_MC_Match'] == 1) &
                (sig_df['Jet0_MC_Jet_EfD'] > 0.6) &
                (sig_df['Jet0_PT'] > 20000) &
                (sig_df['Jet0_Eta'].between(2.2, 4.4))]
bkg_df = bkg_df[(bkg_df['Jet0_MC_Match'] == 1) &
                (bkg_df['Jet0_MC_Jet_EfB'] < 0.6) &
                (bkg_df['Jet0_MC_Jet_EfD'] < 0.6) &
                (bkg_df['Jet0_PT'] > 20000) &
                (bkg_df['Jet0_Eta'].between(2.2, 4.4))]

# Combine signal and background
combined_df = pd.concat([sig_df, bkg_df]).reset_index(drop=True)

# %%
print(f"Efficiency of signal truth matching is: {len(sig_df)/len(cc_df):.4f}")
print(f"Efficiency of background truth matching is: {len(bkg_df)/len(qq_df):.4f}")
print('')
print(f"Total events after truth matching: {len(combined_df)}")
print(f"Number of b-jets after truth matching: {len(sig_df)}")
# Out:
# Efficiency of signal truth matching is: 0.1930
# Efficiency of background truth matching is: 0.4125
#
# Total events after truth matching: 1211
# Number of b-jets after truth matching: 386

# %%
# Define feature columns including jet-level and daughter-level features
daughter_cols = [col for col in sig_df.columns if "_Daughters" in col]
svtag_cols = ['Jet0_SVtag_fdrMin',
 'Jet0_SVtag_ptSvrJet',
 'Jet0_SVtag_nTrk',
 'Jet0_SVtag_nTrkJet',
 'Jet0_SVtag_drSvrJet',
 'Jet0_SVtag_absQSum',
 'Jet0_SVtag_m',
 'Jet0_SVtag_mCor',
 'Jet0_SVtag_fdChi2',
 'Jet0_SVtag_ipChi2Sum',
 'Jet0_SVtag_tau',
 'Jet0_SVtag_z',
 'Jet0_SVtag_pt']
jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
feature_cols = daughter_cols + jet_cols

# Prepare features by converting daughter information to lists and duplicating jet-level features
def prepare_features(df, jet_cols, daughter_cols):
    # Duplicate data to lists matching the number of daughters/nodes per jet/row
    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)

    # Convert string values into list of floats
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)
    return df

df = prepare_features(combined_df, jet_cols, daughter_cols)

# %%
# Split data into training, validation, and test sets
sig_df = df[df['IsC'] == 1].sample(frac=1, random_state=42).reset_index(drop=True)
bkg_df = df[df['IsC'] == 0].sample(frac=1, random_state=42).reset_index(drop=True)

half_train_size = int((sum(combined_df.IsC)*0.8)/2)
half_test_size = int((sum(combined_df.IsC)*0.2)/2)

train_df = pd.concat([sig_df.head(half_train_size), bkg_df.head(half_train_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of training data is: {len(train_df)}')

test_df = pd.concat([sig_df.tail(half_test_size), bkg_df.tail(half_test_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of testing data is: {len(test_df)}')

validation_df = pd.concat([sig_df.iloc[half_train_size:-half_test_size], bkg_df.iloc[half_train_size:-half_test_size]]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of validation data is: {len(validation_df)}')
# Out:
# Length of training data is: 308
# Length of testing data is: 76
# Length of validation data is: 827

# %%
print('Ratio of c to b in datasets:')
print(f'    Training data: {sum(train_df.IsC)/len(train_df)}')
print(f'    Testing data: {sum(test_df.IsC)/len(test_df)}')
print(f'    Validation data: {sum(validation_df.IsC)/len(validation_df)}')
# Out:
# Ratio of c to b in datasets:
#     Training data: 0.5
#     Testing data: 0.5
#     Validation data: 0.23458282950423218

# %%
# Create graphs for training and testing
def create_graphs(df, feature_cols):

    features_list = []
    
    for _, row in df.iterrows():
        num_nodes = row['Jet0_nDaughters']
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    data_objects = []
    for idx, features in enumerate(features_list):

        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        # Create fully connected graph
        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()
        edge_weight = torch.tensor([df['weights'].iloc[idx]] * edge_index.size(1), dtype=torch.float) 

        y = torch.tensor([df['IsC'].iloc[idx]], dtype=torch.float)
        
        data = Data(x=x, edge_index=edge_index, y=y, num_nodes=num_nodes, edge_weight=edge_weight)
        data_objects.append(data)

    return data_objects

# Create graphs for training and testing
train_data = create_graphs(train_df, feature_cols)
test_data = create_graphs(test_df, feature_cols)

# Load data in batches
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %% [markdown]
# # Classifier

# %%
class GNN(torch.nn.Module):
    def __init__(self):
        super(GNN, self).__init__()
        hidden_channels = 64
        self.conv1 = GraphConv(len(feature_cols), hidden_channels)
        self.ln1 = LayerNorm(hidden_channels)
        self.conv2 = GraphConv(hidden_channels, hidden_channels)
        self.ln2 = LayerNorm(hidden_channels)
        self.conv3 = GraphConv(hidden_channels, hidden_channels)
        self.ln3 = LayerNorm(hidden_channels)
        self.conv4 = GraphConv(hidden_channels, hidden_channels)
        self.ln4 = LayerNorm(hidden_channels)
        self.lin = Linear(hidden_channels, 1)
        self.dropout = Dropout(0.3)

    def forward(self, x, edge_index, batch, edge_weight):        
        x = self.conv1(x, edge_index, edge_weight)
        x = self.ln1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv2(x, edge_index, edge_weight)
        x = self.ln2(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv3(x, edge_index, edge_weight)
        x = self.ln3(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv4(x, edge_index, edge_weight)
        x = self.ln4(x)
        x = F.relu(x)

        x = global_add_pool(x, batch)
        x = self.lin(x)
        return x.squeeze(1)
    
model = GNN()
model = model.to(device)

# %% [markdown]
# # Model Evaluation

# %%
# Define optimizer and loss function
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = nn.BCEWithLogitsLoss()
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5) # reduce lr by 0.5 every 5 epochs


# Training loop
def train():
    model.train()
    total_loss = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch, data.edge_weight)
        loss = criterion(out, data.y.float())
        clip_grad_norm_(model.parameters(), max_norm=0.5)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    return avg_loss

# Testing function
def test(loader):
    model.eval()
    total_correct = 0
    total_samples = 0
    total_loss = 0
    
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index, data.batch, data.edge_weight)
            loss = criterion(out, data.y.float())
            pred = (out > 0).float()
            correct = (pred.squeeze() == data.y.float()).sum().item()
            total_correct += correct
            total_samples += len(data.y)
            total_loss += loss.item() * data.num_graphs

        avg_loss = total_loss / len(loader.dataset)
        acc = total_correct / total_samples
    return avg_loss, acc

# Training parameters
num_epochs = 200

# Initialize lists for storing loss and accuracy values
train_loss_values = []
train_acc_values = []
test_loss_values = []
test_acc_values = []

# Training loop
for epoch in range(num_epochs):

    train_loss = train()
    train_loss_values.append(train_loss)

    train_acc = test(train_loader)[1]
    train_acc_values.append(train_acc)

    test_loss, test_acc = test(test_loader)
    test_loss_values.append(test_loss)
    test_acc_values.append(test_acc)

    scheduler.step(test_loss)

    print(f'Epoch: {epoch+1:03d}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')

    # Save the model and results every 50 epochs
    if (epoch + 1) % 50 == 0:
        # Overwrite the existing model file
        torch.save(model.state_dict(), 'cq50_model1.pth')
        print('Model saved as cq50_model1.pth.')

        # Save the loss and accuracy values to a CSV file, overwriting the existing file
        results_df = pd.DataFrame({
            'Epoch': list(range(1, epoch + 2)),
            'Train Loss': train_loss_values,
            'Test Loss': test_loss_values,
            'Train Accuracy': train_acc_values,
            'Test Accuracy': test_acc_values
        })
        results_df.to_csv('cq50_training1.csv', index=False)
        print('Training results saved as cq50_training1.csv.')

torch.save(model.state_dict(), 'cq50_model1.pth')
print('Model saved as cq50_model1.pth. Training complete.')

results_df = pd.DataFrame({
    'Epoch': list(range(1, num_epochs+1)),
    'Train Loss': train_loss_values,
    'Test Loss': test_loss_values,
    'Train Accuracy': train_acc_values,
    'Test Accuracy': test_acc_values
})

# Save the loss and accuracy values to a CSV file
results_df.to_csv('cq50_training1.csv', index=False)
print('Training results saved as cq50_training1.csv. Training complete.')
# Out:
# Epoch: 001, Train Loss: 1.7610, Test Loss: 2.1619, Train Acc: 0.5649, Test Acc: 0.5658
# Epoch: 002, Train Loss: 1.2901, Test Loss: 1.5040, Train Acc: 0.5682, Test Acc: 0.6184
# Epoch: 003, Train Loss: 1.0084, Test Loss: 1.0316, Train Acc: 0.5942, Test Acc: 0.6053
# Epoch: 004, Train Loss: 1.0098, Test Loss: 0.8940, Train Acc: 0.5877, Test Acc: 0.6579
# Epoch: 005, Train Loss: 1.0456, Test Loss: 1.0277, Train Acc: 0.5682, Test Acc: 0.5658
# Epoch: 006, Train Loss: 0.8878, Test Loss: 1.2175, Train Acc: 0.5455, Test Acc: 0.5789
# Epoch: 007, Train Loss: 0.8962, Test Loss: 1.1860, Train Acc: 0.5909, Test Acc: 0.6579
# Epoch: 008, Train Loss: 0.7570, Test Loss: 1.1352, Train Acc: 0.5974, Test Acc: 0.6579
# Epoch: 009, Train Loss: 0.9205, Test Loss: 1.1370, Train Acc: 0.6006, Test Acc: 0.6579
# Epoch: 010, Train Loss: 0.8490, Test Loss: 1.1174, Train Acc: 0.5877, Test Acc: 0.6711
# Epoch: 011, Train Loss: 0.8378, Test Loss: 1.1214, Train Acc: 0.6071, Test Acc: 0.6579
# Epoch: 012, Train Loss: 0.8221, Test Loss: 1.1158, Train Acc: 0.6136, Test Acc: 0.6579
# Epoch: 013, Train Loss: 0.8545, Test Loss: 1.0887, Train Acc: 0.6104, Test Acc: 0.6316
# Epoch: 014, Train Loss: 0.8733, Test Loss: 1.0813, Train Acc: 0.6071, Test Acc: 0.6316
# Epoch: 015, Train Loss: 0.8247, Test Loss: 1.0839, Train Acc: 0.6071, Test Acc: 0.6316
# Epoch: 016, Train Loss: 0.8827, Test Loss: 1.1120, Train Acc: 0.6104, Test Acc: 0.6316
# Epoch: 017, Train Loss: 0.7524, Test Loss: 1.1193, Train Acc: 0.6104, Test Acc: 0.6316
# Epoch: 018, Train Loss: 0.7586, Test Loss: 1.1173, Train Acc: 0.6104, Test Acc: 0.6316
# Epoch: 019, Train Loss: 0.8163, Test Loss: 1.1208, Train Acc: 0.6071, Test Acc: 0.6316
# Epoch: 020, Train Loss: 0.8099, Test Loss: 1.1203, Train Acc: 0.6104, Test Acc: 0.6316
# Epoch: 021, Train Loss: 0.8407, Test Loss: 1.1260, Train Acc: 0.6104, Test Acc: 0.6316
# Epoch: 022, Train Loss: 0.8093, Test Loss: 1.1250, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 023, Train Loss: 0.7807, Test Loss: 1.1220, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 024, Train Loss: 0.8155, Test Loss: 1.1176, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 025, Train Loss: 0.8380, Test Loss: 1.1095, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 026, Train Loss: 0.7909, Test Loss: 1.1064, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 027, Train Loss: 0.7618, Test Loss: 1.1000, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 028, Train Loss: 0.7490, Test Loss: 1.0992, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 029, Train Loss: 0.7801, Test Loss: 1.1015, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 030, Train Loss: 0.8625, Test Loss: 1.1021, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 031, Train Loss: 0.7903, Test Loss: 1.1010, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 032, Train Loss: 0.7934, Test Loss: 1.1043, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 033, Train Loss: 0.7468, Test Loss: 1.1041, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 034, Train Loss: 0.7173, Test Loss: 1.1046, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 035, Train Loss: 0.7835, Test Loss: 1.1049, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 036, Train Loss: 0.8225, Test Loss: 1.1071, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 037, Train Loss: 0.7726, Test Loss: 1.1085, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 038, Train Loss: 0.7943, Test Loss: 1.1103, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 039, Train Loss: 0.7420, Test Loss: 1.1111, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 040, Train Loss: 0.7470, Test Loss: 1.1103, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 041, Train Loss: 0.8188, Test Loss: 1.1104, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 042, Train Loss: 0.7572, Test Loss: 1.1096, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 043, Train Loss: 0.7884, Test Loss: 1.1092, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 044, Train Loss: 0.7808, Test Loss: 1.1091, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 045, Train Loss: 0.7875, Test Loss: 1.1095, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 046, Train Loss: 0.7527, Test Loss: 1.1098, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 047, Train Loss: 0.7103, Test Loss: 1.1097, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 048, Train Loss: 0.7359, Test Loss: 1.1094, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 049, Train Loss: 0.7595, Test Loss: 1.1089, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 050, Train Loss: 0.7901, Test Loss: 1.1085, Train Acc: 0.6169, Test Acc: 0.6316
# Model saved as cq50_model1.pth.
# Training results saved as cq50_training1.csv.
# Epoch: 051, Train Loss: 0.8485, Test Loss: 1.1081, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 052, Train Loss: 0.7883, Test Loss: 1.1079, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 053, Train Loss: 0.7768, Test Loss: 1.1079, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 054, Train Loss: 0.7721, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 055, Train Loss: 0.7458, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 056, Train Loss: 0.8226, Test Loss: 1.1076, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 057, Train Loss: 0.7833, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 058, Train Loss: 0.7147, Test Loss: 1.1076, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 059, Train Loss: 0.7584, Test Loss: 1.1076, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 060, Train Loss: 0.8180, Test Loss: 1.1075, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 061, Train Loss: 0.7934, Test Loss: 1.1075, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 062, Train Loss: 0.7639, Test Loss: 1.1075, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 063, Train Loss: 0.8237, Test Loss: 1.1076, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 064, Train Loss: 0.7883, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 065, Train Loss: 0.7821, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 066, Train Loss: 0.7315, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 067, Train Loss: 0.7799, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 068, Train Loss: 0.7399, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 069, Train Loss: 0.8156, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 070, Train Loss: 0.7842, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 071, Train Loss: 0.7671, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 072, Train Loss: 0.7726, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 073, Train Loss: 0.7535, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 074, Train Loss: 0.7494, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 075, Train Loss: 0.8210, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 076, Train Loss: 0.7373, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 077, Train Loss: 0.7858, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 078, Train Loss: 0.8293, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 079, Train Loss: 0.7241, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 080, Train Loss: 0.7847, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 081, Train Loss: 0.7958, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 082, Train Loss: 0.7281, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 083, Train Loss: 0.7549, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 084, Train Loss: 0.7947, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 085, Train Loss: 0.7415, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 086, Train Loss: 0.8238, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 087, Train Loss: 0.7761, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 088, Train Loss: 0.8096, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 089, Train Loss: 0.7479, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 090, Train Loss: 0.7187, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 091, Train Loss: 0.8436, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 092, Train Loss: 0.8402, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 093, Train Loss: 0.8189, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 094, Train Loss: 0.7622, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 095, Train Loss: 0.7694, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 096, Train Loss: 0.7680, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 097, Train Loss: 0.7831, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 098, Train Loss: 0.7812, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 099, Train Loss: 0.8533, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 100, Train Loss: 0.7615, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Model saved as cq50_model1.pth.
# Training results saved as cq50_training1.csv.
# Epoch: 101, Train Loss: 0.7696, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 102, Train Loss: 0.7938, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 103, Train Loss: 0.7835, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 104, Train Loss: 0.7671, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 105, Train Loss: 0.7221, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 106, Train Loss: 0.7557, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 107, Train Loss: 0.8170, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 108, Train Loss: 0.7848, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 109, Train Loss: 0.7191, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 110, Train Loss: 0.7612, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 111, Train Loss: 0.8083, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 112, Train Loss: 0.7878, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 113, Train Loss: 0.7349, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 114, Train Loss: 0.7499, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 115, Train Loss: 0.7770, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 116, Train Loss: 0.7905, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 117, Train Loss: 0.7478, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 118, Train Loss: 0.7658, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 119, Train Loss: 0.7896, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 120, Train Loss: 0.7841, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 121, Train Loss: 0.8135, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 122, Train Loss: 0.8211, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 123, Train Loss: 0.8160, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 124, Train Loss: 0.8280, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 125, Train Loss: 0.7434, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 126, Train Loss: 0.7441, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 127, Train Loss: 0.7222, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 128, Train Loss: 0.7014, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 129, Train Loss: 0.8209, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 130, Train Loss: 0.7941, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 131, Train Loss: 0.8016, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 132, Train Loss: 0.7466, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 133, Train Loss: 0.8424, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 134, Train Loss: 0.7084, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 135, Train Loss: 0.7395, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 136, Train Loss: 0.7194, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 137, Train Loss: 0.8137, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 138, Train Loss: 0.7222, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 139, Train Loss: 0.7771, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 140, Train Loss: 0.7069, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 141, Train Loss: 0.7332, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 142, Train Loss: 0.7373, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 143, Train Loss: 0.7419, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 144, Train Loss: 0.7782, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 145, Train Loss: 0.7977, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 146, Train Loss: 0.7521, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 147, Train Loss: 0.7776, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 148, Train Loss: 0.9192, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 149, Train Loss: 0.8483, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 150, Train Loss: 0.7811, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Model saved as cq50_model1.pth.
# Training results saved as cq50_training1.csv.
# Epoch: 151, Train Loss: 0.8065, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 152, Train Loss: 0.7681, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 153, Train Loss: 0.7828, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 154, Train Loss: 0.8487, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 155, Train Loss: 0.8018, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 156, Train Loss: 0.7837, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 157, Train Loss: 0.7755, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 158, Train Loss: 0.8273, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 159, Train Loss: 0.7681, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 160, Train Loss: 0.7331, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 161, Train Loss: 0.7878, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 162, Train Loss: 0.7574, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 163, Train Loss: 0.7512, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 164, Train Loss: 0.7547, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 165, Train Loss: 0.7381, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 166, Train Loss: 0.7844, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 167, Train Loss: 0.8220, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 168, Train Loss: 0.8473, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 169, Train Loss: 0.7838, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 170, Train Loss: 0.8631, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 171, Train Loss: 0.7379, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 172, Train Loss: 0.8465, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 173, Train Loss: 0.7210, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 174, Train Loss: 0.8240, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 175, Train Loss: 0.8152, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 176, Train Loss: 0.7639, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 177, Train Loss: 0.7437, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 178, Train Loss: 0.7992, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 179, Train Loss: 0.7542, Test Loss: 1.1078, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 180, Train Loss: 0.7399, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 181, Train Loss: 0.7620, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 182, Train Loss: 0.8221, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 183, Train Loss: 0.7902, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 184, Train Loss: 0.8118, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 185, Train Loss: 0.8860, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 186, Train Loss: 0.8458, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 187, Train Loss: 0.8062, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 188, Train Loss: 0.7606, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 189, Train Loss: 0.7508, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 190, Train Loss: 0.7853, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 191, Train Loss: 0.8078, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 192, Train Loss: 0.8026, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 193, Train Loss: 0.7853, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 194, Train Loss: 0.8210, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 195, Train Loss: 0.8030, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 196, Train Loss: 0.7528, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 197, Train Loss: 0.8296, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 198, Train Loss: 0.6952, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 199, Train Loss: 0.7849, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Epoch: 200, Train Loss: 0.8015, Test Loss: 1.1077, Train Acc: 0.6169, Test Acc: 0.6316
# Model saved as cq50_model1.pth.
# Training results saved as cq50_training1.csv.
# Model saved as cq50_model1.pth. Training complete.
# Training results saved as cq50_training1.csv. Training complete.

# %% [markdown]
# # Model Evaluation

# %%
# Reload training data to produce plots
training = pd.read_csv('cq50_training1.csv')
train_loss_values = training['Train Loss'].to_list()
test_loss_values = training['Test Loss'].to_list()
train_acc_values = training['Train Accuracy'].to_list()
test_acc_values = training['Test Accuracy'].to_list()

# %%
# Plot Loss and Accuracy
def plot_training_results():
    epochs = range(1, len(train_loss_values) + 1)

    mean_train_loss = np.mean(train_loss_values)
    mean_test_loss = np.mean(test_loss_values)
    mean_train_acc = np.mean(train_acc_values)
    mean_test_acc = np.mean(test_acc_values)

    min_train_loss = min(train_loss_values)
    min_test_loss = min(test_loss_values)
    max_train_acc = max(train_acc_values)
    max_test_acc = max(test_acc_values)

    final_train_loss = train_loss_values[-1]
    final_test_loss = test_loss_values[-1]
    final_train_acc = train_acc_values[-1]
    final_test_acc = test_acc_values[-1]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    #fig.suptitle('Training Results', fontsize=16)

    # Plot Loss
    ax1.plot(epochs, train_loss_values, color='darkred', label=(f"Training Loss (min = {min_train_loss:.4f})"))
    ax1.plot(epochs, test_loss_values, color='mediumblue', label=(f"Testing Loss (min = {min_test_loss:.4f})"))

    ax1.text(0.15, 0.90, "LHCb Simulation", transform=ax1.transAxes, fontsize=14, verticalalignment='bottom')

    ax1.set_title('Loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='best')

    # Plot  Accuracy
    ax2.plot(epochs, train_acc_values, color='darkred', label=(f"Training Accuracy (max = {max_train_acc:.4f})"))
    ax2.plot(epochs, test_acc_values, color='mediumblue', label=(f"Testing Accuracy (max = {max_test_acc:.4})"))

    ax2.text(0.7, 0.15, "LHCb Simulation", transform=ax2.transAxes, fontsize=14, verticalalignment='bottom')

    ax2.set_title(' Accuracy')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.legend(loc='best')

    plt.style.use('default')
    plt.tight_layout()
    plt.show()
    
# After your training loop, call the function:
plot_training_results()

# %%
# Get model predictions
y_true = []  # class values (0 or 1)
y_scores = []  # predicted probabilities or scores

model.load_state_dict(torch.load('cq50_model1.pth'))
model = model.to('cpu')
model.eval()
with torch.no_grad():
    for data in test_loader:
        out = model(data.x, data.edge_index, data.batch, data.edge_weight)
        prob = torch.sigmoid(out)
        
        y_true.append(data.y.numpy().flatten())
        y_scores.append(prob.numpy().flatten())

y_true = np.concatenate(y_true)
y_scores = np.concatenate(y_scores)

fpr, tpr, thresholds = roc_curve(y_true, y_scores)
auc = roc_auc_score(y_true, y_scores)

# Save each array separately
np.save('cq50_fpr.npy', fpr)
np.save('cq50_tpr.npy', tpr)
np.save('cq50_thresholds.npy', thresholds)
np.save('cq50_auc.npy', auc)

# %%
# Get FPRs for TPRs
desired_tpr = [0.85, 0.80, 0.75, 0.70, 0.65, 0.60]

print("Efficiency | FPR ")
for val in desired_tpr:
    # Find the index of the closest TPR to the desired TPR value
    closest_index = np.argmin(np.abs(tpr - val))

    # Get the chosen threshold and corresponding FPR, where the threshold is the probability cutoff
    chosen_threshold = thresholds[closest_index]
    given_fpr = fpr[closest_index]
    print(f"{val}: {given_fpr:.4f}")
# Out:
# Efficiency | FPR
# 0.85: 0.8421
# 0.8: 0.7632
# 0.75: 0.6842
# 0.7: 0.6316
# 0.65: 0.6053
# 0.6: 0.4211

# %%
chosen_tpr = 0.75
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pb {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.75: Pb 0.0309: FPR 0.6842

# %%
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)

cm_percentage = cm.astype(float) / cm.sum(axis=1)[:, np.newaxis] * 100

annot_labels = np.empty_like(cm, dtype=object)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        percentage = cm_percentage[i, j]
        annot_labels[i, j] = f'{percentage:.1f}%'

fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm_percentage, annot=annot_labels, fmt='', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr*100}% Efficiency")

ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)
df_cm = pd.DataFrame(cm)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr*100}% Efficiency")

# Add TP, FP, FN, TN labels
ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
# Plot ROC Curve and show AUC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='navy', label=f'ROC curve (AUC = {auc:.4f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--', label='Baseline (AUC = 0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.style.use('default')
plt.ylabel('Signal Efficiency')
plt.xlabel('False Positive Rate (FPR)')
plt.title('Receiver Operating Characteristics (ROC)')
plt.text(0.85, 0.15, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.legend(loc='lower right')
plt.show()

# %%
# Prepare model
model.eval()
data = next(iter(test_loader))
x, edge_index, batch = data.x, data.edge_index, data.batch

G = nx.Graph()
edges = list(zip(edge_index[0].numpy(), edge_index[1].numpy()))
G.add_edges_from(edges)

feature_importances = np.zeros(x.size(1))

for feature_idx in range(x.size(1)):
    x_perturbed = x.clone()
    x_perturbed[:, feature_idx] = 0

    # Predict with original features
    with torch.no_grad():
        orig_pred = model(x, edge_index, batch, None)
        perturbed_pred = model(x_perturbed, edge_index, batch, None)

    # Compute importance - difference in predictions
    importance = torch.mean(torch.abs(orig_pred - perturbed_pred))
    feature_importances[feature_idx] = importance

importance_df = pd.DataFrame({'Feature': feature_cols, 'Importance': feature_importances})
print(importance_df)

plt.figure(figsize=(12, 12))
sns.barplot(x='Importance', y='Feature', data=importance_df, palette='viridis', hue='Feature', dodge=False)
plt.title('Feature Importance', fontsize=15)
plt.text(0.87, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.xlabel('Importance', fontsize=15)
plt.ylabel('Feature', fontsize=15)
plt.show()
# Out:
#                                 Feature    Importance
# 0                      Jet0_Daughters_E  4.483970e-01
# 1                     Jet0_Daughters_pT  1.147501e-02
# 2                     Jet0_Daughters_ID  6.548377e-03
# 3                     Jet0_Daughters_pX  1.016177e-02
# 4                     Jet0_Daughters_pY  8.224835e-03
# 5                     Jet0_Daughters_pZ  2.834620e-01
# 6                    Jet0_Daughters_Eta  1.140535e-04
# 7                    Jet0_Daughters_Phi  3.156764e-05
# 8                      Jet0_Daughters_Q  1.771282e-05
# 9                     Jet0_Daughters_IP  1.996245e-03
# 10                Jet0_Daughters_IPCHI2  1.986254e-01
# 11                 Jet0_Daughters_IPraw  1.778343e-03
# 12                   Jet0_Daughters_NNe  3.593261e-02
# 13                   Jet0_Daughters_NNk  1.294273e-02
# 14                   Jet0_Daughters_NNp  1.036427e-02
# 15                  Jet0_Daughters_NNpi  3.156755e-02
# 16                  Jet0_Daughters_NNmu  4.262396e-02
# 17                  Jet0_Daughters_Chi2  3.617143e-02
# 18                Jet0_Daughters_QoverP  1.860290e-02
# 19                Jet0_Daughters_trackX  1.889512e-02
# 20                Jet0_Daughters_trackY  1.610513e-02
# 21                Jet0_Daughters_trackZ  3.471444e-02
# 22               Jet0_Daughters_trackVX  2.804223e-02
# 23               Jet0_Daughters_trackVY  2.060939e-02
# 24               Jet0_Daughters_trackVZ  3.084258e-01
# 25       Jet0_Daughters_CaloNeutralEcal  6.799856e-02
# 26  Jet0_Daughters_CaloNeutralHcal2Ecal  3.963295e-02
# 27        Jet0_Daughters_CaloNeutralE49  1.848730e-02
# 28        Jet0_Daughters_CaloNeutralPrs  1.595242e-02
# 29                             Jet0_Eta  2.066987e-04
# 30                              Jet0_PT  1.173103e+00
# 31                    Jet0_SVtag_fdrMin  7.018447e-06
# 32                  Jet0_SVtag_ptSvrJet  1.791865e-06
# 33                      Jet0_SVtag_nTrk  6.416813e-06
# 34                   Jet0_SVtag_nTrkJet  6.455928e-06
# 35                  Jet0_SVtag_drSvrJet  3.743917e-07
# 36                   Jet0_SVtag_absQSum  6.031245e-06
# 37                         Jet0_SVtag_m  5.376734e-03
# 38                      Jet0_SVtag_mCor  6.292072e-03
# 39                    Jet0_SVtag_fdChi2  5.691937e-02
# 40                 Jet0_SVtag_ipChi2Sum  4.198827e-03
# 41                       Jet0_SVtag_tau  5.587935e-07
# 42                         Jet0_SVtag_z  2.191179e-04
# 43                        Jet0_SVtag_pt  3.608808e-02

# %%
for index, row in importance_df.iterrows():
    feature = row['Feature'] 
    importance = row['Importance']
    if importance > 0.25:
        print(f'{feature} & {importance:4f}')
# Out:
# Jet0_Daughters_E & 0.448397
# Jet0_Daughters_pZ & 0.283462
# Jet0_Daughters_trackVZ & 0.308426
# Jet0_PT & 1.173103

# %% [markdown]
# # Model Probability Output

# %%
df = validation_df
chosen_threshold = 0.5

def make_predictions():
    # Select a random integer for sampling
    random_integer = np.random.randint(0, len(df))
    sample_jet = df.iloc[random_integer:random_integer+1].copy()

    # Filter columns related to Jet0
    sample_jet = sample_jet.filter(like='Jet0')

    # Define feature columns
    daughter_cols = [col for col in sample_jet.columns if "_Daughters" in col]
    svtag_cols = ['Jet0_SVtag_fdrMin',
    'Jet0_SVtag_ptSvrJet',
    'Jet0_SVtag_nTrk',
    'Jet0_SVtag_nTrkJet',
    'Jet0_SVtag_drSvrJet',
    'Jet0_SVtag_absQSum',
    'Jet0_SVtag_m',
    'Jet0_SVtag_mCor',
    'Jet0_SVtag_fdChi2',
    'Jet0_SVtag_ipChi2Sum',
    'Jet0_SVtag_tau',
    'Jet0_SVtag_z',
    'Jet0_SVtag_pt']
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    for col in jet_cols:
        sample_jet[col] = sample_jet.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)
    for col in daughter_cols:
        sample_jet[col] = sample_jet[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Obtain features of each node within the graph
    features_list = []
    for _, row in sample_jet.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    # Create graph representation with data objects
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch, data.edge_weight)
            probability = torch.sigmoid(output)
            prediction = (probability > chosen_threshold).int()

    print(f'Probability: {probability.item()}')
    if prediction.item() == 1:  
        print(f'Prediction: c-jet')
    if prediction.item() == 0:  
        print(f'Prediction: q-jet')
    return probability.item()

i = 0

for i in range(100):
    make_predictions()
# Out:
# Probability: 0.3698863983154297
# Prediction: q-jet
# Probability: 0.5829692482948303
# Prediction: c-jet
# Probability: 0.3336305618286133
# Prediction: q-jet
# Probability: 0.6423621773719788
# Prediction: c-jet
# Probability: 0.5451791286468506
# Prediction: c-jet
# Probability: 0.6657623052597046
# Prediction: c-jet
# Probability: 0.5389817357063293
# Prediction: c-jet
# Probability: 0.08860411494970322
# Prediction: q-jet
# Probability: 0.6823574304580688
# Prediction: c-jet
# Probability: 0.13333003222942352
# Prediction: q-jet
# Probability: 0.7299748063087463
# Prediction: c-jet
# Probability: 0.31355828046798706
# Prediction: q-jet
# Probability: 0.5281983613967896
# Prediction: c-jet
# Probability: 0.8953631520271301
# Prediction: c-jet
# Probability: 0.20489244163036346
# Prediction: q-jet
# Probability: 0.6033547520637512
# Prediction: c-jet
# Probability: 0.449266254901886
# Prediction: q-jet
# Probability: 0.30883726477622986
# Prediction: q-jet
# Probability: 0.5580857396125793
# Prediction: c-jet
# Probability: 0.2032971829175949
# Prediction: q-jet
# Probability: 0.4414881765842438
# Prediction: q-jet
# Probability: 0.4708870053291321
# Prediction: q-jet
# Probability: 0.6856200695037842
# Prediction: c-jet
# Probability: 0.35339871048927307
# Prediction: q-jet
# Probability: 0.4318370819091797
# Prediction: q-jet
# Probability: 0.40533941984176636
# Prediction: q-jet
# Probability: 0.2336723953485489
# Prediction: q-jet
# Probability: 0.49147284030914307
# Prediction: q-jet
# Probability: 0.1509094387292862
# Prediction: q-jet
# Probability: 0.33515700697898865
# Prediction: q-jet
# Probability: 0.3968677222728729
# Prediction: q-jet
# Probability: 0.21159318089485168
# Prediction: q-jet
# Probability: 0.575340986251831
# Prediction: c-jet
# Probability: 0.28973010182380676
# Prediction: q-jet
# Probability: 0.40797242522239685
# Prediction: q-jet
# Probability: 0.39718520641326904
# Prediction: q-jet
# Probability: 0.6344268918037415
# Prediction: c-jet
# Probability: 0.3588353097438812
# Prediction: q-jet
# Probability: 0.40021541714668274
# Prediction: q-jet
# Probability: 0.5690521597862244
# Prediction: c-jet
# Probability: 0.4318229854106903
# Prediction: q-jet
# Probability: 0.40533941984176636
# Prediction: q-jet
# Probability: 0.5897767543792725
# Prediction: c-jet
# Probability: 0.023533891886472702
# Prediction: q-jet
# Probability: 0.920369029045105
# Prediction: c-jet
# Probability: 0.18361715972423553
# Prediction: q-jet
# Probability: 0.6330671310424805
# Prediction: c-jet
# Probability: 0.7606053948402405
# Prediction: c-jet
# Probability: 0.4139969050884247
# Prediction: q-jet
# Probability: 0.2032971829175949
# Prediction: q-jet
# Probability: 0.7070095539093018
# Prediction: c-jet
# Probability: 0.7263719439506531
# Prediction: c-jet
# Probability: 0.4139969050884247
# Prediction: q-jet
# Probability: 0.3544597923755646
# Prediction: q-jet
# Probability: 0.7417396306991577
# Prediction: c-jet
# Probability: 0.3426056206226349
# Prediction: q-jet
# Probability: 0.5840315818786621
# Prediction: c-jet
# Probability: 0.7299748063087463
# Prediction: c-jet
# Probability: 0.7070095539093018
# Prediction: c-jet
# Probability: 0.13260996341705322
# Prediction: q-jet
# Probability: 0.7636262774467468
# Prediction: c-jet
# Probability: 0.559560239315033
# Prediction: c-jet
# Probability: 0.2961483895778656
# Prediction: q-jet
# Probability: 0.3427445888519287
# Prediction: q-jet
# Probability: 0.5791411399841309
# Prediction: c-jet
# Probability: 0.2121732234954834
# Prediction: q-jet
# Probability: 0.6657623052597046
# Prediction: c-jet
# Probability: 0.09092281013727188
# Prediction: q-jet
# Probability: 0.2209296077489853
# Prediction: q-jet
# Probability: 0.6626256704330444
# Prediction: c-jet
# Probability: 0.5590673089027405
# Prediction: c-jet
# Probability: 0.5897767543792725
# Prediction: c-jet
# Probability: 0.515718936920166
# Prediction: c-jet
# Probability: 0.13258816301822662
# Prediction: q-jet
# Probability: 0.6343696713447571
# Prediction: c-jet
# Probability: 0.515718936920166
# Prediction: c-jet
# Probability: 0.3852601945400238
# Prediction: q-jet
# Probability: 0.3336305618286133
# Prediction: q-jet
# Probability: 0.4221831262111664
# Prediction: q-jet
# Probability: 0.6231136918067932
# Prediction: c-jet
# Probability: 0.35791078209877014
# Prediction: q-jet
# Probability: 0.4318370819091797
# Prediction: q-jet
# Probability: 0.0222608782351017
# Prediction: q-jet
# Probability: 0.6085602641105652
# Prediction: c-jet
# Probability: 0.708589494228363
# Prediction: c-jet
# Probability: 0.4966352880001068
# Prediction: q-jet
# Probability: 0.6680716276168823
# Prediction: c-jet
# Probability: 0.7409933805465698
# Prediction: c-jet
# Probability: 0.5557634234428406
# Prediction: c-jet
# Probability: 0.26081496477127075
# Prediction: q-jet
# Probability: 0.8382133841514587
# Prediction: c-jet
# Probability: 0.5829692482948303
# Prediction: c-jet
# Probability: 0.13258816301822662
# Prediction: q-jet
# Probability: 0.5834192037582397
# Prediction: c-jet
# Probability: 0.6330671310424805
# Prediction: c-jet
# Probability: 0.7442609071731567
# Prediction: c-jet
# Probability: 0.14849528670310974
# Prediction: q-jet
# Probability: 0.7137380242347717
# Prediction: c-jet
# Probability: 0.14716807007789612
# Prediction: q-jet
# Probability: 0.589769184589386
# Prediction: c-jet

# %% [markdown]
# # Create Efficiency Plot

# %%
model.load_state_dict(torch.load('cq50_model1.pth'))
model = model.to('cpu')

# %%
# Separate b and q data from testing dataset (preprocessed)
c = test_df[test_df.IsC == 1]
q = test_df[test_df.IsC == 0]

c_data = create_graphs(c, feature_cols)
q_data = create_graphs(q, feature_cols)

c_prob = []
q_prob = []

def get_probabilities(data_list):
    prob_list = []
    model.eval()
    with torch.no_grad():
        for data in data_list:
            out = model(data.x, data.edge_index, data.batch, data.edge_weight)
            prob = torch.sigmoid(out).numpy().flatten()
            prob_list.append(prob)
    return np.concatenate(prob_list)

# Compute probabilities for b and q data
c_prob = get_probabilities(c_data)
q_prob = get_probabilities(q_data)

# %%
def plot_probability_distribution(c_prob, q_prob, target_efficiencies):

    # Sort c-jet probabilities in descending order for cutoff calculations
    sorted_c_prob = np.sort(c_prob)[::-1]
    
    # Calculate cutoffs for each efficiency level
    cutoffs = {}
    for efficiency in target_efficiencies:
        cutoff_index = int(len(sorted_c_prob) * efficiency)
        cutoffs[efficiency] = sorted_c_prob[cutoff_index - 1] if cutoff_index > 0 else sorted_c_prob[0]
    
    # Plot histograms for c-jet and q-jet probabilities
    plt.figure(figsize=(10, 6))
    c_values, c_bins, _ = plt.hist(c_prob, bins=100, label='c-jets', color='darkred', histtype='step')
    q_values, q_bins, _ = plt.hist(q_prob, bins=100, label='q-jets', color='mediumblue', histtype='step')

    max_y = max(max(c_values), max(q_values))
    
    # Mark cutoffs for selected efficiencies
    for i, (efficiency, cutoff) in enumerate(cutoffs.items()):
        plt.vlines(x=cutoff, ymin=0, ymax=max_y * 0.3, color='grey', linestyle='--', linewidth=1)
        plt.text(cutoff, max_y*0.3, f'{int(efficiency * 100)}%', ha='center', va='bottom', rotation=90)

    plt.xlabel("P$_c$")
    plt.ylabel("Number of Jets")
    plt.text(0.9, max_y * 0.8, "LHCb Simulation", fontsize=14, verticalalignment='bottom', horizontalalignment='right')
    plt.title("Probability Distribution")
    plt.yscale('log')
    plt.legend(loc='best')
    plt.show()

target_efficiencies = [0.6, 0.7, 0.8]
plot_probability_distribution(c_prob, q_prob, target_efficiencies)

# %%
chosen_tpr = 0.75
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pc {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.75: Pc 0.0309: FPR 0.6842

# %%
c = test_df[test_df.IsC == 1]
c.loc[:, 'Jet0_PT'] = c['Jet0_PT'].apply(lambda x: x[0] if isinstance(x, list) else x)

pt23_df = c[(c['Jet0_PT'].between(20000, 30000))].reset_index(drop=True)
pt34_df = c[(c['Jet0_PT'].between(30000, 40000))].reset_index(drop=True)
pt45_df = c[(c['Jet0_PT'].between(40000, 50000))].reset_index(drop=True)
pt50_df = c[(c['Jet0_PT'].between(50000, 100000))].reset_index(drop=True)

# %%
def make_predictions(df):
    daughter_cols = [col for col in df.columns if "_Daughters" in col]
    svtag_cols = [
        'Jet0_SVtag_fdrMin',
        'Jet0_SVtag_ptSvrJet',
        'Jet0_SVtag_nTrk',
        'Jet0_SVtag_nTrkJet',
        'Jet0_SVtag_drSvrJet',
        'Jet0_SVtag_absQSum',
        'Jet0_SVtag_m',
        'Jet0_SVtag_mCor',
        'Jet0_SVtag_fdChi2',
        'Jet0_SVtag_ipChi2Sum',
        'Jet0_SVtag_tau',
        'Jet0_SVtag_z',
        'Jet0_SVtag_pt'
    ]
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Get features of each node within the graph
    features_list = []
    for _, row in df.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()
        edge_weight = torch.ones(edge_index.size(1), dtype=torch.float)

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    num_c = 0
    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch, data.edge_weight)
            probability = torch.sigmoid(output)
            prediction = (probability > chosen_threshold).int()

            if prediction.item() == 1:  
                num_c += 1

    return num_c

# %%
num_c23 = make_predictions(pt23_df)
num_c34 = make_predictions(pt34_df)
num_c45 = make_predictions(pt45_df)
num_c50 = make_predictions(pt50_df)

efficiency23 = num_c23 / len(pt23_df)
efficiency34 = num_c34 / len(pt34_df)
efficiency45 = num_c45 / len(pt45_df)
efficiency50 = num_c50 / len(pt50_df)

print(f'Efficiency for pT 20-30 GeV: {efficiency23:.4f}')
print(f'Efficiency for pT 30-40 GeV: {efficiency34:.4f}')
print(f'Efficiency for pT 40-50 GeV: {efficiency45:.4f}')
print(f'Efficiency for pT 50-100 GeV: {efficiency50:.4f}')

# %%
def plot_efficiency_histogram(efficiencies, pt_bins):
    plt.figure(figsize=(10, 6))

    # Calculate bin centers and widths
    bin_centers = (pt_bins[:-1] + pt_bins[1:]) / 2
    bar_width = np.diff(pt_bins)  # Width of the bins

    # Create the histogram by plotting only the tops of the bins
    for i in range(len(efficiencies)):
        plt.plot([pt_bins[i], pt_bins[i+1]], [efficiencies[i], efficiencies[i]], color='blue', linewidth=2)
    plt.xticks(np.arange(20000, 101000, 10000))
    plt.xlabel('pT (GeV)')
    plt.ylabel('Efficiency')
    plt.text(0.85, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
    plt.title('Efficiency for c-jets at 75% TPR')
    plt.ylim(0, 1.1)
    plt.xlim(20000, 100000)
    plt.show()

# Custom bin ranges (with unequal bins for the upper range)
pt_bins = np.array([20000, 30000, 40000, 50000, 100000])
efficiencies = [efficiency23, efficiency34, efficiency45, efficiency50]

plot_efficiency_histogram(efficiencies, pt_bins)
