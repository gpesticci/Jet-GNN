# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.nn import Linear, Dropout, LayerNorm
import torch.nn.functional as F
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import SAGEConv, global_add_pool
from torch.nn.utils import clip_grad_norm_
from torch.optim.lr_scheduler import ReduceLROnPlateau

import networkx as nx
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix
import seaborn as sns
import random
import uproot

# %%
torch.cuda.is_available()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
path_to_tree = "DecayTreeTuple/tuple"

def rename_columns(df):
    new_columns = {}
    for col in df.columns:
        if "_BDTTag_" in col:
            new_columns[col] = col.replace("_BDTTag_", "_SVtag_")
    df.rename(columns=new_columns, inplace=True)

# maybe don't need
def extract_float(awk_array):
    return awk_array[0] if len(awk_array) > 0 else None

# %%
# Read the ROOT file
tree = uproot.open("Dijet_bb_pt20_50_dw.root" + ":" + path_to_tree)
bb_df = tree.arrays(tree.keys(), library="pd")#, entry_start=0, entry_stop=1000) 

# Clean column names and remove unwanted columns
bb_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in bb_df.columns]
rename_columns(bb_df)
columns_to_remove = [col for col in bb_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
bb_df.drop(columns=columns_to_remove, inplace=True)
for col in bb_df.columns:
    if "SVtag" in col:
        bb_df[col] = bb_df[col].apply(extract_float)
tree.close()

# Read the ROOT file
tree = uproot.open("Dijet_qq_pt20_50_dw.root" + ":" + path_to_tree)
qq_df = tree.arrays(tree.keys(), library="pd")#, entry_start=0, entry_stop=1000) 

# Clean column names and remove unwanted columns
qq_df.columns = [col.rstrip('_') if col.endswith('_') else col for col in qq_df.columns]
rename_columns(qq_df)
columns_to_remove = [col for col in qq_df.columns if (col.startswith("H_10") or col.endswith("COV") or ("Decision" in col) or col.endswith("Tag") or col.endswith("NbTag") )]
qq_df.drop(columns=columns_to_remove, inplace=True)
for col in qq_df.columns:
    if "SVtag" in col:
        qq_df[col] = qq_df[col].apply(extract_float)
tree.close()
# 18m
# Out:
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# ...
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# /data/home/pesticci/.conda/envs/gnn_env/lib/python3.9/site-packages/uproot/interpretation/library.py:795: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   out[name] = series[name]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#      10 for col in bb_df.columns:
#      11     if "SVtag" in col:
# ---> 12         bb_df[col] = bb_df[col].apply(extract_float)
#      13 tree.close()
#      15 # Read the ROOT file
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/base.py:919, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     916 arr = self._values
#     918 if isinstance(arr, ExtensionArray):
# --> 919     return arr.map(mapper, na_action=na_action)
#     921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/arrays/base.py:2322, in ExtensionArray.map(self, mapper, na_action)
#    2302 def map(self, mapper, na_action=None):
#    2303     """
#    2304     Map values using an input mapping or function.
#    2305
#    (...)
#    2320         a MultiIndex will be returned.
#    2321     """
# -> 2322     return map_array(self, mapper, na_action=na_action)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/algorithms.py:1741, in map_array(arr, mapper, na_action, convert)
#    1738     return arr.copy()
#    1740 # we must convert to python types
# -> 1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
#    1743     return lib.map_infer(values, mapper, convert=convert)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/pandas/core/arrays/base.py:723, in ExtensionArray.astype(self, dtype, copy)
#     720     return TimedeltaArray._from_sequence(self, dtype=dtype, copy=copy)
#     722 if not copy:
# --> 723     return np.asarray(self, dtype=dtype)
#     724 else:
#     725     return np.array(self, dtype=dtype, copy=copy)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward_pandas/array.py:144, in AwkwardExtensionArray.__array__(self, dtype)
#     141 dtype = np.dtype(object) if dtype is None else np.dtype(dtype)
#     143 if dtype == np.dtype("O"):
# --> 144     return np.asarray(self._data.tolist(), dtype=dtype)
#     146 return np.asarray(self._data, dtype=dtype)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/highlevel.py:358, in Array.tolist(self)
#     352 def tolist(self):
#     353     """
#     354     Converts this Array into Python objects; same as #ak.to_list
#     355     (but without the underscore, like NumPy's
#     356     [tolist](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.tolist.html)).
#     357     """
# --> 358     return self.to_list()
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/highlevel.py:364, in Array.to_list(self)
#     360 def to_list(self):
#     361     """
#     362     Converts this Array into Python objects; same as #ak.to_list.
#     363     """
# --> 364     return self._layout.to_list(self._behavior)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/contents/content.py:1157, in Content.to_list(self, behavior)
#    1156 def to_list(self, behavior: dict | None = None) -> list:
# -> 1157     return self.to_packed()._to_list(behavior, None)
#
# File ~/.conda/envs/gnn_env/lib/python3.9/site-packages/awkward/contents/listoffsetarray.py:2200, in ListOffsetArray._to_list(self, behavior, json_conversions)
#    2197 out = [None] * starts.length
#    2199 for i in range(starts.length):
# -> 2200     out[i] = content[starts_data[i] : stops_data[i]]
#    2201 return out
#
# KeyboardInterrupt:

# %% [markdown]
# This reads the signal and background data from the csv, then creates a new dataframe with the complete raw data. After combining the signal and background data, it is separated again and assigned truth values in a new column, "IsB". This indicates whether or not it is a b-jet. The data is also selected to only include the leading jet data. Truth matching is done on both the signal and background data, and cuts are applied to only include high momentum jets with a defined pseudorapidity within the range of the detector. The features are defined, including sv tagging as jet-level features.

# %%
print(f'There are {len(bb_df)} b-jet events (signal)')
print(f'There are {len(qq_df)} q-jet events (background)')

# %%
# Read from csv and assign truth labels
sig_df = bb_df.assign(IsB=1)
bkg_df = qq_df.assign(IsB=0)

# Filter columns to include only leading jet data and truth labels
sig_df = sig_df[sig_df.columns[sig_df.columns.str.contains("Jet0|IsB")]]
bkg_df = bkg_df[bkg_df.columns[bkg_df.columns.str.contains("Jet0|IsB")]]

# Apply cuts and truth matching
sig_df = sig_df[(sig_df['Jet0_MC_Match'] == 1) &
                (sig_df['Jet0_MC_Jet_EfB'] > 0.6) &
                (sig_df['Jet0_PT'] > 20000) &
                (sig_df['Jet0_Eta'].between(2.2, 4.4))]
bkg_df = bkg_df[(bkg_df['Jet0_MC_Match'] == 1) &
                (bkg_df['Jet0_MC_Jet_EfB'] < 0.6) &
                (bkg_df['Jet0_MC_Jet_EfD'] < 0.6) &
                (bkg_df['Jet0_PT'] > 20000) &
                (bkg_df['Jet0_Eta'].between(2.2, 4.4))]

# Combine signal and background
combined_df = pd.concat([sig_df, bkg_df]).reset_index(drop=True)
#74 m

# %%
print(f"Efficiency of signal truth matching is: {len(sig_df)/len(bb_df):.4f}")
print(f"Efficiency of background truth matching is: {len(bkg_df)/len(qq_df):.4f}")
print('')
print(f"Total events after truth matching: {len(combined_df)}")
print(f"Number of b-jets after truth matching: {len(sig_df)}")
# Out:
# Efficiency of signal truth matching is: 0.3450
# Efficiency of background truth matching is: 0.3403
#
# Total events after truth matching: 1312597
# Number of b-jets after truth matching: 629588

# %% [markdown]
# The csv stores daughter information as a string, so the prepare features function converts them into accessible lists of floats. This function also duplicates jet-level features into lists of floats with lengths equal to the number of nodes in each jet, in order to match the formatting of the daughter-level features, where each float in a list corresponds to a daughter. The data is processed into a new dataframe. Then, the signal and background features are separated again. Training and testing data are created with equal parts of shuffled signal and background data, in a 80:20 ratio of the available leading jet data. The data before processing with signal and background combined includes 600k jets. After the truth matching and cuts are applied, there are 411,540 jets.

# %%
# Define feature columns including jet-level and daughter-level features
daughter_cols = [col for col in sig_df.columns if "_Daughters" in col]
svtag_cols = ['Jet0_SVtag_fdrMin',
 'Jet0_SVtag_ptSvrJet',
 'Jet0_SVtag_nTrk',
 'Jet0_SVtag_nTrkJet',
 'Jet0_SVtag_drSvrJet',
 'Jet0_SVtag_absQSum',
 'Jet0_SVtag_m',
 'Jet0_SVtag_mCor',
 'Jet0_SVtag_fdChi2',
 'Jet0_SVtag_ipChi2Sum',
 'Jet0_SVtag_tau',
 'Jet0_SVtag_z',
 'Jet0_SVtag_pt']
jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
feature_cols = daughter_cols + jet_cols

# Prepare features by converting daughter information to lists and duplicating jet-level features
def prepare_features(df, jet_cols, daughter_cols):
    # Duplicate data to lists matching the number of daughters/nodes per jet/row
    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)

    # Convert string values into list of floats
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)
    return df

df = prepare_features(combined_df, jet_cols, daughter_cols)
#32 m

# %%
# Split data into training, validation, and test sets
sig_df = df[df['IsB'] == 1].sample(frac=1, random_state=42).reset_index(drop=True)
bkg_df = df[df['IsB'] == 0].sample(frac=1, random_state=42).reset_index(drop=True)

half_train_size = int((sum(combined_df.IsB)*0.8)/2)
half_test_size = int((sum(combined_df.IsB)*0.2)/2)

train_df = pd.concat([sig_df.head(half_train_size), bkg_df.head(half_train_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of training data is: {len(train_df)}')

test_df = pd.concat([sig_df.tail(half_test_size), bkg_df.tail(half_test_size)]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of testing data is: {len(test_df)}')

validation_df = pd.concat([sig_df.iloc[half_train_size:-half_test_size], bkg_df.iloc[half_train_size:-half_test_size]]).sample(frac=1, random_state=42).reset_index(drop=True)
print(f'Length of validation data is: {len(validation_df)}')
# Out:
# Length of training data is: 503670
# Length of testing data is: 125916
# Length of validation data is: 683011

# %%
print('Ratio of c to b in datasets:')
print(f'    Training data: {sum(train_df.IsB)/len(train_df)}')
print(f'    Testing data: {sum(test_df.IsB)/len(test_df)}')
print(f'    Validation data: {sum(validation_df.IsB)/len(validation_df)}')
# Out:
# Ratio of c to b in datasets:
#     Training data: 0.5
#     Testing data: 0.5
#     Validation data: 0.4608930163643045

# %% [markdown]
# The node features are processed into an array, so the data can be transformed into data object, representing one row or jet in the data. The feature array is used to create a tensor of the node features. The graphs are created with fully connected edges, but without self-connectioned nodes. The adjacency matrix of the graph is of size [number of nodes] x [number of nodes] filled with ones except the diagonal has zeros. The y tensor holds the truth labels, for graph-level classification. The data is then loaded in batches.

# %%
# Create graphs for training and testing
def create_graphs(df, feature_cols):

    features_list = []
    
    for _, row in df.iterrows():
        num_nodes = row['Jet0_nDaughters']
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    data_objects = []
    for idx, features in enumerate(features_list):

        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        # Create fully connected graph
        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        y = torch.tensor([df['IsB'].iloc[idx]], dtype=torch.float)
        
        data = Data(x=x, edge_index=edge_index, y=y, num_nodes=num_nodes)
        data_objects.append(data)

    return data_objects

# Create graphs for training and testing
train_data = create_graphs(train_df, feature_cols)
test_data = create_graphs(test_df, feature_cols)

# Load data in batches
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)

# %% [markdown]
# # Classifier

# %% [markdown]
# The model is defined with 64 hidden channels, using SAGEConv (sample and aggregate) for the convolutional layers, which aggregates features from its local neighbors. Each iteration of the convolutional layers access the next layer of surrounding nodes. ReLU activation functions are used between each layer, and dropout layers zero out graph representation tensors with a probability of 30% for regularization. After the message passing process, a global add pooling layer and linear layer work together to map the output to a single logit.

# %%
class GNN(torch.nn.Module):
    def __init__(self):
        super(GNN, self).__init__()
        hidden_channels = 64
        self.conv1 = SAGEConv(len(feature_cols), hidden_channels)
        self.ln1 = LayerNorm(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.ln2 = LayerNorm(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.ln3 = LayerNorm(hidden_channels)
        self.conv4 = SAGEConv(hidden_channels, hidden_channels)
        self.ln4 = LayerNorm(hidden_channels)
        self.lin = Linear(hidden_channels, 1)
        self.dropout = Dropout(0.3)

    def forward(self, x, edge_index, batch):        
        x = self.conv1(x, edge_index)
        x = self.ln1(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv2(x, edge_index)
        x = self.ln2(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv3(x, edge_index)
        x = self.ln3(x)
        x = F.relu(x)
        x = self.dropout(x)

        x = self.conv4(x, edge_index)
        x = self.ln4(x)
        x = F.relu(x)

        x = global_add_pool(x, batch)
        x = self.lin(x)
        return x.squeeze(1)
    
model = GNN()
model = model.to(device)

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# The model is trained on the graphs using the classifier defined above. During the training loop, the gradients are clipped to prevent exploding gradients and overfitting. Loss is calculated for the training data aand minimized with the AdamW optimizer. In the test function, the loss is calculated for just the validation data, and the accuracy is computed for both. Then, for every epoch, the loss and accuracy values are stored as lists, and the learning rate is decreased when the validation data loss plateaus. The loss and accuracy for the training and validation data are printed, then plotted for all epochs.

# %%
# Define optimizer and loss function
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)
criterion = nn.BCEWithLogitsLoss()
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5) # reduce lr by 0.5 every 5 epochs


# Training loop
def train():
    model.train()
    total_loss = 0

    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y.float())
        clip_grad_norm_(model.parameters(), max_norm=0.5)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    avg_loss = total_loss / len(train_loader.dataset)

    return avg_loss

# Testing function
def test(loader):
    model.eval()
    total_correct = 0
    total_samples = 0
    total_loss = 0
    
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index, data.batch)
            loss = criterion(out, data.y.float())
            pred = (out > 0).float()
            correct = (pred.squeeze() == data.y.float()).sum().item()
            total_correct += correct
            total_samples += len(data.y)
            total_loss += loss.item() * data.num_graphs

        avg_loss = total_loss / len(loader.dataset)
        acc = total_correct / total_samples
    return avg_loss, acc

# Training parameters
num_epochs = 200

# Initialize lists for storing loss and accuracy values
train_loss_values = []
train_acc_values = []
test_loss_values = []
test_acc_values = []

# Training loop
for epoch in range(num_epochs):

    train_loss = train()
    train_loss_values.append(train_loss)

    train_acc = test(train_loader)[1]
    train_acc_values.append(train_acc)

    test_loss, test_acc = test(test_loader)
    test_loss_values.append(test_loss)
    test_acc_values.append(test_acc)

    scheduler.step(test_loss)

    print(f'Epoch: {epoch+1:03d}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')

    # Save the model and results every 50 epochs
    if (epoch + 1) % 50 == 0:
        # Overwrite the existing model file
        torch.save(model.state_dict(), 'full_bq_model2.pth')
        print('Model saved as full_bq_model2.pth.')

        # Save the loss and accuracy values to a CSV file, overwriting the existing file
        results_df = pd.DataFrame({
            'Epoch': list(range(1, epoch + 2)),
            'Train Loss': train_loss_values,
            'Test Loss': test_loss_values,
            'Train Accuracy': train_acc_values,
            'Test Accuracy': test_acc_values
        })
        results_df.to_csv('full_bq_training2.csv', index=False)
        print('Training results saved as full_bq_training2.csv.')

torch.save(model.state_dict(), 'full_bq_model2.pth')
print('Model saved as full_bq_model2.pth. Training complete.')

results_df = pd.DataFrame({
    'Epoch': list(range(1, num_epochs+1)),
    'Train Loss': train_loss_values,
    'Test Loss': test_loss_values,
    'Train Accuracy': train_acc_values,
    'Test Accuracy': test_acc_values
})

# Save the loss and accuracy values to a CSV file
results_df.to_csv('full_bq_training2.csv', index=False)
print('Training results saved as full_bq_training2.csv. Training complete.')

#310 m
# Out:
# Epoch: 001, Train Loss: 0.4568, Test Loss: 0.4217, Train Acc: 0.8029, Test Acc: 0.8007
# Epoch: 002, Train Loss: 0.4216, Test Loss: 0.4168, Train Acc: 0.8041, Test Acc: 0.8022
# Epoch: 003, Train Loss: 0.4172, Test Loss: 0.4160, Train Acc: 0.8050, Test Acc: 0.8036
# Epoch: 004, Train Loss: 0.4148, Test Loss: 0.4123, Train Acc: 0.8054, Test Acc: 0.8041
# Epoch: 005, Train Loss: 0.4132, Test Loss: 0.4123, Train Acc: 0.8053, Test Acc: 0.8036
# Epoch: 006, Train Loss: 0.4120, Test Loss: 0.4115, Train Acc: 0.8062, Test Acc: 0.8050
# Epoch: 007, Train Loss: 0.4107, Test Loss: 0.4107, Train Acc: 0.8062, Test Acc: 0.8044
# Epoch: 008, Train Loss: 0.4099, Test Loss: 0.4114, Train Acc: 0.8065, Test Acc: 0.8051
# Epoch: 009, Train Loss: 0.4088, Test Loss: 0.4095, Train Acc: 0.8066, Test Acc: 0.8054
# Epoch: 010, Train Loss: 0.4080, Test Loss: 0.4057, Train Acc: 0.8087, Test Acc: 0.8072
# Epoch: 011, Train Loss: 0.4067, Test Loss: 0.4039, Train Acc: 0.8080, Test Acc: 0.8066
# Epoch: 012, Train Loss: 0.4051, Test Loss: 0.4020, Train Acc: 0.8092, Test Acc: 0.8078
# Epoch: 013, Train Loss: 0.4034, Test Loss: 0.4008, Train Acc: 0.8091, Test Acc: 0.8075
# Epoch: 014, Train Loss: 0.4009, Test Loss: 0.3983, Train Acc: 0.8096, Test Acc: 0.8079
# Epoch: 015, Train Loss: 0.3990, Test Loss: 0.3968, Train Acc: 0.8112, Test Acc: 0.8099
# Epoch: 016, Train Loss: 0.3970, Test Loss: 0.3917, Train Acc: 0.8135, Test Acc: 0.8119
# Epoch: 017, Train Loss: 0.3946, Test Loss: 0.3915, Train Acc: 0.8134, Test Acc: 0.8121
# Epoch: 018, Train Loss: 0.3922, Test Loss: 0.3858, Train Acc: 0.8162, Test Acc: 0.8147
# Epoch: 019, Train Loss: 0.3899, Test Loss: 0.3812, Train Acc: 0.8211, Test Acc: 0.8192
# Epoch: 020, Train Loss: 0.3871, Test Loss: 0.3809, Train Acc: 0.8206, Test Acc: 0.8192
# Epoch: 021, Train Loss: 0.3851, Test Loss: 0.3850, Train Acc: 0.8201, Test Acc: 0.8186
# Epoch: 022, Train Loss: 0.3826, Test Loss: 0.3805, Train Acc: 0.8215, Test Acc: 0.8199
# Epoch: 023, Train Loss: 0.3803, Test Loss: 0.3730, Train Acc: 0.8262, Test Acc: 0.8246
# Epoch: 024, Train Loss: 0.3783, Test Loss: 0.3744, Train Acc: 0.8239, Test Acc: 0.8221
# Epoch: 025, Train Loss: 0.3766, Test Loss: 0.3696, Train Acc: 0.8291, Test Acc: 0.8274
# Epoch: 026, Train Loss: 0.3749, Test Loss: 0.3689, Train Acc: 0.8286, Test Acc: 0.8267
# Epoch: 027, Train Loss: 0.3732, Test Loss: 0.3605, Train Acc: 0.8334, Test Acc: 0.8315
# Epoch: 028, Train Loss: 0.3713, Test Loss: 0.3722, Train Acc: 0.8296, Test Acc: 0.8282
# Epoch: 029, Train Loss: 0.3698, Test Loss: 0.3631, Train Acc: 0.8316, Test Acc: 0.8303
# Epoch: 030, Train Loss: 0.3693, Test Loss: 0.3586, Train Acc: 0.8337, Test Acc: 0.8323
# Epoch: 031, Train Loss: 0.3679, Test Loss: 0.3617, Train Acc: 0.8339, Test Acc: 0.8328
# Epoch: 032, Train Loss: 0.3671, Test Loss: 0.3658, Train Acc: 0.8323, Test Acc: 0.8311
# Epoch: 033, Train Loss: 0.3662, Test Loss: 0.3620, Train Acc: 0.8325, Test Acc: 0.8308
# Epoch: 034, Train Loss: 0.3656, Test Loss: 0.3505, Train Acc: 0.8370, Test Acc: 0.8353
# Epoch: 035, Train Loss: 0.3647, Test Loss: 0.3705, Train Acc: 0.8285, Test Acc: 0.8271
# Epoch: 036, Train Loss: 0.3639, Test Loss: 0.3567, Train Acc: 0.8357, Test Acc: 0.8344
# Epoch: 037, Train Loss: 0.3633, Test Loss: 0.3663, Train Acc: 0.8323, Test Acc: 0.8312
# Epoch: 038, Train Loss: 0.3627, Test Loss: 0.3617, Train Acc: 0.8339, Test Acc: 0.8318
# Epoch: 039, Train Loss: 0.3622, Test Loss: 0.3534, Train Acc: 0.8366, Test Acc: 0.8355
# Epoch: 040, Train Loss: 0.3611, Test Loss: 0.3553, Train Acc: 0.8354, Test Acc: 0.8340
# Epoch: 041, Train Loss: 0.3558, Test Loss: 0.3536, Train Acc: 0.8377, Test Acc: 0.8363
# Epoch: 042, Train Loss: 0.3549, Test Loss: 0.3525, Train Acc: 0.8373, Test Acc: 0.8361
# Epoch: 043, Train Loss: 0.3551, Test Loss: 0.3537, Train Acc: 0.8366, Test Acc: 0.8348
# Epoch: 044, Train Loss: 0.3547, Test Loss: 0.3471, Train Acc: 0.8386, Test Acc: 0.8366
# Epoch: 045, Train Loss: 0.3541, Test Loss: 0.3579, Train Acc: 0.8359, Test Acc: 0.8347
# Epoch: 046, Train Loss: 0.3539, Test Loss: 0.3581, Train Acc: 0.8373, Test Acc: 0.8357
# Epoch: 047, Train Loss: 0.3535, Test Loss: 0.3497, Train Acc: 0.8384, Test Acc: 0.8364
# Epoch: 048, Train Loss: 0.3530, Test Loss: 0.3594, Train Acc: 0.8356, Test Acc: 0.8343
# Epoch: 049, Train Loss: 0.3531, Test Loss: 0.3444, Train Acc: 0.8394, Test Acc: 0.8380
# Epoch: 050, Train Loss: 0.3525, Test Loss: 0.3486, Train Acc: 0.8388, Test Acc: 0.8372
# Model saved as full_bq_model2.pth.
# Training results saved as full_bq_training2.csv.
# Epoch: 051, Train Loss: 0.3527, Test Loss: 0.3578, Train Acc: 0.8359, Test Acc: 0.8344
# Epoch: 052, Train Loss: 0.3521, Test Loss: 0.3490, Train Acc: 0.8384, Test Acc: 0.8371
# Epoch: 053, Train Loss: 0.3524, Test Loss: 0.3429, Train Acc: 0.8405, Test Acc: 0.8386
# Epoch: 054, Train Loss: 0.3518, Test Loss: 0.3486, Train Acc: 0.8393, Test Acc: 0.8378
# Epoch: 055, Train Loss: 0.3520, Test Loss: 0.3616, Train Acc: 0.8362, Test Acc: 0.8349
# Epoch: 056, Train Loss: 0.3515, Test Loss: 0.3473, Train Acc: 0.8392, Test Acc: 0.8376
# Epoch: 057, Train Loss: 0.3513, Test Loss: 0.3464, Train Acc: 0.8392, Test Acc: 0.8372
# Epoch: 058, Train Loss: 0.3508, Test Loss: 0.3447, Train Acc: 0.8407, Test Acc: 0.8389
# Epoch: 059, Train Loss: 0.3505, Test Loss: 0.3455, Train Acc: 0.8398, Test Acc: 0.8383
# Epoch: 060, Train Loss: 0.3471, Test Loss: 0.3417, Train Acc: 0.8412, Test Acc: 0.8397
# Epoch: 061, Train Loss: 0.3465, Test Loss: 0.3410, Train Acc: 0.8416, Test Acc: 0.8397
# Epoch: 062, Train Loss: 0.3466, Test Loss: 0.3472, Train Acc: 0.8403, Test Acc: 0.8386
# Epoch: 063, Train Loss: 0.3465, Test Loss: 0.3430, Train Acc: 0.8404, Test Acc: 0.8384
# Epoch: 064, Train Loss: 0.3465, Test Loss: 0.3423, Train Acc: 0.8416, Test Acc: 0.8398
# Epoch: 065, Train Loss: 0.3460, Test Loss: 0.3441, Train Acc: 0.8405, Test Acc: 0.8384
# Epoch: 066, Train Loss: 0.3459, Test Loss: 0.3459, Train Acc: 0.8399, Test Acc: 0.8386
# Epoch: 067, Train Loss: 0.3461, Test Loss: 0.3427, Train Acc: 0.8410, Test Acc: 0.8390
# Epoch: 068, Train Loss: 0.3441, Test Loss: 0.3393, Train Acc: 0.8427, Test Acc: 0.8401
# Epoch: 069, Train Loss: 0.3438, Test Loss: 0.3395, Train Acc: 0.8421, Test Acc: 0.8401
# Epoch: 070, Train Loss: 0.3438, Test Loss: 0.3412, Train Acc: 0.8414, Test Acc: 0.8394
# Epoch: 071, Train Loss: 0.3435, Test Loss: 0.3418, Train Acc: 0.8414, Test Acc: 0.8396
# Epoch: 072, Train Loss: 0.3436, Test Loss: 0.3402, Train Acc: 0.8423, Test Acc: 0.8404
# Epoch: 073, Train Loss: 0.3430, Test Loss: 0.3393, Train Acc: 0.8425, Test Acc: 0.8404
# Epoch: 074, Train Loss: 0.3432, Test Loss: 0.3365, Train Acc: 0.8434, Test Acc: 0.8410
# Epoch: 075, Train Loss: 0.3437, Test Loss: 0.3393, Train Acc: 0.8427, Test Acc: 0.8408
# Epoch: 076, Train Loss: 0.3432, Test Loss: 0.3418, Train Acc: 0.8421, Test Acc: 0.8401
# Epoch: 077, Train Loss: 0.3430, Test Loss: 0.3356, Train Acc: 0.8439, Test Acc: 0.8413
# Epoch: 078, Train Loss: 0.3425, Test Loss: 0.3447, Train Acc: 0.8411, Test Acc: 0.8391
# Epoch: 079, Train Loss: 0.3433, Test Loss: 0.3362, Train Acc: 0.8436, Test Acc: 0.8411
# Epoch: 080, Train Loss: 0.3431, Test Loss: 0.3394, Train Acc: 0.8429, Test Acc: 0.8407
# Epoch: 081, Train Loss: 0.3426, Test Loss: 0.3429, Train Acc: 0.8415, Test Acc: 0.8398
# Epoch: 082, Train Loss: 0.3432, Test Loss: 0.3453, Train Acc: 0.8408, Test Acc: 0.8388
# Epoch: 083, Train Loss: 0.3430, Test Loss: 0.3420, Train Acc: 0.8420, Test Acc: 0.8399
# Epoch: 084, Train Loss: 0.3417, Test Loss: 0.3415, Train Acc: 0.8422, Test Acc: 0.8402
# Epoch: 085, Train Loss: 0.3416, Test Loss: 0.3430, Train Acc: 0.8416, Test Acc: 0.8395
# Epoch: 086, Train Loss: 0.3416, Test Loss: 0.3406, Train Acc: 0.8422, Test Acc: 0.8404
# Epoch: 087, Train Loss: 0.3417, Test Loss: 0.3412, Train Acc: 0.8415, Test Acc: 0.8396
# Epoch: 088, Train Loss: 0.3417, Test Loss: 0.3404, Train Acc: 0.8424, Test Acc: 0.8405
# Epoch: 089, Train Loss: 0.3414, Test Loss: 0.3385, Train Acc: 0.8429, Test Acc: 0.8410
# Epoch: 090, Train Loss: 0.3411, Test Loss: 0.3389, Train Acc: 0.8429, Test Acc: 0.8408
# Epoch: 091, Train Loss: 0.3408, Test Loss: 0.3368, Train Acc: 0.8437, Test Acc: 0.8415
# Epoch: 092, Train Loss: 0.3405, Test Loss: 0.3380, Train Acc: 0.8431, Test Acc: 0.8409
# Epoch: 093, Train Loss: 0.3408, Test Loss: 0.3363, Train Acc: 0.8436, Test Acc: 0.8415
# Epoch: 094, Train Loss: 0.3409, Test Loss: 0.3379, Train Acc: 0.8435, Test Acc: 0.8410
# Epoch: 095, Train Loss: 0.3408, Test Loss: 0.3403, Train Acc: 0.8427, Test Acc: 0.8406
# Epoch: 096, Train Loss: 0.3404, Test Loss: 0.3379, Train Acc: 0.8434, Test Acc: 0.8412
# Epoch: 097, Train Loss: 0.3407, Test Loss: 0.3364, Train Acc: 0.8438, Test Acc: 0.8415
# Epoch: 098, Train Loss: 0.3404, Test Loss: 0.3362, Train Acc: 0.8438, Test Acc: 0.8415
# Epoch: 099, Train Loss: 0.3405, Test Loss: 0.3375, Train Acc: 0.8434, Test Acc: 0.8413
# Epoch: 100, Train Loss: 0.3402, Test Loss: 0.3386, Train Acc: 0.8431, Test Acc: 0.8409
# Model saved as full_bq_model2.pth.
# Training results saved as full_bq_training2.csv.
# Epoch: 101, Train Loss: 0.3405, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8411
# Epoch: 102, Train Loss: 0.3405, Test Loss: 0.3376, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 103, Train Loss: 0.3402, Test Loss: 0.3373, Train Acc: 0.8436, Test Acc: 0.8414
# Epoch: 104, Train Loss: 0.3401, Test Loss: 0.3363, Train Acc: 0.8439, Test Acc: 0.8416
# Epoch: 105, Train Loss: 0.3404, Test Loss: 0.3386, Train Acc: 0.8433, Test Acc: 0.8411
# Epoch: 106, Train Loss: 0.3403, Test Loss: 0.3380, Train Acc: 0.8434, Test Acc: 0.8411
# Epoch: 107, Train Loss: 0.3402, Test Loss: 0.3375, Train Acc: 0.8434, Test Acc: 0.8413
# Epoch: 108, Train Loss: 0.3399, Test Loss: 0.3367, Train Acc: 0.8438, Test Acc: 0.8413
# Epoch: 109, Train Loss: 0.3404, Test Loss: 0.3380, Train Acc: 0.8433, Test Acc: 0.8411
# Epoch: 110, Train Loss: 0.3400, Test Loss: 0.3378, Train Acc: 0.8433, Test Acc: 0.8412
# Epoch: 111, Train Loss: 0.3401, Test Loss: 0.3368, Train Acc: 0.8436, Test Acc: 0.8415
# Epoch: 112, Train Loss: 0.3399, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 113, Train Loss: 0.3399, Test Loss: 0.3393, Train Acc: 0.8429, Test Acc: 0.8408
# Epoch: 114, Train Loss: 0.3398, Test Loss: 0.3379, Train Acc: 0.8434, Test Acc: 0.8413
# Epoch: 115, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8434, Test Acc: 0.8414
# Epoch: 116, Train Loss: 0.3397, Test Loss: 0.3376, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 117, Train Loss: 0.3400, Test Loss: 0.3374, Train Acc: 0.8436, Test Acc: 0.8415
# Epoch: 118, Train Loss: 0.3398, Test Loss: 0.3372, Train Acc: 0.8436, Test Acc: 0.8414
# Epoch: 119, Train Loss: 0.3400, Test Loss: 0.3376, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 120, Train Loss: 0.3398, Test Loss: 0.3373, Train Acc: 0.8436, Test Acc: 0.8414
# Epoch: 121, Train Loss: 0.3400, Test Loss: 0.3374, Train Acc: 0.8436, Test Acc: 0.8414
# Epoch: 122, Train Loss: 0.3402, Test Loss: 0.3373, Train Acc: 0.8436, Test Acc: 0.8414
# Epoch: 123, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 124, Train Loss: 0.3398, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 125, Train Loss: 0.3398, Test Loss: 0.3377, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 126, Train Loss: 0.3399, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 127, Train Loss: 0.3402, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 128, Train Loss: 0.3400, Test Loss: 0.3376, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 129, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 130, Train Loss: 0.3402, Test Loss: 0.3376, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 131, Train Loss: 0.3403, Test Loss: 0.3376, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 132, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 133, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 134, Train Loss: 0.3398, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 135, Train Loss: 0.3401, Test Loss: 0.3376, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 136, Train Loss: 0.3400, Test Loss: 0.3373, Train Acc: 0.8436, Test Acc: 0.8414
# Epoch: 137, Train Loss: 0.3400, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 138, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8415
# Epoch: 139, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 140, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 141, Train Loss: 0.3398, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 142, Train Loss: 0.3396, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 143, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8415
# Epoch: 144, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8415
# Epoch: 145, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 146, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 147, Train Loss: 0.3398, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 148, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 149, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 150, Train Loss: 0.3396, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Model saved as full_bq_model2.pth.
# Training results saved as full_bq_training2.csv.
# Epoch: 151, Train Loss: 0.3402, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 152, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 153, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 154, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 155, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 156, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 157, Train Loss: 0.3399, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 158, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 159, Train Loss: 0.3398, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 160, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 161, Train Loss: 0.3400, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 162, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 163, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 164, Train Loss: 0.3404, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 165, Train Loss: 0.3404, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 166, Train Loss: 0.3397, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 167, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 168, Train Loss: 0.3403, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 169, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 170, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 171, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8436, Test Acc: 0.8414
# Epoch: 172, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 173, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 174, Train Loss: 0.3399, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 175, Train Loss: 0.3397, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 176, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 177, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 178, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 179, Train Loss: 0.3399, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 180, Train Loss: 0.3405, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 181, Train Loss: 0.3400, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 182, Train Loss: 0.3400, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 183, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 184, Train Loss: 0.3400, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 185, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 186, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 187, Train Loss: 0.3399, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 188, Train Loss: 0.3405, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 189, Train Loss: 0.3404, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 190, Train Loss: 0.3396, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 191, Train Loss: 0.3401, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 192, Train Loss: 0.3405, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8413
# Epoch: 193, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 194, Train Loss: 0.3398, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 195, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 196, Train Loss: 0.3402, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 197, Train Loss: 0.3398, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 198, Train Loss: 0.3401, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 199, Train Loss: 0.3399, Test Loss: 0.3375, Train Acc: 0.8435, Test Acc: 0.8414
# Epoch: 200, Train Loss: 0.3400, Test Loss: 0.3374, Train Acc: 0.8435, Test Acc: 0.8414
# Model saved as full_bq_model2.pth.
# Training results saved as full_bq_training2.csv.
# Model saved as full_bq_model2.pth. Training complete.
# Training results saved as full_bq_training2.csv. Training complete.

# %%
# Reload training data to produce plots
training = pd.read_csv('full_bq_training2.csv')
train_loss_values = training['Train Loss'].to_list()
test_loss_values = training['Test Loss'].to_list()
train_acc_values = training['Train Accuracy'].to_list()
test_acc_values = training['Test Accuracy'].to_list()

# %%
training
# Out:
#      Epoch  Train Loss  Test Loss  Train Accuracy  Test Accuracy
# 0        1    0.456801   0.421720        0.802897       0.800748
# 1        2    0.421618   0.416751        0.804102       0.802209
# 2        3    0.417160   0.416009        0.804977       0.803599
# 3        4    0.414753   0.412267        0.805377       0.804115
# 4        5    0.413244   0.412251        0.805293       0.803615
# ..     ...         ...        ...             ...            ...
# 195    196    0.340234   0.337413        0.843507       0.841378
# 196    197    0.339776   0.337424        0.843507       0.841362
# 197    198    0.340133   0.337392        0.843507       0.841362
# 198    199    0.339906   0.337461        0.843515       0.841362
# 199    200    0.339953   0.337436        0.843513       0.841362
#
# [200 rows x 5 columns]

# %%
# Plot Loss and Accuracy
def plot_training_results():
    epochs = range(1, len(train_loss_values) + 1)

    mean_train_loss = np.mean(train_loss_values)
    mean_test_loss = np.mean(test_loss_values)
    mean_train_acc = np.mean(train_acc_values)
    mean_test_acc = np.mean(test_acc_values)

    min_train_loss = min(train_loss_values)
    min_test_loss = min(test_loss_values)
    max_train_acc = max(train_acc_values)
    max_test_acc = max(test_acc_values)

    final_train_loss = train_loss_values[-1]
    final_test_loss = test_loss_values[-1]
    final_train_acc = train_acc_values[-1]
    final_test_acc = test_acc_values[-1]

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
    #fig.suptitle('Training Results', fontsize=16)

    # Plot Loss
    ax1.plot(epochs, train_loss_values, color='darkred', label=(f"Training Loss (min = {min_train_loss:.4f})"))
    ax1.plot(epochs, test_loss_values, color='mediumblue', label=(f"Testing Loss (min = {min_test_loss:.4f})"))

    ax1.text(0.15, 0.90, "LHCb Simulation", transform=ax1.transAxes, fontsize=14, verticalalignment='bottom')

    ax1.set_title('Loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend(loc='best')

    # Plot  Accuracy
    ax2.plot(epochs, train_acc_values, color='darkred', label=(f"Training Accuracy (max = {max_train_acc:.4f})"))
    ax2.plot(epochs, test_acc_values, color='mediumblue', label=(f"Testing Accuracy (max = {max_test_acc:.4})"))

    ax2.text(0.7, 0.15, "LHCb Simulation", transform=ax2.transAxes, fontsize=14, verticalalignment='bottom')

    ax2.set_title(' Accuracy')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.legend(loc='best')

    plt.style.use('default')
    plt.tight_layout()
    plt.show()
    
# After your training loop, call the function:
plot_training_results()

# %%
# Get model predictions
y_true = []  # class values (0 or 1)
y_scores = []  # predicted probabilities or scores

model.load_state_dict(torch.load('full_bq_model2.pth'))
model = model.to('cpu')
model.eval()
with torch.no_grad():
    for data in test_loader:
        out = model(data.x, data.edge_index, data.batch)
        prob = torch.sigmoid(out)
        
        y_true.append(data.y.numpy().flatten())
        y_scores.append(prob.numpy().flatten())

y_true = np.concatenate(y_true)
y_scores = np.concatenate(y_scores)

fpr, tpr, thresholds = roc_curve(y_true, y_scores)
auc = roc_auc_score(y_true, y_scores)

np.save('full_bq_roc_data2.npy', np.array([fpr, tpr, thresholds, auc]))
# Out:
# /tmp/ipykernel_225433/4272454310.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.save('full_bq_roc_data2.npy', np.array([fpr, tpr, thresholds, auc]))

# %%
# Load ROC data
fpr1, tpr1, thresholds1, auc1 = np.load('full_bq_roc_data2.npy', allow_pickle=True)
fpr2, tpr2, thresholds2, auc2 = np.load('full_cb_roc_data1.npy', allow_pickle=True)
fpr3, tpr3, thresholds3, auc3 = np.load('full_cq_roc_data1.npy', allow_pickle=True)
fpr4, tpr4, thresholds4, auc4 = np.load('full_bcq_roc_data1.npy', allow_pickle=True)


# Plot ROC curves
plt.figure(figsize=(8, 6))
plt.plot(fpr1, tpr1, label=f'b vs q ROC Curve (AUC = {auc1:.4f})', color='green')
plt.plot(fpr2, tpr2, label=f'c vs b ROC Curve (AUC = {auc2:.4f})', color='purple')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')

# Labels and legend
plt.text(0.85, 0.15, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('Signal Efficency (TPR)')
plt.xlim(0,1)
plt.ylim(0,1)
plt.title('Receiver Operating Characteristics (ROC)')
plt.legend(loc='lower right')
plt.show()

# %%
# Get FPRs for TPRs
desired_tpr = [0.85, 0.80, 0.75, 0.70, 0.65, 0.60]

print("Efficiency | FPR ")
for val in desired_tpr:
    # Find the index of the closest TPR to the desired TPR value
    closest_index = np.argmin(np.abs(tpr - val))

    # Get the chosen threshold and corresponding FPR, where the threshold is the probability cutoff
    chosen_threshold = thresholds[closest_index]
    given_fpr = fpr[closest_index]
    print(f"{val}: {given_fpr:.4f}")
# Out:
# Efficiency | FPR
# 0.85: 0.1938
# 0.8: 0.1178
# 0.75: 0.0685
# 0.7: 0.0315
# 0.65: 0.0130
# 0.6: 0.0070

# %%
chosen_tpr = 0.75
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pb {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.75: Pb 0.5078: FPR 0.0685

# %%
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)

cm_percentage = cm.astype(float) / cm.sum(axis=1)[:, np.newaxis] * 100

annot_labels = np.empty_like(cm, dtype=object)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        percentage = cm_percentage[i, j]
        annot_labels[i, j] = f'{percentage:.1f}%'

fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm_percentage, annot=annot_labels, fmt='', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr*100}% Efficiency")

ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
y_pred_binary = (y_scores >= chosen_threshold).astype(int)
cm = confusion_matrix(y_true, y_pred_binary)
df_cm = pd.DataFrame(cm)

# Create a figure and axis
fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', annot_kws={"size": 16, "weight": "bold"})
ax.tick_params(axis='both', which='major', labelsize=12)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f"Confusion Matrix at {chosen_tpr*100}% Efficiency")

# Add TP, FP, FN, TN labels
ax.text(0.15, 0.15, 'TN', ha='center', va='center', fontweight='bold', fontsize=12, color='white')
ax.text(1.15, 0.15, 'FP', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(0.15, 1.15, 'FN', ha='center', va='center', fontweight='bold', fontsize=12)
ax.text(1.15, 1.15, 'TP', ha='center', va='center', fontweight='bold', fontsize=12, color='white')

plt.show()

# %%
# Plot ROC Curve and show AUC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='navy', label=f'ROC curve (AUC = {auc:.4f})')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--', label='Baseline (AUC = 0.5)')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.style.use('default')
plt.ylabel('Signal Efficiency')
plt.xlabel('False Positive Rate (FPR)')
plt.title('Receiver Operating Characteristics (ROC)')
plt.text(0.85, 0.15, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.legend(loc='lower right')
plt.show()

# %%
# Prepare model
model.eval()
data = next(iter(test_loader))
x, edge_index, batch = data.x, data.edge_index, data.batch

G = nx.Graph()
edges = list(zip(edge_index[0].numpy(), edge_index[1].numpy()))
G.add_edges_from(edges)

feature_importances = np.zeros(x.size(1))

for feature_idx in range(x.size(1)):
    x_perturbed = x.clone()
    x_perturbed[:, feature_idx] = 0

    # Predict with original features
    with torch.no_grad():
        orig_pred = model(x, edge_index, batch)
        perturbed_pred = model(x_perturbed, edge_index, batch)

    # Compute importance - difference in predictions
    importance = torch.mean(torch.abs(orig_pred - perturbed_pred))
    feature_importances[feature_idx] = importance

importance_df = pd.DataFrame({'Feature': feature_cols, 'Importance': feature_importances})
print(importance_df)

plt.figure(figsize=(12, 12))
sns.barplot(x='Importance', y='Feature', data=importance_df, palette='viridis', hue='Feature', dodge=False)
plt.title('Feature Importance', fontsize=15)
plt.text(0.87, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
plt.xlabel('Importance', fontsize=15)
plt.ylabel('Feature', fontsize=15)
plt.show()
# Out:
#                                 Feature  Importance
# 0                      Jet0_Daughters_E    1.178953
# 1                     Jet0_Daughters_pT    0.705798
# 2                     Jet0_Daughters_ID    0.027007
# 3                     Jet0_Daughters_pX    0.130874
# 4                     Jet0_Daughters_pY    0.200084
# 5                     Jet0_Daughters_pZ    1.290995
# 6                    Jet0_Daughters_Eta    0.013583
# 7                    Jet0_Daughters_Phi    0.001602
# 8                      Jet0_Daughters_Q    0.001145
# 9                     Jet0_Daughters_IP    0.090118
# 10                Jet0_Daughters_IPCHI2    1.840426
# 11                 Jet0_Daughters_IPraw    0.058055
# 12                   Jet0_Daughters_NNe    0.135086
# 13                   Jet0_Daughters_NNk    0.218437
# 14                   Jet0_Daughters_NNp    0.174714
# 15                  Jet0_Daughters_NNpi    0.148684
# 16                  Jet0_Daughters_NNmu    1.090061
# 17                  Jet0_Daughters_Chi2    0.198167
# 18                Jet0_Daughters_QoverP    0.264155
# 19                Jet0_Daughters_trackX    0.124265
# 20                Jet0_Daughters_trackY    0.147766
# 21                Jet0_Daughters_trackZ    0.235164
# 22               Jet0_Daughters_trackVX    0.141936
# 23               Jet0_Daughters_trackVY    0.163308
# 24               Jet0_Daughters_trackVZ    1.508102
# 25       Jet0_Daughters_CaloNeutralEcal    0.482262
# 26  Jet0_Daughters_CaloNeutralHcal2Ecal    0.410697
# 27        Jet0_Daughters_CaloNeutralE49    0.560570
# 28        Jet0_Daughters_CaloNeutralPrs    0.345381
# 29                             Jet0_Eta    0.008551
# 30                              Jet0_PT    2.074978
# 31                    Jet0_SVtag_fdrMin    0.000828
# 32                  Jet0_SVtag_ptSvrJet    0.000164
# 33                      Jet0_SVtag_nTrk    0.005113
# 34                   Jet0_SVtag_nTrkJet    0.009394
# 35                  Jet0_SVtag_drSvrJet    0.001134
# 36                   Jet0_SVtag_absQSum    0.003923
# 37                         Jet0_SVtag_m    0.176103
# 38                      Jet0_SVtag_mCor    1.141651
# 39                    Jet0_SVtag_fdChi2    0.065831
# 40                 Jet0_SVtag_ipChi2Sum    0.329392
# 41                       Jet0_SVtag_tau    0.000231
# 42                         Jet0_SVtag_z    0.019476
# 43                        Jet0_SVtag_pt    2.151547

# %%
for index, row in importance_df.iterrows():
    feature = row['Feature'] 
    importance = row['Importance']
    if importance > 0.25:
        print(f'{feature} & {importance:4f}')
# Out:
# Jet0_Daughters_E & 1.178953
# Jet0_Daughters_pT & 0.705798
# Jet0_Daughters_pZ & 1.290995
# Jet0_Daughters_IPCHI2 & 1.840426
# Jet0_Daughters_NNmu & 1.090061
# Jet0_Daughters_QoverP & 0.264155
# Jet0_Daughters_trackVZ & 1.508102
# Jet0_Daughters_CaloNeutralEcal & 0.482262
# Jet0_Daughters_CaloNeutralHcal2Ecal & 0.410697
# Jet0_Daughters_CaloNeutralE49 & 0.560570
# Jet0_Daughters_CaloNeutralPrs & 0.345381
# Jet0_PT & 2.074978
# Jet0_SVtag_mCor & 1.141651
# Jet0_SVtag_ipChi2Sum & 0.329392
# Jet0_SVtag_pt & 2.151547

# %% [markdown]
# # Model Probability Output

# %% [markdown]
# This function  inputs a random jet sample from the full dataframe before truth matching or cuts are applied and uses the trained model to output predictions of if the jet is a b-jet or not.

# %%
df = validation_df

def make_predictions():
    # Select a random integer for sampling
    random_integer = np.random.randint(0, len(df))
    sample_jet = df.iloc[random_integer:random_integer+1].copy()

    # Filter columns related to Jet0
    sample_jet = sample_jet.filter(like='Jet0')

    # Define feature columns
    daughter_cols = [col for col in sample_jet.columns if "_Daughters" in col]
    svtag_cols = ['Jet0_SVtag_fdrMin',
    'Jet0_SVtag_ptSvrJet',
    'Jet0_SVtag_nTrk',
    'Jet0_SVtag_nTrkJet',
    'Jet0_SVtag_drSvrJet',
    'Jet0_SVtag_absQSum',
    'Jet0_SVtag_m',
    'Jet0_SVtag_mCor',
    'Jet0_SVtag_fdChi2',
    'Jet0_SVtag_ipChi2Sum',
    'Jet0_SVtag_tau',
    'Jet0_SVtag_z',
    'Jet0_SVtag_pt']
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    for col in jet_cols:
        sample_jet[col] = sample_jet.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)
    for col in daughter_cols:
        sample_jet[col] = sample_jet[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Obtain features of each node within the graph
    features_list = []
    for _, row in sample_jet.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    # Create graph representation with data objects
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch)
            probability = torch.sigmoid(output)
            prediction = (probability > chosen_threshold).int()

    print(f'Probability: {probability.item()}')
    if prediction.item() == 1:  
        print(f'Prediction: b-jet')
    if prediction.item() == 0:  
        print(f'Prediction: not a b-jet')
    return probability.item()

i = 0

for i in range(100):
    make_predictions()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = validation_df
#       3 def make_predictions():
#       4     # Select a random integer for sampling
#       5     random_integer = np.random.randint(0, len(df))
#
# NameError: name 'validation_df' is not defined

# %% [markdown]
# # Create Efficiency Plot

# %%
model.load_state_dict(torch.load('full_bq_model2.pth'))
model = model.to('cpu')

# %%
# Separate b and q data from testing dataset (preprocessed)
b = test_df[test_df.IsB == 1]
q = test_df[test_df.IsB == 0]

b_data = create_graphs(b, feature_cols)
q_data = create_graphs(q, feature_cols)

b_prob = []
q_prob = []

def get_probabilities(data_list):
    prob_list = []
    model.eval()
    with torch.no_grad():
        for data in data_list:
            out = model(data.x, data.edge_index, data.batch)
            prob = torch.sigmoid(out).numpy().flatten()
            prob_list.append(prob)
    return np.concatenate(prob_list)

# Compute probabilities for b and q data
b_prob = get_probabilities(b_data)
q_prob = get_probabilities(q_data)

# %%
def plot_probability_distribution(b_prob, q_prob, target_efficiencies):

    # Sort b-jet probabilities in descending order for cutoff calculations
    sorted_b_prob = np.sort(b_prob)[::-1]
    
    # Calculate cutoffs for each efficiency level
    cutoffs = {}
    for efficiency in target_efficiencies:
        cutoff_index = int(len(sorted_b_prob) * efficiency)
        cutoffs[efficiency] = sorted_b_prob[cutoff_index - 1] if cutoff_index > 0 else sorted_b_prob[0]
    
    # Plot histograms for b-jet and q-jet probabilities
    plt.figure(figsize=(10, 6))
    b_values, b_bins, _ = plt.hist(b_prob, bins=100, label='b-jets', color='darkred', histtype='step')
    q_values, q_bins, _ = plt.hist(q_prob, bins=100, label='q-jets', color='mediumblue', histtype='step')

    max_y = max(max(b_values), max(q_values))
    
    # Mark cutoffs for selected efficiencies
    for i, (efficiency, cutoff) in enumerate(cutoffs.items()):
        plt.vlines(x=cutoff, ymin=0, ymax=max_y * 0.1, color='grey', linestyle='--', linewidth=1)
        plt.text(cutoff, max_y*0.12, f'{int(efficiency * 100)}%', ha='center', va='bottom', rotation=90)

    plt.xlabel("P$_b$")
    plt.ylabel("Number of Jets")
    plt.text(0.9, max_y * 0.8, "LHCb Simulation", fontsize=14, verticalalignment='bottom', horizontalalignment='right')
    plt.title("Probability Distribution")
    plt.yscale('log')
    plt.legend(loc='best')
    plt.show()

target_efficiencies = [0.6, 0.7, 0.8]
plot_probability_distribution(b_prob, q_prob, target_efficiencies)

# %%
chosen_tpr = 0.75
closest_index = np.argmin(np.abs(tpr - chosen_tpr))

# Retrieve the threshold and corresponding FPR for this TPR
chosen_threshold = thresholds[closest_index]
chosen_fpr = fpr[closest_index]

print(f"TPR {chosen_tpr}: Pb {chosen_threshold:.4f}: FPR {chosen_fpr:.4f}")
# Out:
# TPR 0.75: Pb 0.5078: FPR 0.0685

# %%
b = test_df[test_df.IsB == 1]
b.loc[:, 'Jet0_PT'] = b['Jet0_PT'].apply(lambda x: x[0] if isinstance(x, list) else x)

pt23_df = b[(b['Jet0_PT'].between(20000, 30000))].reset_index(drop=True)
pt34_df = b[(b['Jet0_PT'].between(30000, 40000))].reset_index(drop=True)
pt45_df = b[(b['Jet0_PT'].between(40000, 50000))].reset_index(drop=True)

# %%
def make_predictions(df):
    daughter_cols = [col for col in df.columns if "_Daughters" in col]
    svtag_cols = [
        'Jet0_SVtag_fdrMin',
        'Jet0_SVtag_ptSvrJet',
        'Jet0_SVtag_nTrk',
        'Jet0_SVtag_nTrkJet',
        'Jet0_SVtag_drSvrJet',
        'Jet0_SVtag_absQSum',
        'Jet0_SVtag_m',
        'Jet0_SVtag_mCor',
        'Jet0_SVtag_fdChi2',
        'Jet0_SVtag_ipChi2Sum',
        'Jet0_SVtag_tau',
        'Jet0_SVtag_z',
        'Jet0_SVtag_pt'
    ]
    jet_cols = ['Jet0_Eta', 'Jet0_PT'] + svtag_cols
    feature_cols = daughter_cols + jet_cols

    for col in jet_cols:
        df[col] = df.apply(lambda row: [row[col]] * row['Jet0_nDaughters'] if isinstance(row[col], (float, int)) else row[col], axis=1)
    for col in daughter_cols:
        df[col] = df[col].apply(lambda x: [float(num) for num in x.strip('[]').split(',')] if isinstance(x, str) else x)

    # Get features of each node within the graph
    features_list = []
    for _, row in df.iterrows():
        num_nodes = int(row['Jet0_nDaughters'])
        jet_nodes = [[] for _ in range(num_nodes)]
        
        for column in feature_cols:
            cell_value = row[column]

            if isinstance(cell_value, list):
                for i in range(num_nodes):
                    jet_nodes[i].append(cell_value[i])
            else:
                for node_features in jet_nodes:
                    node_features.append(cell_value)
        
        features_list.append(jet_nodes)
    
    data_objects = []
    for features in features_list:
        x = torch.tensor(features, dtype=torch.float)

        num_nodes = x.size(0)

        G = nx.complete_graph(num_nodes)
        edge_index = torch.tensor(list(G.edges)).t().contiguous()

        data = Data(x=x, edge_index=edge_index)
        data_objects.append(data)

    num_b = 0
    for data in data_objects:
        with torch.no_grad():
            output = model(data.x, data.edge_index, data.batch)
            probability = torch.sigmoid(output)
            prediction = (probability > chosen_threshold).int()

            if prediction.item() == 1:  
                num_b += 1

    return num_b

# %%
num_b23 = make_predictions(pt23_df)
num_b34 = make_predictions(pt34_df)
num_b45 = make_predictions(pt45_df)

# %%
efficiency23 = num_b23 / len(pt23_df)
efficiency34 = num_b34 / len(pt34_df)
efficiency45 = num_b45 / len(pt45_df)

print(f'Efficiency for pT 20-30 GeV: {efficiency23:.4f}')
print(f'Efficiency for pT 30-40 GeV: {efficiency34:.4f}')
print(f'Efficiency for pT 40-50 GeV: {efficiency45:.4f}')
# Out:
# Efficiency for pT 20-30 GeV: 0.7430
# Efficiency for pT 30-40 GeV: 0.7599
# Efficiency for pT 40-50 GeV: 0.7643

# %%
def plot_efficiency_histogram(efficiencies, pt_bins):
    plt.figure(figsize=(10, 6))

    # Calculate bin centers and widths
    bin_centers = (pt_bins[:-1] + pt_bins[1:]) / 2
    bar_width = np.diff(pt_bins)  # Width of the bins

    # Create the histogram by plotting only the tops of the bins
    for i in range(len(efficiencies)):
        plt.plot([pt_bins[i], pt_bins[i+1]], [efficiencies[i], efficiencies[i]], color='blue', linewidth=2)
    plt.xticks(np.arange(20000, 51000, 5000))
    plt.xlabel('pT (GeV)')
    plt.ylabel('Efficiency')
    plt.text(0.85, 0.95, "LHCb Simulation", fontsize=14, transform=plt.gca().transAxes, verticalalignment='center', horizontalalignment='center')
    plt.title('Efficiency for b-jets at 75% TPR')
    plt.ylim(0, 1)
    plt.xlim(20000,50000)
    plt.show()

pt_bins = np.array([20000, 30000, 40000, 50000])
efficiencies = [efficiency23, efficiency34, efficiency45]

plot_efficiency_histogram(efficiencies, pt_bins)

# %%
# Visualize some graphs
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, data in enumerate(train_loader.dataset[:6]):
    G = nx.Graph()
    G.add_edges_from(data.edge_index.t().tolist())

    nx.draw(G, ax=axes[i], node_color='navy', node_size=100)
    
    axes[i].set_title(f"Graph {i+1}: {data.num_nodes} nodes, {data.edge_index.size(1)} edges")

plt.tight_layout()
plt.show()
